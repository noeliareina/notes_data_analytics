# %% [markdown]
# JUEGO 1: PIEDRA, PAPEL O TIJERAS

# %% [markdown]
# Cliente:

# %% [markdown]
# - Inversor en app móvil.

# %% [markdown]
# Objetivo:
# - Queremos demostrar la funcionalidad del juego.
# - Entretener al usuario.
# - Intuitivo.

# %% [markdown]
# Audiencia:
# - Todas las edades
# - Adolescentes
# - Todos los que busquen un método de elección.

# %% [markdown]
# Aspectos importantes del juego a destacar:

# %% [markdown]
# - Intuitivo.
# - Personalización (Nick para cada jugador)

# %% [markdown]
# Código

# %%
# Vamos a definir cuántos puntos necesitas para ganar 
puntos_necesarios = 3

# %%
import random

jugador = input ("¿Cómo te llamas?🕵️")
print(jugador)


puntos_jugador = 0
puntos_compu = 0

while puntos_jugador < 3 and puntos_compu < 3:
    eleccion_jugador = input("Elige: piedra, papel o tijera 🗿🧻✂️").lower() 
    jugador_compu = random.choice(["piedra","papel","tijera"])  
    print(eleccion_jugador, "vs", jugador_compu)


    if eleccion_jugador not in ["piedra", "papel", "tijera"]:
        print("Opción no válida. Debes elegir entre piedra, papel o tijera.😡")   
        continue 


    if eleccion_jugador == jugador_compu:
            print("¡Empate!")
    elif eleccion_jugador == 'piedra' and jugador_compu == 'tijera':
            print('¡Has ganado un punto!✔️')
            puntos_jugador += 1
    elif eleccion_jugador == 'papel' and jugador_compu == 'piedra':
            print('¡Has ganado un punto!✔️')
            puntos_jugador += 1
    elif eleccion_jugador == 'tijera' and jugador_compu == 'papel':
            print('¡Has ganado un punto!✔️')
            puntos_jugador += 1

    else:
            print('¡Un punto menos, pringao!🤪')
            puntos_compu += 1
        
       

print ("---------------------")

if puntos_jugador ==3:
    print(f"Tienes tres puntos, has ganado, {jugador}.🥳")
    
else:
    print ("Compu tiene tres puntos, has perdido.😭")
