# %% [markdown]
# # **Repetición del Ejercicio Intermedio**
#  *para Aprobar el Examen del miércoles 12 de marzo*

# %%
# Creamos la conexión 💕😊

# %%
pip install mysql-connector

# %%
import pandas as pd
import mysql.connector
from datetime import date

# %%
def insertar(bbdd, query, valores):
    try:
        # Conectar a la base de datos
        cnx = mysql.connector.connect(
            user='root', 
            password='AlumnaAdalab',
            host='127.0.0.1', 
            database=bbdd,  # Ya especificaste la BBDD aquí
            auth_plugin='mysql_native_password'
        )
        mycursor = cnx.cursor()  # 🔹 Definir cursor antes de usarlo
        
        mycursor.executemany(query, valores)
        cnx.commit()  # Confirmar cambios

        print(mycursor.rowcount, "registros insertados")
    
    except mysql.connector.Error as err:
        print("Error:", err)

    finally:
        if mycursor:
            mycursor.close()  # Cerrar cursor
        if cnx:
            cnx.close()  # Cerrar conexión

# %%
# 🔹 Definir consultas por separado
query_generos = "INSERT INTO generos (nombre_genero, descripcion) VALUES (%s, %s)"
valores_generos = [
    ('Acción', 'Películas llenas de emoción y aventuras'),
    ('Comedia', 'Películas para reír y disfrutar'),
    ('Drama', 'Películas emocionales y profundas'),
    ('Ciencia Ficción', 'Películas con elementos futuristas o tecnológicos')
]

query_peliculas = "INSERT INTO peliculas (nombre, duracion, direccion, id_genero, fecha_estreno) VALUES (%s, %s, %s, %s, %s)"
valores_peliculas = [
    ('Misión Rescate', 130, 'Ridley Scott', 4, '2015-10-02'),
    ('La Gran Aventura', 120, 'Chris Columbus', 1, '2001-06-22'),
    ('Reír o Llorar', 95, 'John Smith', 2, '2020-11-12'),
    ('Crisis Total', 110, 'Jane Doe', 3, '2019-05-15')
]

query_clientes = "INSERT INTO clientes_act (nombre, apellido, direccion, telefono, email, fecha_registro) VALUES (%s, %s, %s, %s, %s, %s)"
valores_clientes = [
    ('Carlos', 'García', 'Av. Principal 123', '555-1234', 'carlos@example.com', '2023-01-15'),
    ('Lucía', 'Pérez', 'Calle Secundaria 45', '555-5678', 'lucia@example.com', '2023-02-20'),
    ('Miguel', 'Lopez', 'Av. Tercera 789', '555-9876', 'miguel@example.com', '2023-03-10')
]

query_alquileres = "INSERT INTO alquileres_act (id_alquileres, id_cliente, id_pelicula, fecha_alquiler, fecha_devolucion, estado) VALUES (%s, %s, %s, %s, %s, %s)"
valores_alquileres = [
    (1, 1, 1, '2025-01-01', None, 'pendiente'),
    (2, 2, 2, '2025-01-03', '2025-01-07', 'devuelto'),
    (3, 3, 4, '2025-01-05', None, 'pendiente')
]


# 🔹 Ejecutar cada inserción por separado
insertar("videoclub", query_generos, valores_generos)
insertar("videoclub", query_peliculas, valores_peliculas)
insertar("videoclub", query_clientes, valores_clientes)
insertar("videoclub", query_alquileres, valores_alquileres)
# Out:
# 4 registros insertados
# 4 registros insertados
# 3 registros insertados
# 3 registros insertados

# %%
df_clientes = pd.read_csv("files/clientes.csv", header=None, names=['nombre', 'apellido', 'direccion', 'telefono', 'email', 'fecha_registro'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df_clientes = pd.read_csv("files/clientes.csv", header=None, names=['nombre', 'apellido', 'direccion', 'telefono', 'email', 'fecha_registro'])
#
# ...
