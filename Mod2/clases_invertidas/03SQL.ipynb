# %% [markdown]
# ## 3. SQL: Introducción a BBDD y Normalización

# %% [markdown]
# Cómo se gestionan, diseñan las bases de datos con MySQL, un sistema de gestión de bases muy popular. Manipulación de datos.

# %% [markdown]
# 1. Intro entorno de trabajo Workbench
# 2. Importación de bases de datos: necesarias para nuestras lecciones de SQL, incluyendo cómo crear y cargar datos en MySQL Workbench.
# 3. Estructura de una base de datos: componentes básicos (tablas, atributos, registros y su interrelación.
# 4. Modelo relacional: info en tablas y relaciones
# 5. Claves Primarias y Foráneas: se utilizan para mantener la integridad de la base de datos.
# 6. Normalización: Proceso crucial para organizar la información de manera eficiente y libre de redundancias.

# %% [markdown]
# Aprenderemos a importar datos y a estructurarlos de forma que sean fáciles de analizar y visualizar.
#
# Paso 1: Preparar los Datos
# Antes de importar, asegúrate de que tus datos:
#
# Estén limpios (sin valores nulos inesperados, caracteres especiales, etc.).
# Sean coherentes (mismo formato de fecha, tipo de dato, etc.).
# Estén en un formato compatible, como CSV, Excel (XLSX) o SQL.
#
# Paso 2: Crear una Base de Datos en MySQL Workbench
# Abre MySQL Workbench y sigue estos pasos:
#
# Crear una nueva base de datos (schema):
#
# sql<>
# Copiar
# Editar
# CREATE DATABASE nombre_base_datos;
# USE nombre_base_datos;
#
# Paso 3: Importar Datos en MySQL Workbench
# 🔸 Opción A: Importar desde un Archivo CSV
# 1. Prepara el Archivo CSV:
#
# Asegúrate de que la primera fila contenga los nombres de las columnas.
# Usa comas , o punto y coma ; como delimitadores (según la configuración regional).
#
# 2. Crea la Tabla Manualmente: Primero, crea la tabla con las columnas correctas:
#
# sql<>
# Copiar
# Editar
#
# CREATE TABLE nombre_tabla (
#     id INT PRIMARY KEY AUTO_INCREMENT,
#     nombre VARCHAR(100),
#     edad INT,
#     fecha_registro DATE
# );
# 3. Importar el CSV usando Workbench:
#
# Ve a Server → Data Import.
# Selecciona Import from Self-Contained File y elige tu archivo CSV.
# Elige la base de datos destino.
# Marca Dump Structure and Data.
# En Advanced Options, selecciona el delimitador correcto (ej. , o ;).
# Haz clic en Start Import.
#
# 4. Importar CSV con SQL (Alternativa) Si prefieres hacerlo con SQL, usa:
# sql <>
# LOAD DATA INFILE '/ruta/a/tu/archivo.csv'
# INTO TABLE nombre_tabla
# FIELDS TERMINATED BY ','
# ENCLOSED BY '"'
# LINES TERMINATED BY '\n'
# IGNORE 1 ROWS;
#
# - FIELDS TERMINATED BY ',': Indica que los campos están separados por comas.
# - ENCLOSED BY '"': Si los valores están entre comillas.
# - IGNORE 1 ROWS: Ignora la primera fila (encabezados).
# Nota: Asegúrate de que MySQL tenga permisos para leer el archivo. En algunos sistemas, es posible que necesites mover el archivo a un directorio accesible como /var/lib/mysql-files/.

# %% [markdown]
# Opción B: Importar desde Excel (XLSX)
# Convierte el archivo a CSV:
#
# Abre el archivo en Excel o Google Sheets.
# Exporta o guarda como CSV.
# Sigue el Paso A para importar el CSV.
#
# Opción C: Importar desde un Script SQL
# Si tienes un archivo .sql que crea y llena las tablas, sigue estos pasos:
#
# Ve a Server → Data Import.
# Selecciona Import from Self-Contained File y elige el archivo .sql.
# Elige la base de datos destino.
# Haz clic en Start Import.

# %% [markdown]
# Paso 4: Normalizar los Datos
# Para que sean fáciles de analizar y visualizar, asegúrate de:
#
# Eliminar datos duplicados:
#
# SQL<>
# DELETE FROM nombre_tabla WHERE id NOT IN (
#     SELECT MIN(id) FROM nombre_tabla GROUP BY nombre, edad, fecha_registro
# );
#
# Separar datos en tablas relacionadas (normalización):
#
# Crea tablas para datos repetitivos, como:
# sql<>
#
# CREATE TABLE clientes (
#     id INT PRIMARY KEY AUTO_INCREMENT,
#     nombre VARCHAR(100),
#     email VARCHAR(100)
# );
#
# CREATE TABLE pedidos (
#     id INT PRIMARY KEY AUTO_INCREMENT,
#     cliente_id INT,
#     producto VARCHAR(100),
#     cantidad INT,
#     FOREIGN KEY (cliente_id) REFERENCES clientes(id)
# );
#
# Paso 5: Consultas para Análisis y Visualización
# - Consultas Básicas:
# SELECT * FROM nombre_tabla;
# SELECT nombre, COUNT(*) AS total FROM nombre_tabla GROUP BY nombre;
# SELECT AVG(edad) AS promedio_edad FROM nombre_tabla;
#
# Consultas Avanzadas para Análisis:
#
# sql<>
# SELECT producto, SUM(cantidad) AS total_vendido
# FROM pedidos
# GROUP BY producto
# ORDER BY total_vendido DESC;
#
# Join entre Tablas:
# SELECT c.nombre, p.producto, p.cantidad
# FROM clientes c
# JOIN pedidos p ON c.id = p.cliente_id;

# %% [markdown]
# Paso 6: Visualización en MySQL Workbench
# En MySQL Workbench, puedes visualizar datos usando la pestaña "EER Diagram":
#
# Ve a Database → Reverse Engineer... para crear un diagrama ER.
# Elige la base de datos.
# Sigue los pasos y genera el diagrama.
# Esto te ayudará a ver las relaciones entre tablas.

# %% [markdown]
#  Consejos para una Estructura Eficiente:
#  1. Usa índices en columnas que consultes frecuentemente
#  CREATE INDEX idx_nombre ON nombre_tabla(nombre);
#  2. Elige los tipos de datos correctos para optimizar el almacenamiento y las consultas (ej. INT para números, DATE para fechas).
#  3. Normaliza los datos para evitar redundancias, pero no exageres (3FN es suficiente en la mayoría de los casos)

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Cargar el CVD en un DataFrame
df = pd.read_csv ("/Escritorio/DATA ANALYTICS/promo 49/modulo2/clases_invertidas/personal2.csv")
print(df.head())
# Out:
#    Unnamed: 0                                            workers
# 0           0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1           1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2           2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3           3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'workers'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      int64
#  1   workers     4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes
# None

# %%
df_personal2 = pd.DataFrame(df)
pd.DataFrame(df)
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
df
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import json
df = pd.read_json("personal2.json")
df.head()
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
df.to_excel("personal2.xlsx")

# %%
df.to_csv("personal2.csv")
df.head()
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
df_personal2.to_csv("personal2.csv")
df_personal2 = pd.read_csv("personal2.csv")
