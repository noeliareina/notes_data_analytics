# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
from bs4 import BeautifulSoup
import requests
# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
pip install beautifulsoup4
url = "https://www.ebay.es/deals/electronica/moviles"

César Valle 8:54

# %%
sopa = BeautifulSoup(resp.content, "html.parser")

# %%
sopa.find("span", {"itemprop": "name"})

# %%
precios = sopa.findAll("span", {"itemprop": "price"})

# %%
<"span" itemprop="price">
class="first">360,50 EUR</span

# %%
nombres_dec = sopa_dec.findAll("h4", {"class": "de-ProductTile-title de-u-textMedium de-u-textShrink1 de-u-lg-textGrow1 de-u-lineHeight2"})
nombres_limpio = []
for n in nombres_dec:
    nombres_limpio.append(n.text.strip())
sopa_dec = BeautifulSoup(resp.content, "html.parser")
sopa_dec
sopa_dec.findAll("h4")

# %%
precios_dec = sopa_dec.findAll("span", {"class": "js-de-ProductTile-currentPrice"})

# %%
try:
    print(precios_dec[4].text.split("—")[1].replace("$", "").strip())
except:
    print(precios_dec[4].text.split("—")[0].replace("$", "").strip())
for p in precios_dec[5:]:
    print(p.text)
    try:
        print(p.text.split("—")[1])
    except:
        print(p.text.split("—")[0])

# %%
url_med = "https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020"
resp = requests.get(url_med)
sopa_med = BeautifulSoup(resp.content, "html.parser")
sopa_med

# %%
sopa_med.findAll("table")[0].findAll("th")[0]
