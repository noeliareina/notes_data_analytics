# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\noeli\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

#from src import soporte_extraccion as sp

# %%
load_dotenv()
key = os.getenv("API_KEY")

# %%
url = "https://jsonplaceholder.typicode.com/users"

# %%
datos = sp.llamada(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 datos = sp.llamada(url)
#
# NameError: name 'sp' is not defined

# %%
df = sp.transformar(datos)

# %%
def llamada(direccion, ):
    response = requests.get(direccion) 
    if response.status_code == 200:
        return response.json()
    
    else:
        print(f'hay un error en la llamada {response.status_code}')

# %%
datos_limpios = []
for d in datos:
    user = {"id": d["id"], "nombre": d["name"], "email": d["email"], "ciudad": d["address"]["city"]}
    datos_limpios.append(user)
def transformacion(datos_sucios):
    datos_limpios = []
    for d in datos_sucios:
        user = {"id": d["id"], "nombre": d["name"], "email": d["email"], "ciudad": d["address"]["city"]}
        datos_limpios.append(user)
    return pd.DataFrame(datos_limpios)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 datos_limpios = []
# ----> 2 for d in datos:
#       3     user = {"id": d["id"], "nombre": d["name"], "email": d["email"], "ciudad": d["address"]["city"]}
#       4     datos_limpios.append(user)
#
# NameError: name 'datos' is not defined

# %%
def transformacion(datos_sucios):
    datos_limpios = []
    for d in datos_sucios:
        user = {"id": d["id"], "nombre": d["name"], "email": d["email"], "ciudad": d["address"]["city"]}
        datos_limpios.append(user)
    return pd.DataFrame(datos_limpios)

# %%
# Usando list comprehension para limpiar los datos
def transformation(data):
clean_data = [{"id": d["id"], "name": d["name"], "email": d["email"], "city": d["address"]["city"]} for d in data]
return pd.DataFrame(clean_data)
