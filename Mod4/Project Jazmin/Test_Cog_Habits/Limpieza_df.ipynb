# %% [markdown]
# # Fase 2: Limpieza del Dataset

# %%
# Importación de librerías necesarias
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# Comenzamos la lectura del archivo .csv que contiene la data de la investigación. Los datos que se muestran han sido explorados en la primera fase del proyecto, no existen valores nulos ni duplicados pero si vemos necesario realizar un par de modificaciones para estandarizar los datos y mejorar la lectura de las variables para establecer relaciones.

# %%
df_limpieza = pd.read_csv("human_cognitive_performance.csv")


df_limpieza.sample(3)
# Out:
#       User_ID  Age  Gender  Sleep_Duration  Stress_Level       Diet_Type  \
# 55480  U55481   18  Female             4.7             9  Non-Vegetarian
# 76775  U76776   19    Male             5.9             9  Non-Vegetarian
# 72415  U72416   41  Female             4.5             1  Non-Vegetarian
#
#        Daily_Screen_Time Exercise_Frequency  Caffeine_Intake  Reaction_Time  \
# 55480                4.1                Low               64         476.83
# 76775                7.6             Medium              482         460.56
# 72415                9.2             Medium               11         204.03
#
#        Memory_Test_Score  Cognitive_Score  AI_Predicted_Score
# 55480                 55             27.0               23.39
# 76775                 56             29.0               25.18
# 72415                 85            100.0               97.41

# %% [markdown]
# **1. Cambiar las columnas de mayúscula a minúscula.**

# %%
df_limpieza.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Sleep_Duration', 'Stress_Level',
#        'Diet_Type', 'Daily_Screen_Time', 'Exercise_Frequency',
#        'Caffeine_Intake', 'Reaction_Time', 'Memory_Test_Score',
#        'Cognitive_Score', 'AI_Predicted_Score'],
#       dtype='object')

# %% [markdown]
# ¿Qué columnas tienen categóricas nominales ("object")?

# %%
df_limpieza.describe(include="O").T
# Out:
#                     count unique             top   freq
# User_ID             80000  80000              U1      1
# Gender              80000      3          Female  38404
# Diet_Type           80000      3  Non-Vegetarian  47986
# Exercise_Frequency  80000      3          Medium  31990

# %% [markdown]
# ¿Qué columnas tienen números discretos ("int")?

# %%
df_limpieza.describe(include="int").T
# Out:
#                      count        mean         std   min    25%    50%    75%  \
# Age                80000.0   38.525525   12.101876  18.0   28.0   39.0   49.0
# Stress_Level       80000.0    5.493762    2.865308   1.0    3.0    5.0    8.0
# Caffeine_Intake    80000.0  248.988213  144.541990   0.0  123.0  249.0  375.0
# Memory_Test_Score  80000.0   69.498350   17.305659  40.0   55.0   70.0   85.0
#
#                      max
# Age                 59.0
# Stress_Level        10.0
# Caffeine_Intake    499.0
# Memory_Test_Score   99.0

# %% [markdown]
# ¿Qué columnas tienen números discretos con decimales ("float")?

# %%
df_limpieza.describe(include="float").T
# Out:
#                       count        mean         std    min     25%     50%  \
# Sleep_Duration      80000.0    7.005332    1.734435    4.0    5.50    7.00
# Daily_Screen_Time   80000.0    6.504646    3.167072    1.0    3.80    6.50
# Reaction_Time       80000.0  399.973579  115.369329  200.0  300.15  400.36
# Cognitive_Score     80000.0   58.172395   23.058522    0.0   40.91   58.36
# AI_Predicted_Score  80000.0   58.121357   23.119598    0.0   40.85   58.36
#
#                        75%     max
# Sleep_Duration        8.50   10.00
# Daily_Screen_Time     9.20   12.00
# Reaction_Time       499.25  599.99
# Cognitive_Score      75.83  100.00
# AI_Predicted_Score   75.89  100.00

# %%
"""Función para renombrar las columnas"""

df_limpieza.rename(columns={columna: columna.lower() for columna in df_limpieza.columns}, inplace=True) #inplace=True, indica que la modificación se debe realizar directamente sobre el df

# %%
df_limpieza.columns # Comprobación
# Out:
# Index(['user_id', 'age', 'gender', 'sleep_duration', 'stress_level',
#        'diet_type', 'daily_screen_time', 'exercise_frequency',
#        'caffeine_intake', 'reaction_time', 'memory_test_score',
#        'cognitive_score', 'ai_predicted_score'],
#       dtype='object')

# %% [markdown]
# **2. Eliminamos la "U" en "user_id"**

# %%
def limpiar_columna(serie):
    return (
        serie
        .astype(str)           # aseguro que todo sea string
        .str.replace("U", "")  # eliminar "U"
        .astype(int)         # convierto a número
    )

# %%
columnas_a_convertir = ['user_id']

for col in columnas_a_convertir:
    df_limpieza[col] = limpiar_columna(df_limpieza[col])

# %%
df_limpieza.sample(3) # Comprobamos cambios
# Out:
#        user_id  age  gender  sleep_duration  stress_level       diet_type  \
# 44868    44869   20  Female             9.1             4  Non-Vegetarian
# 68897    68898   46    Male             4.6             7      Vegetarian
# 32815    32816   26    Male             8.8             2  Non-Vegetarian
#
#        daily_screen_time exercise_frequency  caffeine_intake  reaction_time  \
# 44868                5.4               High              450         274.36
# 68897                8.3             Medium               89         256.14
# 32815                9.2                Low              296         543.55
#
#        memory_test_score  cognitive_score  ai_predicted_score
# 44868                 88           100.00              100.00
# 68897                 48            67.28               69.87
# 32815                 99            47.79               46.59

# %% [markdown]
# **3.Convertimos a indice 'user_id'**

# %%
df_limpieza.set_index('user_id', inplace=True)

# %%
df_limpieza.sample(10)
# Out:
#          age  gender  sleep_duration  stress_level       diet_type  \
# user_id
# 66896     23    Male             4.6             7  Non-Vegetarian
# 17384     43    Male             5.0             1      Vegetarian
# 60706     45  Female             9.8             1           Vegan
# 55764     18  Female             6.1             2  Non-Vegetarian
# 14796     28    Male             4.7             8  Non-Vegetarian
# 31434     37  Female             9.8             5  Non-Vegetarian
# 62801     25  Female             4.3             9  Non-Vegetarian
# 7413      22  Female             8.7             7  Non-Vegetarian
# 16026     19    Male             8.5             8      Vegetarian
# 35971     21    Male             6.5             8           Vegan
#
#          daily_screen_time exercise_frequency  caffeine_intake  reaction_time  \
# user_id
# 66896                  8.9                Low              475         400.00
# 17384                  2.2                Low              345         259.11
# 60706                 10.6                Low              156         238.32
# 55764                 11.5             Medium              281         586.29
# 14796                  6.0               High              114         294.87
# 31434                  4.4             Medium              324         426.15
# 62801                 10.2               High              295         366.62
# 7413                   2.0             Medium               98         219.29
# 16026                  8.3             Medium              202         334.15
# 35971                  9.6               High              186         358.88
#
#          memory_test_score  cognitive_score  ai_predicted_score
# user_id
# 66896                   53            27.18               27.75
# 17384                   97            98.12               98.92
# 60706                   67            87.36               87.40
# 55764                   97            41.12               40.22
# 14796                   78            81.98               80.12
# 31434                   52            56.50               55.24
# 62801                   73            54.80               59.54
# 7413                    50            91.89               93.20
# 16026                   79            73.32               71.13
# 35971                   83            70.57               67.73

# %%
df_limpieza.to_csv("df_test.csv")
