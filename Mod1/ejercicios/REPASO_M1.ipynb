# %% [markdown]
# EJERCICIOS REPASO

# %% [markdown]
# INPUT SIEMPRE NOS DEVUELVE UN STRING
# int(input())

# %%
#Ejercicio 12 CLASE INVERTIDA BUCLES

#12. Inicia la variable 'ahorros' con un valor de '5'
# Crea un bucle while que mientras los ahorros sean igual o menor que '20'.
# Imprima por pantalla la cantidad de ahorros y añade '5' días más.
# Cuando la variable ahorros supere el valor de 20 el bucle deberá parar.


ahorros = 2
while ahorros <=20:
    print(ahorros)
    ahorros += 5

print(" ")

ahorros = 5
while ahorros <=20:
    ahorros += 5
    print(ahorros)
  
print(" ")
# Out:
# 2
# 7
# 12
# 17
#
# 10
# 15
# 20
# 25

# %%
ahorros = 2
while ahorros <=20:
    print(f"ahorros iniciales {ahorros}")

    # f de format: estamos formateando un String, 
    # lo ponemos para que la variable ahorros sea un string !!!!!!!!!!!!!!!
    # {} los corchetes son para meter variables: DICCIONARIOS

    ahorros += 5
    print(f"ahorros finales {ahorros}")
    # ITERACIÓN, CADA VEZ QUE SE EJECUTE EL CÓDIGO
    print("------------------" "👌"*10)
# Out:
# ahorros iniciales 2
# ahorros finales 7
# ------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌
# ahorros iniciales 7
# ahorros finales 12
# ------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌
# ahorros iniciales 12
# ahorros finales 17
# ------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌
# ahorros iniciales 17
# ahorros finales 22
# ------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌------------------👌

# %% [markdown]
# LA "f" NOS PERMITE PONER VARIABLES DENTRO DE UNA STRING

# %%
ahorros = 7
while ahorros <=20:
    print(f"ahorros iniciales {ahorros}")
    ahorros += 5
print(f"ahorros finales {ahorros}")
# Out:
# ahorros iniciales 7
# ahorros iniciales 12
# ahorros iniciales 17
# ahorros finales 22

# %% [markdown]
# 14. Crea un programa que calcule el impuesto sobre la renta de una persona basado en su ingreso anual y su estado civil (soltero o casado).
# 1""""Solicitar al usuario su ingreso anual.
#
# 2""""Preguntar al usuario su estado civil, permitiendo dos opciones: "soltero" (S) o "casado" (C).
#
# 3"""""Calcular el impuesto sobre la renta utilizando las siguientes reglas:
#
# 4"""""Si el estado civil es "soltero" (S):
#
# 5"""""Si el ingreso anual es menor o igual a $9,875, el impuesto es el 10% del ingreso anual.
#
# 6"""""Si el ingreso anual está entre $9,876 y $40,125, el impuesto es el 10% de los primeros $9,875 más el 12% de la cantidad que excede los $9,875.
#
# 7"""""Si el estado civil es "casado" (C):
#
# 8"""""Si el ingreso anual es menor o igual a $19,850, el impuesto es el 10% del ingreso anual.
#
# 9"""""Si el ingreso anual está entre $19,851 y $80,250, el impuesto es el 10% de los primeros $19,850 más el 12% de la cantidad que excede los $19,850

# %%
# Solicita el ingreso anual y el estado civil al usuario
ingreso_anual = float(input("cuanto ganas al año"))
print(ingreso_anual, type(ingreso_anual))

estado_civil = input("Estado civil (S/C)")
print(estado_civil, type(estado_civil))

if estado_civil.upper()== "S" or estado_civil.lower() == "soltera":
    print("ESTAS SOLTERA")

 #CUANDO LLEGAMOS A ESTE CAMINO, LO ROMPEMOS A OTRA CONDICIÓN
 # """"5
    if ingreso_anual <=9875 :
        impuesto = ingreso_anual*0.10
        print("el impuesto anuel es: ", impuesto)
        
# """"6. Si el ingreso anual está entre $9,876 y $40,125, el impuesto es el 10% 
# de los primeros $9,875 más el 12% de la cantidad que excede los $9,875.
    
    elif ingreso_anual <= 40125:
        impuesto = (9875 * 0.10) + (ingreso_anual - 9875) * 0.12
        print("el impuesto anual es:", impuesto)

    else:
        print("welcome to andorra")
   

elif estado_civil.upper() == "C" or estado_civil.lower() == "casada":
     print("estas casada")

     if ingreso_anual <=19850:
        impuesto = ingreso_anual*0.10
        print("el impuesto anual es: ", impuesto)

     elif ingreso_anual <= 80250:
        impuesto = (19850 * 0.10) + (ingreso_anual - 19850) * 0.12
        print("el impuesto anual es:", impuesto)  

     else:
        print("welcome to andorra")

else:
    ("No entiendo tu estado civil")
# Out:
# 18999.5 <class 'float'>
# s <class 'str'>
# ESTAS SOLTERA
# el impuesto anual es: 2082.44

# %%
estado = "S" #OPERADOR DE ASIGNACION
estado == "S"#OPERADOR DE COMPARACIÓN. DEVUELVE TRUE O FALSE

# %% [markdown]
# GENERAR UN BUCLE WHILE QUE NOS VAYA PREGUNTANDO HASTA QUE ...

# %%
letra = input("introduce una letra")
Vocales = ["a", "e", "i", "o", "u"]

if letra in Vocales:
    print("es vocal")

else:
    print("no es vocal")
# Out:
# no es vocal

# %%
# SOLO QUIERO QUE ME DES VOCAL.
letra = input("introduce una vocal")
vocales = ["a", "e", "i", "o", "u"]

while letra not in vocales:

    print("error, prueba otra vez")
    letra = input("introduce una letra")
print(letra)
# Out:
# error, prueba otra vez
# error, prueba otra vez
# error, prueba otra vez
# u

# %%
# SOLO QUIERO QUE ME DES VOCAL pero PUEDES INTENTAR SOLO 4 VECES
letra = input("introduce una vocal")
intentos = 4
vocales = ["a", "e", "i", "o", "u"]

while letra not in vocales and intentos > 0:

    print("error, prueba otra vez")
    letra = input("introduce una letra")
    intentos -= 1
    #IMPORTANTE
print(letra)
# Out:
# error, prueba otra vez
# error, prueba otra vez
# error, prueba otra vez
# error, prueba otra vez
# 1

# %% [markdown]
# CUANDO APRENDAMOS EL BREAK LE VAMOS A DECIR QUE PARE CUANDO HAYA UNA CONDICION QUE LE DIGAMOS

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
