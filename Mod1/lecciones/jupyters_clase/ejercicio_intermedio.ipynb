# %% [markdown]
# 1. Crea un programa que busque una palabra específica(elegida por la usuaria) en una cadena de texto
#  e indique su posición.

# %%
frase = "adalabers promo 49"
objetivo = "promo"
lista_frase = frase.split()

# %%
print (lista_frase)
# Out:
# ['adalabers', 'promo', '49']

# %%
lista_frase.index(objetivo) + 1
# Out:
# 2

# %%
frase.find("promo")
# Out:
# 10

# %%
frase.find(objetivo)
# Out:
# 10

# %%
frase = "adalabers", "promo", "49"

# %%
type(frase)
# Out:
# tuple

# %%
frase = 'Mi gato está que se sube por las paredes'
frase.find('gato')
# Out:
# 3

# %% [markdown]
# 2. Dada la siguiente lista:
# frutas = ['manzana', 'pera', 'banana', 'uva', 'kiwi'],
#  realiza lo siguiente:

# %%
frutas = ['manzana', 'pera', 'banana', 'uva', 'kiwi']

# %%
# Reemplaza el segundo elemento con 'durazno'.

frutas.pop(1)
frutas.insert(1, "durazno")

print(frutas)
# Out:
# ['manzana', 'durazno', 'banana', 'uva', 'kiwi']

# %%
frutas = ['manzana', 'pera', 'banana', 'uva', 'kiwi']

# %%
frutas[1]
# Out:
# 'pera'

# %%
frutas[1] = "durazno"

print(frutas)
# Out:
# ['manzana', 'durazno', 'banana', 'uva', 'kiwi']

# %%
# Agrega 'naranja' al final de la lista.

frutas.append("naranja")

# %%
print(frutas)
# Out:
# ['manzana', 'durazno', 'banana', 'uva', 'kiwi', 'naranja']

# %%
# frutas[-1] = "naranja" -> no añade si no que modifica el último elemento

# %%
# Extrae y muestra por pantalla el tercer elemento de la lista.

frutas = ['manzana', 'pera', 'banana', 'uva', 'kiwi']
tercer_elemento = frutas[2]
print("El tercer elemento es:", tercer_elemento)
# Out:
# El tercer elemento es: banana

# %%
print("El tercer elemento es:", frutas[2])
# Out:
# El tercer elemento es: banana

# %%
frutas.pop(2) # elimina el elemento de la lista
# Out:
# 'banana'

# %%
print(frutas[2])
# Out:
# uva

# %% [markdown]
# 3. Crea una lista llamada numeros que contenga los siguientes valores: 10, 25, 15, 30, 20.

# %%
numeros = [10, 25, 15, 30, 20]

# %%
# Agrega el valor 35 al incio de la lista numeros.

numeros.insert(0, 35)

print(numeros)
# Out:
# [35, 10, 25, 15, 30, 20]

# %%
# Ordena la lista numeros en orden ascendente.

# 2.- Ordena la lista de numeros en orden ascendente:
numeros = [35, 10, 25, 15, 30, 20]
print("La lista de numeros antes de ordenarse es:", numeros)
# Out:
# La lista de numeros antes de ordenarse es: [35, 10, 25, 15, 30, 20]

# %%
numeros.sort()
print("La lista de numeros despues de ordenarse es:", numeros)
# Out:
# La lista de numeros despues de ordenarse es: [10, 15, 20, 25, 30, 35]

# %%
numeros.sort(reverse=True)

# %%
print(numeros)
# Out:
# [35, 30, 25, 20, 15, 10]

# %%
# Encuentra el índice del número 25.

numeros.index(25)
# Out:
# 2

# %%
"25" == 25
# Out:
# False

# %%
type("25")
# Out:
# str

# %%
type(25)
# Out:
# int

# %% [markdown]
# 4. Crea un diccionario llamado frutas con las siguientes parejas clave-valor:

# %%
frutas = {'manzana': 2, 
          'banana': 3, 
          'uva': 5,
          'pera': 4}

# %%
# Saca una lista de todas las frutas en el diccionario.

list(frutas.keys())
# Out:
# ['manzana', 'banana', 'uva', 'pera']

# %%
type(frutas.keys())
# Out:
# dict_keys

# %%
frutas.keys()
# Out:
# dict_keys(['manzana', 'banana', 'uva', 'pera'])

# %%
# help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
# ...

# %%
# Saca una lista de todas las cantidades en el diccionario.

list(frutas.values())
# Out:
# [2, 3, 5, 4]

# %%
#¿Qué cantidad de 'manzana' tenemos?. Si la clave 'manzana' no está presente, devuelve un mensaje diciendo "No existe esa clave".

if "manzana" in frutas:
    print("tenemos", frutas.get("manzana"), "manzanas")

else:
    print("no existe esa clave")
# Out:
# tenemos 2 manzanas

# %%
frutas.get("macarrones", "no existe esa clave")
# Out:
# 'no existe esa clave'

# %%
frutas["macarrones"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 frutas["macarrones"]
#
# KeyError: 'macarrones'

# %%
print(frutas)
# Out:
# {'manzana': 2, 'banana': 3, 'uva': 5, 'pera': 4}

# %%
frutas.get("macarrones")
if "macarrones" not in frutas:
    print("No existe esa clase")
# Out:
# No existe esa clase

# %% [markdown]
# Combinar métodos de listas y diccionarios:
# Obtén una lista de todas las cantidades en el diccionario y calcula suma total de las cantidades del diccionario frutas_total.
# Utilizando la lista creada en el apartado anterior encuentra la cantidad más grande y más pequeña.

# %%
print(frutas)
# Out:
# {'manzana': 2, 'banana': 3, 'uva': 5, 'pera': 4}

# %%
valores = list(frutas.values())

print(valores)
# Out:
# [2, 3, 5, 4]

# %%
sum(valores)
# Out:
# 14

# %%
print(sum(frutas.values()))
# Out:
# 14

# %%
print(frutas)
# Out:
# {'manzana': 2, 'banana': 3, 'uva': 5, 'pera': 4}

# %%
frutas["kiwi"] = 6

# %%
print(frutas)
# Out:
# {'manzana': 2, 'banana': 3, 'uva': 5, 'pera': 4, 'kiwi': 6}

# %% [markdown]
# 5. Evaluación de Edades:
#
# Escribe un programa que solicite al usuario ingresar su edad.
# Si la edad es menor de 18, muestra "Eres menor de edad".
# Si la edad está entre 18 y 65 (incluyendo ambos extremos), muestra "Eres adulto".
# Si la edad es mayor que 65, muestra "Eres un adulto mayor".

# %%
edad = int (input ("Ingresa tu edad"))

if edad <18:
    print ("Eres menor de edad")
elif edad== 18:
    print ("Eres adulto por los pelos")
elif edad<= 65:
    print ("Eres adulto")
else:
    print("Eres un adulto mayor")

# %%
edad = 17

if edad <18:
    print ("Eres menor de edad")

elif edad<= 65:
    print ("Eres adulto")

else:
    print("Eres un adulto mayor")
# Out:
# Eres menor de edad

# %%
edad = 19

if edad < 18:
    print("Eres menor de edad")
elif edad >= 18 and edad <= 65:
    print("Eres adulto")
else:
    print("Eres un adulto mayor")
# Out:
# Eres adulto

# %%
edad = 210

if edad < 18:
    print("Eres menor de edad")
elif 18 <= edad <= 65:
    print("Eres adulto")
else:
    print("Eres un adulto mayor")
# Out:
# Eres un adulto mayor

# %% [markdown]
# Determinación de Día de la Semana
#
#  - Solicita al usuario que ingrese un número del 1 al 7.
#  - Utilizando una serie de `if-elif-else`, muestra el día de la semana correspondiente al número ingresado. Por ejemplo, si ingresa 1, muestra "Lunes".

# %%
dia_semana=int(input("Introduce un dia de la semana en números"))
if dia_semana ==1:
    print("Es lunes")
elif dia_semana ==2:
    print("Es martes")
elif dia_semana ==3:
    print("Es miercoles")
elif dia_semana ==4:
    print("Es jueves")
elif dia_semana ==5:
    print("Es viernes")
elif dia_semana ==6:
    print("Es sabado")
elif dia_semana ==7:
    print("Es domingo")
else:
    print("El día introducido es erróneo, vuelve a intentarlo con números del 1 al 7")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 dia_semana=int(input("Introduce un dia de la semana en números"))
#       2 if dia_semana ==1:
#       3     print("Es lunes")
#
# ValueError: invalid literal for int() with base 10: 'lunes'

# %%
dia_semana="lunes"
if dia_semana ==1:
    print("Es lunes")
elif dia_semana ==2:
    print("Es martes")
elif dia_semana ==3:
    print("Es miercoles")
elif dia_semana ==4:
    print("Es jueves")
elif dia_semana ==5:
    print("Es viernes")
elif dia_semana ==6:
    print("Es sabado")
elif dia_semana ==7:
    print("Es domingo")
else:
    print("El día introducido es erróneo, vuelve a intentarlo con números del 1 al 7")
# Out:
# El día introducido es erróneo, vuelve a intentarlo con números del 1 al 7

# %%
dia_semana=input("Introduce un dia de la semana en números")
if dia_semana =="1" or dia_semana.lower() == "lunes":
    print("Es lunes")
elif dia_semana =="2":
    print("Es martes")
elif dia_semana =="3":
    print("Es miercoles")
elif dia_semana =="4":
    print("Es jueves")
elif dia_semana =="5":
    print("Es viernes")
elif dia_semana =="6":
    print("Es sabado")
elif dia_semana =="7":
    print("Es domingo")
else:
    print("El día introducido es erróneo, vuelve a intentarlo con números del 1 al 7")
# Out:
# Es lunes

# %%
dias_semana = {1: "lunes", 2: "martes", 3: "miércoles", 4: "jueves", 5: "viernes", 6:"sábado", 7: "domingo"}

dia_elegido = int(input("Ingrese un número del 1 al 7"))

if dia_elegido in dias_semana.keys():

    print(f"El día {dia_elegido} corresponde a {dias_semana[dia_elegido]}")

else:
    
    print("Has introducido un número incorrecto")
# Out:
# El día 2 corresponde a martes

# %%
dias_semana[1]
# Out:
# 'lunes'

# %%
nombre = "Cesar"
ciudad = "Madrid"

print("Hola mi nombre es ", nombre, "y vivo en ", ciudad)
# Out:
# Hola mi nombre es  Cesar y vivo en  Madrid

# %%
nombre = "Cristina"
ciudad = "Madrid"

print(f"Hola mi nombre es {nombre} y vivo en {ciudad}")
# Out:
# Hola mi nombre es Cristina y vivo en Madrid

# %%
dias_semana={1:'lunes', 2: 'martes', 3:'miercoles', 4: 'jueves', 5: 'viernes', 6: 'sabado', 7:'domingo'}

dia_usuario=int(input("elije un numero del 1 al 7"))

dias_semana.get(dia_usuario, "error")
# Out:
# 'error'

# %%
weekdays= ['Lunes','Martes','Miercules','Jueves','Viernes','Sabado','Domingo']
unnumero=int((input('Elige un numero entre 1 y 7')))
print(weekdays[unnumero-1])
# Out:
# Lunes

# %% [markdown]
# Ejercicio 7: Juego de Adivinanza

# %%
import random

print("🕹️Este es el juego de adivinar el número🕹️")
numero_secreto = random.randint(a=0, b=100)
# print(numero_secreto)
contador = 0
while True:
    numero_jugador = int(input("Inserte un número entre el 1 y el 100✏️"))
    contador += 1
    if numero_secreto == numero_jugador:
            if contador == 1:
                 print("¡Ganaste al primer intento!🎉")
            else:        
                print(f"¡Ganaste en el intento {contador}!🎉")
            break
    elif numero_jugador < numero_secreto:
        print(f"El {numero_jugador} no es el correcto😥. PISTA: El número secreto es mayor ⏫ que el que has introducido. Llevas {contador} intentos")
    else:
        print(f"El {numero_jugador} no es el correcto😥. PISTA: El número secreto es menor ⏬ que el que has introducido. Llevas {contador} intentos")
# Out:
# 🕹️Este es el juego de adivinar el número🕹️
# 93
# El 99 no es el correcto😥. PISTA: El número secreto es menor ⏬ que el que has introducido. Llevas 1 intentos
# El 99 no es el correcto😥. PISTA: El número secreto es menor ⏬ que el que has introducido. Llevas 2 intentos
# El 2 no es el correcto😥. PISTA: El número secreto es mayor ⏫ que el que has introducido. Llevas 3 intentos
# ¡Ganaste en el 4 intento!🎉

# %%
import random

# %%
random.randint(1,1000000)
# Out:
# 650214

# %%
num_random = random.randint(1, 100)
intentos = 0
print("Inserta un número")
num_usuario = int(input())
print(num_usuario)
if num_usuario == num_random:
    print("¡Ganaste en el primer intento!")
else:
    while num_usuario != num_random:
        
        if num_usuario > num_random:
            print("Prueba con un número más pequeño")
            num_usuario = int(input())
            print(num_usuario)
            intentos += 1
        else:
            print("Prueba con un número más grande")
            num_usuario = int(input())
            print(num_usuario)
            intentos += 1
        if num_random == num_usuario:
            print("Ganaste en el intento número", intentos)
            break

# %%
n_aleat = random.randint(1,100)
print(n_aleat)
intentos = 1
while intentos !=0:
    intentos = intentos -1
    numero_usuario = input("proporciona un numero entre el 1 y el 100")
    numero_int = int(numero_usuario)
    if (n_aleat == numero_int) : 
        print('¡Ganaste en el primer intento!')
else:
    print('has fallado')

# %%
numero = 89

adivina_numero = int(input("Pasa un numero entero entre 1 y 100"))

intentos = 1

while numero != adivina_numero:
    print("lo siento no has acertado, intentalo de nuevo")
    adivina_numero = int(input("Pasa un numero entero entre 1 y 100"))
    intentos += 1

    if numero > adivina_numero:
        print("el numero es mas grande")
    else:
        print("el num es mas pequeño")
        
if intentos == 1:
    print("1 intento")

else:
    print("mas")     
print(f"Perfecto, el numero era {adivina_numero} lo has acertado despues de {intentos} intentos")

# %%
num = 66
adivina = int(input('adivina el número'))
numero_intentos = 0
if adivina == num:
    print('¡Ganaste en el primer intento')

else:
    while adivina != num:
        print('prueba otra vez')
        numero_intentos += 1
        
        if adivina < num:
            print('pista: mayor')
        else:
            print('pista: menor')
        adivina = int(input('vuelve a adivinar el número'))

# %%
numero = 12
intentos = 1

pregunta = int(input("¿que nuemero crees que es?"))

if pregunta == numero:
    print("¡Ganaste en el primer intento!")
else:
    while pregunta != numero:
        intentos += 1
        if pregunta < numero:
            print("el numero a adivinar es mayor, intentalo de nuevo")
        else:
            print("el numero a adivinar es menor, intentalo de nuevo")
        pregunta = int(input("¿que numero crees que es?"))

# %%
num = 2


opcion = "sigue en el bucle"

while opcion == "sigue en el bucle":
    usuaria = int(input("dime un num"))

    if num == usuaria:
        opcion = "para el bucle"
        print("lo has adivinado")
        # si intentos = 1 print
        # si mas intentos otro print

    else:
        # si el num es mayor pasan cosas

        # si el num es menor pasan otras cosas
        print("sigo en el bucle")

    print("---------------------------------------------------------------")
# Out:
# sigo en el bucle
# ---------------------------------------------------------------
# sigo en el bucle
# ---------------------------------------------------------------
# lo has adivinado
# ---------------------------------------------------------------

# %%
opcion = False

opcion == True
# Out:
# False

# %%
numero1 = 50
intentos = 0
correcto = False
while correcto == False:
    usuario_num = int(input('Adivina adivinanza, adivina el número que estoy pensando:'))
    intentos += 1 
    
    if usuario_num == numero1:
        correcto = True         #condicion parada
        print('¡Ganaste!')
        if intentos == 1:
            print('¡Ganaste en el primer intento!')
        else:
            print('Has ganado en', intentos, 'intentos.') 
    else:
        if usuario_num < numero1:
            print('El número es mayor. Intenta de nuevo.')
        else: 
            usuario_num > numero1
            print('El número es menor. Intenta de nuevo.')

# %%
correcto = True
not correcto
# Out:
# False

# %%
intentos = 1
intentos += 1

print(intentos == 1)
# Out:
# False

# %%
# Yo lo he hecho siguiendo la lógica del ejercicio del dinero de ayer, aunque es verdad que se incluyen cosas que he ido armando con chat: numero = 22
intentos = 5


while intentos > 0: # Mientras haya intentos disponibles
    numero = int(input('Adivina el número: '))

    if numero == numero_adivinanza:
        print("¡Has acertado!")
        break # Sale del bucle si aciertas
    else:
    # Añadir pistas
    if numero < numero_adivinanza:
        print("El número es mayor.")
    elif numero > numero_adivinanza:
        print("El número es menor.")
    else:
        print("Sigue intentando")

    intentos -= 1 # Disminuye los intentos restantes
    print(f"Llevas {intentos} intentos restantes")

    if intentos == 0: # Si se acaban los intentos sin acertar
        print("Se han acabado tus intentos. El número era", numero_adivinanza)

# %%
if num > 0 and num < 100:
    logica_juego


else:
    print("error")

# %%
while True:
    print("aquí te quedas")
# Out:
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# aquí te quedas
# ...
