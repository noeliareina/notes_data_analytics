# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("world_data_full_apply_nulos.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      country  density abbreviation  agricultural_land  \
# 0           0  Afghanistan     60.0           AF               58.1
# 1           1      Albania    105.0           AL               43.1
# 2           2      Algeria     18.0           DZ               17.4
# 3           3      Andorra    164.0           AD               40.0
# 4           4       Angola     26.0           AO               47.5
#
#    land_area  armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0    652.230              323.0       32.49          93.0              Kabul
# 1     28.748                9.0       11.78         355.0             Tirana
# 2        NaN              317.0       24.28         213.0            Algiers
# 3    468.000                NaN        7.20         376.0   Andorra la Vella
# 4        NaN              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# ...

# %%
val_land_area = df["land_area"].value_counts()
# Out:
# land_area
# 652.230    1
# 120.538    1
# 323.802    1
# 309.500    1
# 796.095    1
#           ..
# 245.857    1
# 36.125     1
# 214.969    1
# 27.750     1
# 390.757    1
# Name: count, Length: 165, dtype: int64

# %%
df.groupby("continent")["country"].count()
# Out:
# continent
# Africa             53
# Asia               45
# Central America    20
# Europe             47
# North America       2
# Oceania            14
# South America      13
# Name: country, dtype: int64

# %%
df.groupby("continent")["country"].describe()
# Out:
#                 count unique                  top freq
# continent
# Africa             53     53              Algeria    1
# Asia               45     45          Afghanistan    1
# Central America    20     20  Antigua and Barbuda    1
# Europe             47     47              Albania    1
# North America       2      2               Canada    1
# Oceania            14     14            Australia    1
# South America      13     13            Argentina    1

# %%
df.groupby("continent")["country"].min()
# Out:
# continent
# Africa                         Algeria
# Asia                       Afghanistan
# Central America    Antigua and Barbuda
# Europe                         Albania
# North America                   Canada
# Oceania                      Australia
# South America                Argentina
# Name: country, dtype: object
