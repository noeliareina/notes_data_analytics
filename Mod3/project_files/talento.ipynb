# %% [markdown]
# SALARIO:
# todas las que son rate es por lo que vende la empresa al empleado.
#
#     - columnas salario unificar: HourlyRate: Tarifa por hora calculada.(eliminar)
#
#     - MonthlyIncome: Ingreso mensual estimado en base al salario anual.
#
#     - MonthlyRate: Tarifa mensual estimada en función de la tarifa diaria.
#
#     - PercentSalaryHike: Incremento porcentual en el salario...al año? desde que entro en la empresa?
#
#     - WORKLIFEBALANCE: Nivel de balance entre vida personal y laboral.
#
#     - Salary: Salario anual calculado para el empleado. ES OBJETC PASAR A FLOAT
#
#     - HourlyRate: Tarifa por hora calculada. ELIMINAR

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("hr_raw_data.csv", index_col = 0)

# %%
data.head(5)
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# ...

# %%
data.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 41

# %%
data.columns[:10]
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %% [markdown]
# ### Observación y limpieza de datos en columnas desde Age a employeenumber ###

# %%
data.shape
# Out:
# (1678, 41)

# %%
print(f"El número de filas de mi df es {data.shape[0]}, y el número de columnas es {df_raw_data.shape[1]}.")
# Out:
# El número de filas de mi df es 1678, y el número de columnas es 41.

# %%
# describe para sacar los principales estadísticos del DataFrame
data.describe().T
# Out:
#                            count         mean         std          min  \
# dailyrate                 1678.0   668.079714  470.787298   104.103175
# distancefromhome          1678.0     4.504172   14.652066   -49.000000
# education                 1678.0     2.932658    1.024270     1.000000
# employeecount             1678.0     1.000000    0.000000     1.000000
# employeenumber            1678.0   809.859952  467.084867     1.000000
# environmentsatisfaction   1678.0     4.264005    6.912695     1.000000
# gender                    1678.0     0.398689    0.489774     0.000000
# hourlyrate                 411.0    83.140768   57.272101    13.012897
# jobinvolvement            1678.0     2.740763    0.710359     1.000000
# joblevel                  1678.0     2.064362    1.099425     1.000000
# jobsatisfaction           1678.0     2.743147    1.105172     1.000000
# numcompaniesworked        1678.0     2.670441    2.501133     0.000000
# ...

# %%
# describe para columnas de tipo numérico, object(texto)
data.describe(include="O").T
# Out:
#                     count unique  \
# age                  1678     54
# attrition            1678      2
# businesstravel        877      3
# department            312      3
# educationfield        904      6
# jobrole              1678   1579
# maritalstatus        1003      5
# monthlyincome        1189    493
# monthlyrate          1678    673
# over18                740      1
# overtime              982      2
# performancerating    1478      2
# standardhours        1327      2
# totalworkingyears    1129     40
# worklifebalance      1564      4
# yearsincurrentrole     35     10
# sameasmonthlyincome  1189    493
# salary               1393    583
# roledepartament       312    301
# remotework           1678      5
#
#                                                                  top  freq
# age                                                               35    88
# attrition                                                         No  1406
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1673     True
# 1674     True
# 1675     True
# 1676     True
# 1677     True
# Length: 1678, dtype: bool

# %%
data.isna()
# Out:
#         age  attrition  businesstravel  dailyrate  department  \
# 0     False      False            True      False        True
# 1     False      False            True      False        True
# 2     False      False           False      False       False
# 3     False      False           False      False        True
# 4     False      False            True      False        True
# ...     ...        ...             ...        ...         ...
# 1673  False      False            True      False        True
# 1674  False      False            True      False        True
# 1675  False      False           False      False        True
# 1676  False      False           False      False        True
# 1677  False      False            True      False        True
#
#       distancefromhome  education  educationfield  employeecount  \
# 0                False      False            True          False
# 1                False      False           False          False
# ...

# %%
round(data.isna().sum()/data.shape[0]*100, 2)
# Out:
# age                           0.00
# attrition                     0.00
# businesstravel               47.74
# dailyrate                     0.00
# department                   81.41
# distancefromhome              0.00
# education                     0.00
# educationfield               46.13
# employeecount                 0.00
# employeenumber                0.00
# environmentsatisfaction       0.00
# gender                        0.00
# hourlyrate                   75.51
# jobinvolvement                0.00
# joblevel                      0.00
# jobrole                       0.00
# jobsatisfaction               0.00
# maritalstatus                40.23
# monthlyincome                29.14
# monthlyrate                   0.00
# numcompaniesworked            0.00
# over18                       55.90
# overtime                     41.48
# percentsalaryhike             0.00
# performancerating            11.92
# relationshipsatisfaction      0.00
# standardhours                20.92
# ...

# %%
df_cat = data.select_dtypes(include="object")
df_cat
# Out:
#      age attrition businesstravel                department    educationfield  \
# 0     51        No            NaN                       NaN               NaN
# 1     52        No            NaN                       NaN     Life Sciences
# 2     42        No  travel_rarely   Research & Development   Technical Degree
# 3     47        No  travel_rarely                       NaN           Medical
# 4     46        No            NaN                       NaN  Technical Degree
# ...   ..       ...            ...                       ...               ...
# 1673  43        No            NaN                       NaN           Medical
# 1674  47        No            NaN                       NaN               NaN
# 1675  29        No  travel_rarely                       NaN               NaN
# 1676  47        No  travel_rarely                       NaN     Life Sciences
# 1677  32        No            NaN                       NaN     Life Sciences
#
# ...

# %%
# vemos los datos que son tipo float
df_flo= data.select_dtypes(include="float")
df_flo
# Out:
#         dailyrate  hourlyrate  numberchildren
# 0     2015.722222         NaN             NaN
# 1     2063.388889         NaN             NaN
# 2     1984.253968         NaN             NaN
# 3     1771.404762         NaN             NaN
# 4     1582.771346         NaN             NaN
# ...           ...         ...             ...
# 1673   488.944444         NaN             NaN
# 1674  1973.984127         NaN             NaN
# 1675   290.035510         NaN             NaN
# 1676  1032.487286         NaN             NaN
# 1677   556.256661   69.532083             NaN
#
# [1678 rows x 3 columns]

# %%
data["datebirth"].unique()
# Out:
# array([1972, 1971, 1981, 1976, 1977, 1975, 1964, 1982, 1967, 1985, 1968,
#        1983, 1965, 1988, 1978, 1990, 1987, 1989, 1970, 1980, 1963, 1991,
#        1986, 1974, 1984, 1973, 1979, 1993, 1994, 1992, 1969, 1966, 1996,
#        1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005],
#       dtype=int64)

# %%
data["datebirth"].value_counts()
# Out:
# datebirth
# 1992    89
# 1988    88
# 1989    86
# 1994    82
# 1987    80
# 1991    67
# 1993    66
# 1985    64
# 1990    63
# 1983    60
# 1986    56
# 1995    54
# 1996    54
# 1978    50
# 1981    50
# 1982    48
# 1997    47
# 1984    46
# 1980    42
# 1977    38
# 1979    34
# 1973    34
# 1999    31
# 1976    31
# 1998    28
# 1974    26
# 1968    26
# 1972    22
# 1975    22
# 1969    20
# 1970    20
# 1971    19
# 1967    18
# 1965    17
# 2001    17
# 2002    17
# 2000    15
# 1964    11
# 2003    11
# 2004     9
# 2005     9
# 1966     6
# 1963     5
# Name: count, dtype: int64

# %%
data["age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 'forty-seven', '53',
#        '43', '60', '32', '37', '49', '39', '50', '44', '30',
#        'fifty-eight', '29', '31', '54', '57', '27', 'thirty-six', '28',
#        '26', 'fifty-five', '25', 'fifty-two', 'thirty-one', '24',
#        'thirty', '23', '22', '21', '20', 'twenty-six', '19',
#        'thirty-seven', '18', 'thirty-two', 'twenty-four'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

# %%
data["age"].value_counts()
# Out:
# age
# 35              88
# 31              88
# 34              86
# 29              82
# 36              79
# 32              66
# 30              65
# 38              64
# 33              63
# 40              60
# 28              54
# 37              54
# 27              54
# 45              50
# 42              50
# 41              48
# 39              46
# 26              46
# 43              42
# 46              38
# 44              34
# 50              34
# 47              30
# 24              29
# 25              28
# 49              26
# 55              25
# 51              22
# 48              22
# 53              20
# 54              20
# 52              18
# 56              18
# 21              17
# 22              17
# 58              16
# 23              15
# 59              11
# 20              11
# 18               9
# 19               9
# 57               6
# 60               5
# thirty-two       2
# twenty-four      2
# thirty           1
# fifty-eight      1
# ...

# %%
data["age"].count()
# Out:
# 1678

# %%
data.select_dtypes(include='object')
# Out:
#      age attrition businesstravel                department    educationfield  \
# 0     51        No            NaN                       NaN               NaN
# 1     52        No            NaN                       NaN     Life Sciences
# 2     42        No  travel_rarely   Research & Development   Technical Degree
# 3     47        No  travel_rarely                       NaN           Medical
# 4     46        No            NaN                       NaN  Technical Degree
# ...   ..       ...            ...                       ...               ...
# 1673  43        No            NaN                       NaN           Medical
# 1674  47        No            NaN                       NaN               NaN
# 1675  29        No  travel_rarely                       NaN               NaN
# 1676  47        No  travel_rarely                       NaN     Life Sciences
# 1677  32        No            NaN                       NaN     Life Sciences
#
# ...

# %%
sum(data["educationfield"].isnull())
# Out:
# 774

# %%
sum(data["educationfield"].isnull())

# %%
data.select_dtypes(include=['int', 'float'])
# Out:
#         dailyrate  distancefromhome  education  employeecount  employeenumber  \
# 0     2015.722222                 6          3              1               1
# 1     2063.388889                 1          4              1               2
# 2     1984.253968                 4          2              1               3
# 3     1771.404762                 2          4              1               4
# 4     1582.771346                 3          3              1               5
# ...           ...               ...        ...            ...             ...
# 1673   488.944444               -26          3              1             824
# 1674  1973.984127                26          4              1            1087
# 1675   290.035510                15          3              1             528
# 1676  1032.487286                 4          3              1              76
# 1677   556.256661                 2          2              1             401
#
# ...

# %%
data["joblevel"].value_counts()
# Out:
# joblevel
# 2    618
# 1    612
# 3    255
# 4    114
# 5     79
# Name: count, dtype: int64

# %%
data["jobrole"].value_counts()
# Out:
# jobrole
# mANager                    5
# ManagEr                    3
# mAnageR                    3
# maNaGeR                    3
# MANAgER                    3
#                           ..
# RESeaRCh sCientIsT         1
# reseARCH sCIEntiST         1
# REseaRCh SCiENTIst         1
# LabOrATory TEChNICiaN      1
# mAnUfactURInG DiRECTOr     1
# Name: count, Length: 1579, dtype: int64

# %%
list(data["jobrole"].unique())
# Out:
# [' resEArch DIREcToR ',
#  ' ManAGeR ',
#  ' ManaGER ',
#  ' ReseArCH DIrECtOr ',
#  ' sAleS EXECUtIve ',
#  ' MANAger ',
#  ' Sales ExeCutIVe ',
#  ' Sales eXEcUTiVe ',
#  ' mANAGEr ',
#  ' reSEaRCH DIrectoR ',
#  ' RESeArcH DIrEctoR ',
#  ' MANUfACturing DIReCtOr ',
#  ' REseaRCh dirEcToR ',
#  ' reseARCh DIrEctoR ',
#  ' RESeaRCH dirEctor ',
#  ' MAnAgeR ',
#  ' reSeARCh DIrEcToR ',
#  ' MAnaGER ',
#  ' REseArcH sciENtiST ',
#  ' MAnUFaCtUring dIRecTOr ',
#  ' heaLtHcArE repResENtATiVe ',
#  ' RESEARCH dIrECtor ',
#  ' hEaltHCarE ReprESENTAtIvE ',
#  ' maNagEr ',
#  ' SALEs exeCUtIVe ',
#  ' manUfACtURing dirEctOR ',
#  ' mAnageR ',
#  ' MaNufActURing dIrecTOr ',
#  ' laBoratOry tecHNiCiaN ',
#  ' saLEs exEcutIVe ',
#  ' Sales ExECuTIVe ',
#  ' heALthCArE RePResEntaTIVe ',
#  ' ManAgER ',
#  ' salEs EXeCUtIvE ',
#  ' rEsEARcH SCIeNTist ',
#  ' SALEs eXECuTive ',
#  ' ManagEr ',
#  ' lABORAtOry tECHnIcIan ',
#  ' Sales exEcUtiVe ',
#  ' saLes eXEcUTIVE ',
# ...

# %%
data[["sameasmonthlyincome", "monthlyincome"]].sample(9)
# Out:
#      sameasmonthlyincome monthlyincome
# 791             4492,84$      4492,84$
# 311             4492,84$      4492,84$
# 1487                 NaN           NaN
# 1454            4492,84$      4492,84$
# 126            12783,92$     12783,92$
# 482                  NaN           NaN
# 424            12783,92$     12783,92$
# 740             4492,84$      4492,84$
# 1061            2424,17$      2424,17$
