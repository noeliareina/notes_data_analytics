# %% [markdown]
# ## Proyecto MusicStream

# %% [markdown]
# Tenemos la API de Spotify y de Last.fm
# Con ello queremos obtener data y crear BBDD con ayuda de Python y SQL
#
# Extraer 5 canciones más populares por lustros desde el año 2000 hasta la actualidad en diferentes zonas de Europa
# y relacionar entre sí canciones y géneros una vez que las bbdd estén exportadas
# a SQL
#
# Los datos que necesitamos son:
# - Zonas geográficas de Europa
# - Rangos de años

# %%
pd.concat([df1, df2], ignore_index=True)

# %%
df = df.replace({float('NaN'): None})
