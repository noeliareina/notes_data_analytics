# %% [markdown]
# # 0. Justificación de uso de Spotify para sacar toptracks.

# %% [markdown]
# # 1. Sacar datos Spotify de 5 años, por países.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '13122d95aee54d2e828fdbc53ab27756'
CLIENT_SECRET = '628a3ebb227a4a46a8cdc6cc44327ee6'
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
paises_este_europa = {
    "BY": "Bielorrusia",
    "BG": "Bulgaria",
    "CZ": "Chequia",
    "SK": "Eslovaquia",
    "HU": "Hungría",
    "MD": "Moldavia",
    "PL": "Polonia",
    "RO": "Rumanía",
    "UA": "Ucrania"}

# %%
#datos_rango = sp.search(q = "year:2020-2024", limit=50, offset=0, type='track', market="ES")

# %%
def extraccion_por_paises(diccionario_zonas, años):
    todos_los_datos = [] # Esto es una lista de dicts donde se van guardando los diccionarios de cada país
    for pais in diccionario_zonas.keys():
        datos_rango = sp.search(q = f'year:{años}', limit=50, offset=0, type='track', market={pais}) # Cada una tiene que cambiar en q el rango de años
        datos_por_pais = {}
        datos_por_pais['pais'] = pais
        datos_por_pais['datos'] = datos_rango
        todos_los_datos.append(datos_por_pais)
    return todos_los_datos

# %%
lista_datos_zonas = extraccion_por_paises(paises_este_europa, "2020-2024")

# %%
for element in lista_datos_zonas:
    print(element)
# Out:
# {'pais': 'BY', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=BY', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 48, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'}, 'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY', 'id': '1oSPZhvZMIrWW5I41kPkkY', 'name': 'Jimin', 'type': 'artist', 'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'}, 'href': 'https://api.spotify.com/v1/albums/15XcLhiVMlSOipUddTNDnr', 'id': '15XcLhiVMlSOipUddTNDnr', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f02c451189a709b9a952aaec'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f02c451189a709b9a952aaec'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f02c451189a709b9a952aaec'}], 'is_playable': True, 'name': 'MUSE', 'release_date': '2024-07-19', 'release_date_precision': 'day', 'total_tracks': 7, 'type': 'album', 'uri': 'spotify:album:15XcLhiVMlSOipUddTNDnr'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'}, 'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY', 'id': '1oSPZhvZMIrWW5I41kPkkY', 'name': 'Jimin', 'type': 'artist', 'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}], 'disc_number': 1, 'duration_ms': 170887, 'explicit': False, 'external_ids': {'isrc': 'USA2P2431062'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU'}, 'href': 'https://api.spotify.com/v1/tracks/7tI8dRuH2Yc6RuoTjxo4dU', 'id': '7tI8dRuH2Yc6RuoTjxo4dU', 'is_local': False, 'is_playable': True, 'name': 'Who', 'popularity': 86, 'preview_url': None, 'track_number': 6, 'type': 'track', 'uri': 'spotify:track:7tI8dRuH2Yc6RuoTjxo4dU'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6cX9Qyl1Ug5lli2y2yBm52'}, 'href': 'https://api.spotify.com/v1/artists/6cX9Qyl1Ug5lli2y2yBm52', 'id': '6cX9Qyl1Ug5lli2y2yBm52', 'name': 'Fiorella', 'type': 'artist', 'uri': 'spotify:artist:6cX9Qyl1Ug5lli2y2yBm52'}], 'disc_number': 1, 'duration_ms': 183808, 'explicit': False, 'external_ids': {'isrc': 'BKN242400085'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/07K2sgnL5mV2itmVMmFzmq'}, 'href': 'https://api.spotify.com/v1/tracks/07K2sgnL5mV2itmVMmFzmq', 'id': '07K2sgnL5mV2itmVMmFzmq', 'is_local': False, 'is_playable': False, 'name': 'Seu Astral / Mistérios', 'popularity': 11, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:07K2sgnL5mV2itmVMmFzmq'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'}, 'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY', 'id': '1oSPZhvZMIrWW5I41kPkkY', 'name': 'Jimin', 'type': 'artist', 'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4wfwJUghbK2z2iaz65U7VS'}, 'href': 'https://api.spotify.com/v1/albums/4wfwJUghbK2z2iaz65U7VS', 'id': '4wfwJUghbK2z2iaz65U7VS', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382601539d4a27061ad90eacb'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282601539d4a27061ad90eacb'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182601539d4a27061ad90eacb'}], 'is_playable': True, 'name': 'MUSE (WANDER ver.)', 'release_date': ' ...
# {'pais': 'BG', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=BG', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=BG', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vczAVLBVJzhMndKRCsQls'}, 'href': 'https://api.spotify.com/v1/artists/4vczAVLBVJzhMndKRCsQls', 'id': '4vczAVLBVJzhMndKRCsQls', 'name': 'Djordan', 'type': 'artist', 'uri': 'spotify:artist:4vczAVLBVJzhMndKRCsQls'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/5VBSe7KYebMlPsrDoETNul'}, 'href': 'https://api.spotify.com/v1/albums/5VBSe7KYebMlPsrDoETNul', 'id': '5VBSe7KYebMlPsrDoETNul', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27375085a0ce793b5594287a3ca'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0275085a0ce793b5594287a3ca'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485175085a0ce793b5594287a3ca'}], 'is_playable': True, 'name': 'Мераклия', 'release_date': '2024-12-15', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:5VBSe7KYebMlPsrDoETNul'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vczAVLBVJzhMndKRCsQls'}, 'href': 'https://api.spotify.com/v1/artists/4vczAVLBVJzhMndKRCsQls', 'id': '4vczAVLBVJzhMndKRCsQls', 'name': 'Djordan', 'type': 'artist', 'uri': 'spotify:artist:4vczAVLBVJzhMndKRCsQls'}], 'disc_number': 1, 'duration_ms': 188780, 'explicit': False, 'external_ids': {'isrc': 'BGA261584299'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0b2D7UMjaaIYJndNYBbdRU'}, 'href': 'https://api.spotify.com/v1/tracks/0b2D7UMjaaIYJndNYBbdRU', 'id': '0b2D7UMjaaIYJndNYBbdRU', 'is_local': False, 'is_playable': True, 'name': 'Мераклия', 'popularity': 47, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:0b2D7UMjaaIYJndNYBbdRU'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4AZihrM3P96d5mA9kvsxxH'}, 'href': 'https://api.spotify.com/v1/artists/4AZihrM3P96d5mA9kvsxxH', 'id': '4AZihrM3P96d5mA9kvsxxH', 'name': 'Tsvetelina Yaneva', 'type': 'artist', 'uri': 'spotify:artist:4AZihrM3P96d5mA9kvsxxH'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/2wiHKbihm8cm4UTRebBDaE'}, 'href': 'https://api.spotify.com/v1/albums/2wiHKbihm8cm4UTRebBDaE', 'id': '2wiHKbihm8cm4UTRebBDaE', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273599b71922c325d649a5058b2'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02599b71922c325d649a5058b2'}, {'height': 64, 'widt ...
# {'pais': 'CZ', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=CZ', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=CZ', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lEkQtWa3UKlI1hj7sktcd'}, 'href': 'https://api.spotify.com/v1/artists/5lEkQtWa3UKlI1hj7sktcd', 'id': '5lEkQtWa3UKlI1hj7sktcd', 'name': 'Calin', 'type': 'artist', 'uri': 'spotify:artist:5lEkQtWa3UKlI1hj7sktcd'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/5MlxIyYE1oUZg9bp1vXI52'}, 'href': 'https://api.spotify.com/v1/albums/5MlxIyYE1oUZg9bp1vXI52', 'id': '5MlxIyYE1oUZg9bp1vXI52', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f8708b8bd19b830f30ac6516'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f8708b8bd19b830f30ac6516'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f8708b8bd19b830f30ac6516'}], 'is_playable': True, 'name': 'Bieber Fever Tour Life', 'release_date': '2024-12-06', 'release_date_precision': 'day', 'total_tracks': 8, 'type': 'album', 'uri': 'spotify:album:5MlxIyYE1oUZg9bp1vXI52'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lEkQtWa3UKlI1hj7sktcd'}, 'href': 'https://api.spotify.com/v1/artists/5lEkQtWa3UKlI1hj7sktcd', 'id': '5lEkQtWa3UKlI1hj7sktcd', 'name': 'Calin', 'type': 'artist', 'uri': 'spotify:artist:5lEkQtWa3UKlI1hj7sktcd'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZHJEckf6HJXMSuD2icSSW'}, 'href': 'https://api.spotify.com/v1/artists/2ZHJEckf6HJXMSuD2icSSW', 'id': '2ZHJEckf6HJXMSuD2icSSW', 'name': 'Sofian Medjmedj', 'type': 'artist', 'uri': 'spotify:artist:2ZHJEckf6HJXMSuD2icSSW'}], 'disc_number': 1, 'duration_ms': 174117, 'explicit': True, 'external_ids': {'isrc': 'CZA232401129'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5LG6E6hwx6u84X7hMVkpKp'}, 'href': 'https://api.spotify.com/v1/tracks/5LG6E6hwx6u84X7hMVkpKp', 'id': '5LG6E6hwx6u84X7hMVkpKp', 'is_local': False, 'is_playable': True, 'name': 'Pistácie (feat. Sofian Medjmedj)', 'popularity': 64, 'preview_url': None, 'track_number': 7, 'type': 'track', 'uri': 'spotify:track:5LG6E6hwx6u84X7hMVkpKp'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'}, 'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ', 'id': '5Pwc4xIPtQLFEnJriah9YJ', 'name': 'OneRepublic', 'type': 'artist', 'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}], 'disc_number': 1, 'duration_ms': 165965, 'explicit': False, 'external_ids': {'isrc': 'USUV72404416'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5UwsOLn7un3PbIh6N2T5X9'}, 'href': 'https://api.spotify.com/v1/tracks/5UwsOLn7un3PbIh6N2T5X9', 'id': '5UwsOLn7un3PbIh6N2T5X9', 'is_local': False, 'is_playable': False, 'name': 'Hurt', 'popularity': 12, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5UwsOLn7un3PbIh6N2T5X9'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lEkQtWa3UKlI1hj7sktcd'}, 'href': 'https://api.spotify.com/v1/artists/5lEkQtWa3UKlI1hj7sktcd', 'id': '5lEkQtWa3UKlI1hj7sktcd', 'name': 'Calin', 'type': 'artist', 'uri': 'spotify:artist:5lEkQtWa3UKlI1hj7sktcd'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/5MlxIyYE1oUZg9bp1vXI52'}, 'href': 'https://api.spotify.com/v1/albums/5MlxIyYE1oUZg9bp1vXI52', 'id': '5MlxIyYE1o ...
# {'pais': 'SK', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=SK', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=SK', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lEkQtWa3UKlI1hj7sktcd'}, 'href': 'https://api.spotify.com/v1/artists/5lEkQtWa3UKlI1hj7sktcd', 'id': '5lEkQtWa3UKlI1hj7sktcd', 'name': 'Calin', 'type': 'artist', 'uri': 'spotify:artist:5lEkQtWa3UKlI1hj7sktcd'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/5MlxIyYE1oUZg9bp1vXI52'}, 'href': 'https://api.spotify.com/v1/albums/5MlxIyYE1oUZg9bp1vXI52', 'id': '5MlxIyYE1oUZg9bp1vXI52', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273f8708b8bd19b830f30ac6516'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02f8708b8bd19b830f30ac6516'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851f8708b8bd19b830f30ac6516'}], 'is_playable': True, 'name': 'Bieber Fever Tour Life', 'release_date': '2024-12-06', 'release_date_precision': 'day', 'total_tracks': 8, 'type': 'album', 'uri': 'spotify:album:5MlxIyYE1oUZg9bp1vXI52'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lEkQtWa3UKlI1hj7sktcd'}, 'href': 'https://api.spotify.com/v1/artists/5lEkQtWa3UKlI1hj7sktcd', 'id': '5lEkQtWa3UKlI1hj7sktcd', 'name': 'Calin', 'type': 'artist', 'uri': 'spotify:artist:5lEkQtWa3UKlI1hj7sktcd'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZHJEckf6HJXMSuD2icSSW'}, 'href': 'https://api.spotify.com/v1/artists/2ZHJEckf6HJXMSuD2icSSW', 'id': '2ZHJEckf6HJXMSuD2icSSW', 'name': 'Sofian Medjmedj', 'type': 'artist', 'uri': 'spotify:artist:2ZHJEckf6HJXMSuD2icSSW'}], 'disc_number': 1, 'duration_ms': 174117, 'explicit': True, 'external_ids': {'isrc': 'CZA232401129'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5LG6E6hwx6u84X7hMVkpKp'}, 'href': 'https://api.spotify.com/v1/tracks/5LG6E6hwx6u84X7hMVkpKp', 'id': '5LG6E6hwx6u84X7hMVkpKp', 'is_local': False, 'is_playable': True, 'name': 'Pistácie (feat. Sofian Medjmedj)', 'popularity': 64, 'preview_url': None, 'track_number': 7, 'type': 'track', 'uri': 'spotify:track:5LG6E6hwx6u84X7hMVkpKp'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'}, 'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ', 'id': '5Pwc4xIPtQLFEnJriah9YJ', 'name': 'OneRepublic', 'type': 'artist', 'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}], 'disc_number': 1, 'duration_ms': 165965, 'explicit': False, 'external_ids': {'isrc': 'USUV72404416'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5UwsOLn7un3PbIh6N2T5X9'}, 'href': 'https://api.spotify.com/v1/tracks/5UwsOLn7un3PbIh6N2T5X9', 'id': '5UwsOLn7un3PbIh6N2T5X9', 'is_local': False, 'is_playable': False, 'name': 'Hurt', 'popularity': 12, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5UwsOLn7un3PbIh6N2T5X9'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du ...
# {'pais': 'HU', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=HU', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=HU', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dqqy9z09htrVsRiJpoQmw'}, 'href': 'https://api.spotify.com/v1/artists/4dqqy9z09htrVsRiJpoQmw', 'id': '4dqqy9z09htrVsRiJpoQmw', 'name': 'DESH', 'type': 'artist', 'uri': 'spotify:artist:4dqqy9z09htrVsRiJpoQmw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zmW213tzA7NFv6ESRso7N'}, 'href': 'https://api.spotify.com/v1/artists/0zmW213tzA7NFv6ESRso7N', 'id': '0zmW213tzA7NFv6ESRso7N', 'name': 'Young Fly', 'type': 'artist', 'uri': 'spotify:artist:0zmW213tzA7NFv6ESRso7N'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/0rxSEyr7JxVRxuUMtZ5eRT'}, 'href': 'https://api.spotify.com/v1/albums/0rxSEyr7JxVRxuUMtZ5eRT', 'id': '0rxSEyr7JxVRxuUMtZ5eRT', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273e8dd596aa0cf567d4e3a85b1'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02e8dd596aa0cf567d4e3a85b1'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851e8dd596aa0cf567d4e3a85b1'}], 'is_playable': True, 'name': 'BAKPAKK', 'release_date': '2024-07-26', 'release_date_precision': 'day', 'total_tracks': 5, 'type': 'album', 'uri': 'spotify:album:0rxSEyr7JxVRxuUMtZ5eRT'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dqqy9z09htrVsRiJpoQmw'}, 'href': 'https://api.spotify.com/v1/artists/4dqqy9z09htrVsRiJpoQmw', 'id': '4dqqy9z09htrVsRiJpoQmw', 'name': 'DESH', 'type': 'artist', 'uri': 'spotify:artist:4dqqy9z09htrVsRiJpoQmw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zmW213tzA7NFv6ESRso7N'}, 'href': 'https://api.spotify.com/v1/artists/0zmW213tzA7NFv6ESRso7N', 'id': '0zmW213tzA7NFv6ESRso7N', 'name': 'Young Fly', 'type': 'artist', 'uri': 'spotify:artist:0zmW213tzA7NFv6ESRso7N'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6EIriUxo7vznEgJtTDlXpq'}, 'href': 'https://api.spotify.com/v1/artists/6EIriUxo7vznEgJtTDlXpq', 'id': '6EIriUxo7vznEgJtTDlXpq', 'name': 'Azahriah', 'type': 'artist', 'uri': 'spotify:artist:6EIriUxo7vznEgJtTDlXpq'}], 'disc_number': 1, 'duration_ms': 147120, 'explicit': False, 'external_ids': {'isrc': 'HUAMV2100292'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5v1qS9RS2g42zeXHevEdYn'}, 'href': 'https://api.spotify.com/v1/tracks/5v1qS9RS2g42zeXHevEdYn', 'id': '5v1qS9RS2g42zeXHevEdYn', 'is_local': False, 'is_playable': True, 'name': 'PANNONIA', 'popularity': 55, 'preview_url': None, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:5v1qS9RS2g42zeXHevEdYn'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'ty ...
# {'pais': 'MD', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=MD', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 49, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}, 'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N', 'id': '10FLjwfpbxLmW8c25Xyc2N', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}], 'is_playable': True, 'name': 'Die With A Smile', 'release_date': '2024-08-16', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'disc_number': 1, 'duration_ms': 251667, 'explicit': False, 'external_ids': {'isrc': 'USUM72409273'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'}, 'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe', 'id': '2plbrEY59IikOBgBGLjaoe', 'is_local': False, 'is_playable': True, 'name': 'Die With A Smile', 'popularity': 96, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vvLuXEEf7sl3izJcw0GIn'}, 'href': 'https://api.spotify.com/v1/artists/3vvLuXEEf7sl3izJcw0GIn', 'id': '3vvLuXEEf7sl3izJcw0GIn', 'name': 'Skryptonite', 'type': 'artist', 'uri ...
# {'pais': 'PL', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=PL', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=PL', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56VhOZOF6hwqrbNYwkmcsH'}, 'href': 'https://api.spotify.com/v1/artists/56VhOZOF6hwqrbNYwkmcsH', 'id': '56VhOZOF6hwqrbNYwkmcsH', 'name': 'Sobel', 'type': 'artist', 'uri': 'spotify:artist:56VhOZOF6hwqrbNYwkmcsH'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6HdxibJzoNkDUUDHagx3Ko'}, 'href': 'https://api.spotify.com/v1/artists/6HdxibJzoNkDUUDHagx3Ko', 'id': '6HdxibJzoNkDUUDHagx3Ko', 'name': 'francis', 'type': 'artist', 'uri': 'spotify:artist:6HdxibJzoNkDUUDHagx3Ko'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3gm9b6AeMf2eGQTLashkDt'}, 'href': 'https://api.spotify.com/v1/artists/3gm9b6AeMf2eGQTLashkDt', 'id': '3gm9b6AeMf2eGQTLashkDt', 'name': 'Deemz', 'type': 'artist', 'uri': 'spotify:artist:3gm9b6AeMf2eGQTLashkDt'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/41oKsyCDiyUxtWX2GL1ptR'}, 'href': 'https://api.spotify.com/v1/albums/41oKsyCDiyUxtWX2GL1ptR', 'id': '41oKsyCDiyUxtWX2GL1ptR', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d4e7bed1ac12d257ffa21485'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d4e7bed1ac12d257ffa21485'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d4e7bed1ac12d257ffa21485'}], 'is_playable': True, 'name': 'KOCHASZ?', 'release_date': '2024-12-26', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:41oKsyCDiyUxtWX2GL1ptR'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56VhOZOF6hwqrbNYwkmcsH'}, 'href': 'https://api.spotify.com/v1/artists/56VhOZOF6hwqrbNYwkmcsH', 'id': '56VhOZOF6hwqrbNYwkmcsH', 'name': 'Sobel', 'type': 'artist', 'uri': 'spotify:artist:56VhOZOF6hwqrbNYwkmcsH'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6HdxibJzoNkDUUDHagx3Ko'}, 'href': 'https://api.spotify.com/v1/artists/6HdxibJzoNkDUUDHagx3Ko', 'id': '6HdxibJzoNkDUUDHagx3Ko', 'name': 'francis', 'type': 'artist', 'uri': 'spotify:artist:6HdxibJzoNkDUUDHagx3Ko'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3gm9b6AeMf2eGQTLashkDt'}, 'href': 'https://api.spotify.com/v1/artists/3gm9b6AeMf2eGQTLashkDt', 'id': '3gm9b6AeMf2eGQTLashkDt', 'name': 'Deemz', 'type': 'artist', 'uri': 'spotify:artist:3gm9b6AeMf2eGQTLashkDt'}], 'disc_number': 1, 'duration_ms': 152386, 'explicit': False, 'external_ids': {'isrc': 'PLUM72400642'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/1d718gwJbujwNO9x9BzNfc'}, 'href': 'https://api.spotify.com/v1/tracks/1d718gwJbujwNO9x9BzNfc', 'id': '1d718gwJbujwNO9x9BzNfc', 'is_local': False, 'is_playable': True, 'name': 'KOCHASZ?', 'popularity': 68, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:1d718gwJbujwNO9x9BzNfc'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GqZI2mcDNtrVB8pRP61Tu'}, 'href': 'https://api.spotify.com/v1/artists/3GqZI2mcDNtrVB8pRP61Tu', 'id': '3GqZI2mcDNtrVB8pRP61Tu', 'name': 'Lemon', 'type': 'artist', 'uri': 'spotify:artist:3GqZI2mcDNtrVB8pRP61Tu'}], 'disc_number': 1, 'duration_ms': 306048, 'explicit': False, 'external_ids': {'isrc': 'PLA582300049'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/39TZ1ud5m7xO1C8PRquYLs'}, ...
# {'pais': 'RO', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=RO', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=RO', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/60KR2lVVoYd6GIcfLoUjPI'}, 'href': 'https://api.spotify.com/v1/artists/60KR2lVVoYd6GIcfLoUjPI', 'id': '60KR2lVVoYd6GIcfLoUjPI', 'name': 'Dani Mocanu', 'type': 'artist', 'uri': 'spotify:artist:60KR2lVVoYd6GIcfLoUjPI'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6HYk4ydfuVNkTLVq5eILau'}, 'href': 'https://api.spotify.com/v1/albums/6HYk4ydfuVNkTLVq5eILau', 'id': '6HYk4ydfuVNkTLVq5eILau', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273c91534ffb3598ff5fd5bdac0'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02c91534ffb3598ff5fd5bdac0'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851c91534ffb3598ff5fd5bdac0'}], 'is_playable': True, 'name': 'Vino să te f', 'release_date': '2024-12-14', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:6HYk4ydfuVNkTLVq5eILau'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/60KR2lVVoYd6GIcfLoUjPI'}, 'href': 'https://api.spotify.com/v1/artists/60KR2lVVoYd6GIcfLoUjPI', 'id': '60KR2lVVoYd6GIcfLoUjPI', 'name': 'Dani Mocanu', 'type': 'artist', 'uri': 'spotify:artist:60KR2lVVoYd6GIcfLoUjPI'}], 'disc_number': 1, 'duration_ms': 180393, 'explicit': False, 'external_ids': {'isrc': 'ROGRA2400747'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2AKfAnct7MFEglIueZ7ROM'}, 'href': 'https://api.spotify.com/v1/tracks/2AKfAnct7MFEglIueZ7ROM', 'id': '2AKfAnct7MFEglIueZ7ROM', 'is_local': False, 'is_playable': True, 'name': 'Vino să te f', 'popularity': 57, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2AKfAnct7MFEglIueZ7ROM'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5h0wBmd25qPcGSInl3dp66'}, 'href': 'https://api.spotify.com/v1/artists/5h0wBmd25qPcGSInl3dp66', 'id': '5h0wBmd25qPcGSInl3dp66', 'name': 'Tzanca Uraganu', 'type': 'artist', 'uri': 'spotify:artist:5h0wBmd25qPcGSInl3dp66'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/7nAYBo6ma8p4sGj9cig5Bb'}, 'href': 'https://api.spotify.com/v1/albums/7nAYBo6ma8p4sGj9cig5Bb', 'id': '7nAYBo6ma8p4sGj9cig5Bb', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2730267902299004ae7bb4336d5'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e020267902299004ae7bb4336d5'}, {'heigh ...
# {'pais': 'UA', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=UA', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 49, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4anb8rmk0xipuQP6QZ5IlH'}, 'href': 'https://api.spotify.com/v1/artists/4anb8rmk0xipuQP6QZ5IlH', 'id': '4anb8rmk0xipuQP6QZ5IlH', 'name': 'FORTUNA 812', 'type': 'artist', 'uri': 'spotify:artist:4anb8rmk0xipuQP6QZ5IlH'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/60Evg5wOVFEI0PH4XKersZ'}, 'href': 'https://api.spotify.com/v1/albums/60Evg5wOVFEI0PH4XKersZ', 'id': '60Evg5wOVFEI0PH4XKersZ', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27358cd5ffa7e7ef0329e00de7f'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0258cd5ffa7e7ef0329e00de7f'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485158cd5ffa7e7ef0329e00de7f'}], 'is_playable': True, 'name': 'ParisLove', 'release_date': '2024-11-08', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:60Evg5wOVFEI0PH4XKersZ'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4anb8rmk0xipuQP6QZ5IlH'}, 'href': 'https://api.spotify.com/v1/artists/4anb8rmk0xipuQP6QZ5IlH', 'id': '4anb8rmk0xipuQP6QZ5IlH', 'name': 'FORTUNA 812', 'type': 'artist', 'uri': 'spotify:artist:4anb8rmk0xipuQP6QZ5IlH'}], 'disc_number': 1, 'duration_ms': 109870, 'explicit': True, 'external_ids': {'isrc': 'DGA0Q2446622'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6zECxDYlNtEybq8hZ9Tp12'}, 'href': 'https://api.spotify.com/v1/tracks/6zECxDYlNtEybq8hZ9Tp12', 'id': '6zECxDYlNtEybq8hZ9Tp12', 'is_local': False, 'is_playable': True, 'name': 'ParisLove', 'popularity': 62, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6zECxDYlNtEybq8hZ9Tp12'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vx5nhHgobaaaRSHM9ZN1R'}, 'href': 'https://api.spotify.com/v1/artists/6vx5nhHgobaaaRSHM9ZN1R', 'id': '6vx5nhHgobaaaRSHM9ZN1R', 'name': 'Тоня Матвієнко', 'type': 'artist', 'uri': 'spotify:artist:6vx5nhHgobaaaRSHM9ZN1R'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4E15bK5N42WiJElQc7ozM2'}, 'href': 'https://api.spotify.com/v1/albums/4E15bK5N42WiJElQc7ozM2', 'id': '4E15bK5N42WiJElQc7ozM2', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ae08bc96b3a25899a1f6302d'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ae08bc96b3a25899a1f6302d'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ae08bc96b3a25899a1f6302d'}], 'is_p ...

# %% [markdown]
# ## 1.1. Filtrar ahora los datos que hemos sacado

# %%
# Un intento de función con el bucle de arriba:

# %%
def filtro_de_datos(lista_datos_zonas, datos):
    for datos_pais in lista_datos_zonas:
            for element in datos_pais['datos']['tracks']['items']:
                datos['pais'].append(datos_pais['pais'])
                datos['popularity'].append(element['popularity'])
                datos['nombre'].append(element['name'])
                
                artistas = []
                for artista in element['artists']:
                    artistas.append(artista['name'])   
                artistas_str = ', '.join(artistas)
                datos['artista'].append(artistas_str)

# %%
ext_este= extraccion_por_paises(paises_este_europa, '2020-2024')

# %%
dic_este = {'nombre': [], 'popularity': [], 'artista': [], 'pais': [], 'genero': []}

# %%
filtro_de_datos(ext_este, dic_este)

# %%
dic_este
# Out:
# {'nombre': ['Who',
#   'Seu Astral / Mistérios',
#   'Who',
#   'Tussi Code Mari',
#   'ParisLove',
#   'Das riecht gut / Ça Sent Bon',
#   'Who',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Who',
#   'Party Jumpin’',
#   'Winter Ahead (with PARK HYO SHIN)',
#   'Cono Hielo',
#   'гладиатор/рыцарь',
#   'Casino',
#   'DUMBAI',
#   'Winter Ahead (with PARK HYO SHIN)',
#   'Pode Ir Embora / Vagalumes / Trânsito Parado',
#   'Winter Ahead (with PARK HYO SHIN)',
#   'Na Nossa Sala / Amor e Amor - Ao Vivo',
#   'Who (Rock Remix)',
#   'Vamos Fugir / Aqui É O Seu Lugar',
#   'мило материшься',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Гектор',
#   'Leilão / Palpite / O Amor Não Deixa',
#   'Lost Angeles',
#   'Postcards - Acoustic Version',
#   'Turbo (Majestic)',
#   'BABY GANGSTA',
#   'Контракт',
#   'LEDI',
#   'Последняя Любовь',
#   'Por Ti / Sou Fã',
#   'ALASKA PUFFER',
#   'Outro Estado',
#   'Be Mine',
#   'Jogado Na Rua / Velha Infância / Seu Polícia',
#   'Amsterdam',
#   'Me Apego / Prisão Sem Grade / Lendas e Mistérios',
#   'Страшный сон 2',
#   'FRI(END)S',
#   'Schifoan',
#   'Be Mine',
#   'Ghosts / Slowing Down',
#   'Фото со звездой',
#   'ILMSY (MOVES)',
#   'Адская колыбельная',
#   'Peder Elias/吴宇恒《First Flight》Special Video',
#   'Мераклия',
#   'That’s So True - Live From Radio City Music Hall',
#   'Питаш ли ме',
#   'Hurt',
#   'Mazalyak',
#   'Rodeo (Remix)',
#   'Уау',
#   'Circles',
#   'Die With A Smile',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Mi Amor',
#   "Don't Play by the Rules",
#   'Окадар',
#   'Vivien',
#   'Дум Так',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Чалга',
#   'Rid Of Me - Live',
#   'AMG Isteria',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Who',
#   'Linger - Live On The Voice Australia 2024',
#   'Timeless (feat. Playboi Carti)',
#   'Passenger Princess',
#   'Откачила',
#   'Das riecht gut / Ça Sent Bon',
#   'Бом, Бом',
#   'Ferrari (feat. Luciano)',
#   'Снайпера',
#   'EA2 (The Beginning of the Era)',
#   'BIRDS OF A FEATHER',
#   'Riches Wii a Pree',
#   'Not Like Us',
#   'Она любила музыку',
#   'Влака',
#   'Last Night In Kingston',
#   'tv off (feat. lefty gunplay)',
#   'All We Got (feat. KIDDO)',
#   'Пуши, пуши',
#   'Bank of Wildflowers (feat. Georgia)',
#   'Рупе Рупе',
#   'Party Jumpin’',
#   'Мания',
#   'Standard',
#   'Зиг-заг',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Филм за нас',
#   'Сиромах',
#   'APT.',
#   'ILMSY (MOVES)',
#   'Pistácie (feat. Sofian Medjmedj)',
#   'Hurt',
#   'Vítej mezi náma (feat. STEIN27)',
#   'That’s So True - Live From Radio City Music Hall',
#   'Syndrom',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Cígo a káva (feat. Saul)',
#   'All We Got (feat. KIDDO)',
#   'KSN',
#   'Circles',
#   'Die With A Smile',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Sailor Song',
#   'Family Feud - Live at The Ford',
#   'That’s So True',
#   "Don't Play by the Rules",
#   'Pátky',
#   'Armáda Lásky',
#   'BIRDS OF A FEATHER',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Roleplay',
#   'Party Jumpin’',
#   'Mentira Estampada',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Safír',
#   'Rodeo (Remix)',
#   'É Que Eu Sofri Demais',
#   'EA2 (The Beginning of the Era)',
#   'Suave',
#   'เพิ่งรู้(Never Knew)',
#   'Ohnivej kruh',
#   'Passenger Princess',
#   'APT.',
#   'Playa (feat. Ella Bands)',
#   'Painkillers',
#   'Last Night In Kingston',
#   'Uma e Quinze da Manhã',
#   'Full Round Table',
#   'Brick na brick',
#   'Little Window - Live Studio Session',
#   'Převlečená žízeň',
#   'My Blood',
#   'Pro štěstí',
#   'Postcards - Acoustic Version',
#   'V Hlavě',
#   '2001 // Life Is Yours - The Colour Wheel Session , London 2022',
#   'omluva',
#   'Vivien',
#   'The Days - NOTION Remix',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Pistácie (feat. Sofian Medjmedj)',
#   'Hurt',
#   'Die With A Smile',
#   'Circles',
#   'Cígo a káva (feat. Saul)',
#   'That’s So True - Live From Radio City Music Hall',
#   'Painkillers',
#   'All We Got (feat. KIDDO)',
#   'BIRDS OF A FEATHER',
#   'Babylon - Live',
#   'Syndrom',
#   'Passenger Princess',
#   'Vítej mezi náma (feat. STEIN27)',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'APT.',
#   'Little Window - Live Studio Session',
#   'NENI STRE$S',
#   'Aimer à moitié',
#   'Sailor Song',
#   'Swimming with Sharks',
#   'That’s So True',
#   'THE DINER - ISOLATED VOCALS/Visualizer',
#   'Not Like Us',
#   "rollin'",
#   'Iné Plemená',
#   'Silverlines Orchestral Version',
#   'Bbejbb',
#   'เปล่าหวง (Jealous)',
#   'KSN',
#   "อย่างที่ฉันนั้นเป็นของเธอ (I'm Yours)",
#   'AM4',
#   '2001 // Life Is Yours - The Colour Wheel Session , London 2022',
#   'Biely šum na spanie',
#   "Don't Play by the Rules",
#   'Safír',
#   'Rodeo (Remix)',
#   '7DIGITS',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Clean Baby Sleep White Noise (Loopable)',
#   'EA2 (The Beginning of the Era)',
#   'Timeless (feat. Playboi Carti)',
#   'Vivien',
#   'The Days - NOTION Remix',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Sunset',
#   'Elixir',
#   'Suave',
#   'Party Jumpin’',
#   'I Got It (feat. Shimmi)',
#   'Мотыльки',
#   'PANNONIA',
#   'That’s So True - Live From Radio City Music Hall',
#   'SUV',
#   'All We Got (feat. KIDDO)',
#   'MOKKA',
#   'Hurt',
#   'Die With A Smile',
#   'Circles',
#   'Passport',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'díva',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'VIDÉKI CSAJSZI',
#   'Rodeo (Remix)',
#   'Úgy Hiszem',
#   "Don't Play by the Rules",
#   'BAKPAKK',
#   'Passenger Princess',
#   'Lidokain',
#   'Babylon - Live',
#   'Not Like Us',
#   'Swimming with Sharks',
#   'Strawberry',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'That’s So True',
#   'EA2 (The Beginning of the Era)',
#   'EGY/KETTŐ',
#   'Family Feud - Live at The Ford',
#   'BIRDS OF A FEATHER',
#   'crocodile tears',
#   'LEVÉL',
#   '04:30',
#   'APT.',
#   'Vivien',
#   'Mámor',
#   'Little Window - Live Studio Session',
#   'BANDANA',
#   'Party Jumpin’',
#   'Felednéd',
#   'Riches Wii a Pree',
#   'Sailor Song',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Tiara',
#   'Tuck Your Chain',
#   'SANDELA',
#   'Standard',
#   'Afro Beat',
#   'Bank of Wildflowers (feat. Georgia)',
#   'PROSECCO',
#   'Schifoan',
#   'Die With A Smile',
#   'That’s So True - Live From Radio City Music Hall',
#   'не расслабляйся',
#   'Hurt',
#   'Как je',
#   'Seu Astral / Mistérios',
#   'WILDFLOWER',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Патрон',
#   'Circles',
#   'Асфальт',
#   '04:30',
#   'Texture - Remastered',
#   'Tussi Code Mari',
#   'BIRDS OF A FEATHER',
#   'Das riecht gut / Ça Sent Bon',
#   'Not Like Us',
#   'Babylon - Live',
#   'Приятная',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Малиновый рассвет',
#   'Little Window - Live Studio Session',
#   'Есенин',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Timeless (feat. Playboi Carti)',
#   'Rid Of Me - Live',
#   'По весне',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Minor',
#   'Last Night In Kingston',
#   'Amsterdam',
#   "I Ain't Sayin' - Performance",
#   'Харизма',
#   'Party Jumpin’',
#   'Дорога дальняя',
#   'Family Feud - Live at The Ford',
#   'IVL',
#   'Aimer à moitié',
#   'Pentru totdeauna',
#   'Cono Hielo',
#   'Lost Angeles',
#   'Заново',
#   'DUMBAI',
#   'ParisLove',
#   'Pode Ir Embora / Vagalumes / Trânsito Parado',
#   'Спой',
#   'Na Nossa Sala / Amor e Amor - Ao Vivo',
#   'Гектор',
#   'Vamos Fugir / Aqui É O Seu Lugar',
#   'KOCHASZ?',
#   'Dużo Ciebie Mi',
#   'Die With A Smile',
#   'That’s So True - Live From Radio City Music Hall',
#   'Dom Nad Wodą',
#   'All We Got (feat. KIDDO)',
#   'BIRDS OF A FEATHER',
#   'Rodeo (Remix)',
#   'Sophia Loren',
#   'Hurt',
#   'Lloret de Mar',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'APT.',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Wynalazek Filipa Golarza',
#   '僕は頑張るよっ feat. ano',
#   'Pięknie płyniesz',
#   'Circles',
#   'The Days - NOTION Remix',
#   "Don't Play by the Rules",
#   'That’s So True',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Not Like Us',
#   'Passenger Princess',
#   'Good Luck, Babe!',
#   'Party Jumpin’',
#   'Miłość jest ślepa',
#   'One Day - Live',
#   'Sailor Song',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Dom Nad Wodą',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'taki mały ja',
#   'EA2 (The Beginning of the Era)',
#   'Still Into You',
#   'Little Window - Live Studio Session',
#   'CZEMU NIE ŚPISZ?',
#   'Family Feud - Live at The Ford',
#   'Messy',
#   'Vivien',
#   'wszystkie noce są samotne',
#   'Babylon - Live',
#   'Bad Dreams',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'Falochrony',
#   'Do Ciebie mówię (Taste The Beat)',
#   'PRZEKAZ MYŚLI',
#   'Elixir',
#   'NDA',
#   'Bank of Wildflowers (feat. Georgia)',
#   'Vino să te f',
#   'That’s So True - Live From Radio City Music Hall',
#   'Meneaito',
#   'Hurt',
#   'Anglia',
#   'Little Window - Live Studio Session',
#   'Mercedes',
#   'Circles',
#   'Baklava',
#   'All We Got (feat. KIDDO)',
#   'Die With A Smile',
#   'Rodeo (Remix)',
#   'Vreau',
#   'Vivien',
#   'Who',
#   'Passenger Princess',
#   'Hai sa ne iubim ca nemtii',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Rusia',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Spania',
#   'Babylon - Live',
#   'A venit poliția - From "Candidatul perfect" The Movie',
#   'EA2 (The Beginning of the Era)',
#   'Yali, Yali',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Vin Sa Te Fur',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'NUMAI FEMEI',
#   'Love Of Mine',
#   'Sper Ca Esti Bine',
#   "Don't Play by the Rules",
#   'Păi naa',
#   'Playa (feat. Ella Bands)',
#   'Jenifer buci de fier',
#   'Family Feud - Live at The Ford',
#   'El chapo',
#   '04:30',
#   'Diss Music Romania',
#   'Riches Wii a Pree',
#   'Who',
#   'Gyal Dem Time (feat. Teejay)',
#   'Who',
#   'Delli (feat. Adel)',
#   'Who',
#   'Bank of Wildflowers (feat. Georgia)',
#   'REGINA',
#   'Party Jumpin’',
#   'Merhaba (Stil Turcesc)',
#   'Tuck Your Chain',
#   'ParisLove',
#   'That’s So True - Live From Radio City Music Hall',
#   'Кульбаби',
#   'Hurt',
#   'Касета',
#   'Seu Astral / Mistérios',
#   'Die With A Smile',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Не лякай',
#   'Circles',
#   'гладиатор/рыцарь',
#   '04:30',
#   'Силуети',
#   'Tussi Code Mari',
#   'мило материшься',
#   'Das riecht gut / Ça Sent Bon',
#   'Нагадай',
#   'Babylon - Live',
#   'Забий',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Врубай',
#   'Little Window - Live Studio Session',
#   'Молодість',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Lost Angeles',
#   'Rid Of Me - Live',
#   'Як ніколи',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Рана',
#   'Last Night In Kingston',
#   'Їде дах',
#   "I Ain't Sayin' - Performance",
#   'P*RNSTAR',
#   'Party Jumpin’',
#   'BIRDS OF A FEATHER',
#   'Family Feud - Live at The Ford',
#   'Особистий рай',
#   'Aimer à moitié',
#   'А що?',
#   'Cono Hielo',
#   'Контракт',
#   'Casino',
#   'DUMBAI',
#   'Последняя Любовь',
#   'Pode Ir Embora / Vagalumes / Trânsito Parado',
#   'не расслабляйся',
#   'Na Nossa Sala / Amor e Amor - Ao Vivo',
#   'ALASKA PUFFER',
#   'Vamos Fugir / Aqui É O Seu Lugar'],
#  'popularity': [86,
#   11,
#   82,
#   5,
#   62,
#   4,
#   82,
#   3,
#   82,
#   2,
#   81,
#   1,
#   60,
#   58,
#   1,
#   79,
#   1,
#   78,
#   1,
#   68,
#   1,
#   59,
#   1,
#   58,
#   1,
#   59,
#   1,
#   57,
#   1,
#   58,
#   1,
#   58,
#   1,
#   57,
#   1,
#   71,
#   1,
#   57,
#   1,
#   56,
#   76,
#   1,
#   64,
#   0,
#   55,
#   0,
#   55,
#   0,
#   47,
#   20,
#   47,
#   12,
#   46,
#   9,
#   46,
#   7,
#   96,
#   8,
#   45,
#   3,
#   46,
#   1,
#   45,
#   3,
#   44,
#   3,
#   43,
#   3,
#   86,
#   0,
#   87,
#   6,
#   43,
#   4,
#   43,
#   0,
#   42,
#   1,
#   93,
#   0,
#   92,
#   0,
#   41,
#   3,
#   90,
#   14,
#   41,
#   0,
#   42,
#   2,
#   41,
#   6,
#   42,
#   1,
#   41,
#   0,
#   91,
#   0,
#   64,
#   12,
#   60,
#   20,
#   59,
#   8,
#   59,
#   14,
#   58,
#   7,
#   96,
#   3,
#   89,
#   2,
#   91,
#   3,
#   55,
#   0,
#   93,
#   3,
#   55,
#   2,
#   73,
#   3,
#   55,
#   9,
#   73,
#   1,
#   55,
#   0,
#   54,
#   6,
#   91,
#   0,
#   56,
#   3,
#   78,
#   0,
#   54,
#   3,
#   53,
#   0,
#   53,
#   1,
#   53,
#   0,
#   53,
#   1,
#   84,
#   1,
#   64,
#   12,
#   96,
#   7,
#   59,
#   20,
#   56,
#   14,
#   93,
#   4,
#   59,
#   6,
#   60,
#   8,
#   91,
#   3,
#   54,
#   2,
#   89,
#   0,
#   91,
#   0,
#   92,
#   0,
#   54,
#   0,
#   53,
#   0,
#   58,
#   0,
#   49,
#   0,
#   47,
#   3,
#   55,
#   9,
#   47,
#   1,
#   91,
#   1,
#   87,
#   1,
#   84,
#   3,
#   52,
#   1,
#   55,
#   2,
#   49,
#   0,
#   55,
#   20,
#   55,
#   14,
#   55,
#   12,
#   96,
#   7,
#   53,
#   8,
#   53,
#   3,
#   52,
#   9,
#   52,
#   3,
#   52,
#   6,
#   52,
#   4,
#   92,
#   0,
#   52,
#   3,
#   91,
#   1,
#   51,
#   2,
#   93,
#   0,
#   51,
#   7,
#   91,
#   1,
#   50,
#   3,
#   50,
#   2,
#   50,
#   0,
#   89,
#   1,
#   50,
#   0,
#   50,
#   6,
#   50,
#   0,
#   49,
#   1,
#   96,
#   20,
#   60,
#   12,
#   57,
#   11,
#   90,
#   8,
#   60,
#   7,
#   59,
#   7,
#   56,
#   5,
#   93,
#   4,
#   92,
#   4,
#   55,
#   3,
#   57,
#   3,
#   60,
#   3,
#   87,
#   3,
#   55,
#   3,
#   58,
#   3,
#   57,
#   2,
#   56,
#   2,
#   56,
#   2,
#   53,
#   2,
#   47,
#   1,
#   59,
#   51,
#   1,
#   62,
#   1,
#   52,
#   1,
#   58,
#   1,
#   68,
#   4,
#   96,
#   20,
#   65,
#   14,
#   93,
#   9,
#   64,
#   12,
#   64,
#   3,
#   91,
#   8,
#   63,
#   1,
#   63,
#   7,
#   84,
#   3,
#   91,
#   3,
#   92,
#   6,
#   89,
#   2,
#   63,
#   0,
#   89,
#   3,
#   62,
#   3,
#   62,
#   1,
#   75,
#   3,
#   61,
#   2,
#   86,
#   1,
#   61,
#   4,
#   80,
#   1,
#   61,
#   0,
#   61,
#   1,
#   61,
#   0,
#   57,
#   20,
#   56,
#   12,
#   55,
#   3,
#   56,
#   7,
#   56,
#   14,
#   96,
#   9,
#   53,
#   1,
#   86,
#   6,
#   54,
#   8,
#   53,
#   3,
#   53,
#   4,
#   55,
#   1,
#   53,
#   3,
#   52,
#   3,
#   51,
#   0,
#   52,
#   3,
#   53,
#   0,
#   51,
#   2,
#   52,
#   7,
#   51,
#   0,
#   82,
#   0,
#   82,
#   0,
#   82,
#   0,
#   50,
#   2,
#   51,
#   0,
#   62,
#   20,
#   55,
#   12,
#   56,
#   11,
#   96,
#   8,
#   54,
#   7,
#   60,
#   7,
#   56,
#   5,
#   59,
#   4,
#   53,
#   4,
#   53,
#   3,
#   53,
#   3,
#   53,
#   3,
#   59,
#   3,
#   52,
#   3,
#   52,
#   3,
#   51,
#   2,
#   77,
#   2,
#   93,
#   2,
#   51,
#   2,
#   51,
#   1,
#   58,
#   58,
#   1,
#   58,
#   1,
#   60,
#   1,
#   57,
#   1],
#  'artista': ['Jimin',
#   'Fiorella',
#   'Jimin',
#   'Marcianeke, Crismj',
#   'FORTUNA 812',
#   'Team Karacho, Roger Rekless',
#   'Jimin',
#   'Billie Eilish',
#   'Jimin',
#   'Jamie Brown, Marshmello',
#   'V, Park Hyo Shin',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'fallen777angel',
#   'Icegergert',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'V, Park Hyo Shin',
#   'Fiorella',
#   'V, Park Hyo Shin',
#   'Rodriguinho, Gaab, Mr. Dan',
#   'Jimin',
#   'Fiorella',
#   'volhey',
#   'Lola Young',
#   'Icegergert',
#   'Fiorella',
#   'FRIENDLY THUG 52 NGG',
#   'Mackenzy Mackay',
#   'Big Baby Tape',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'Poshlaya Molly',
#   'Robot95, DJ Maff',
#   'MORGENSHTERN',
#   'Fiorella',
#   'паранойя',
#   'Fiorella, Hugo Henrique',
#   'Jimin',
#   'Fiorella',
#   'Icegergert',
#   'Fiorella',
#   'Раковая Выхухоль',
#   'V',
#   'Felix Harrer, Leopold Franz',
#   'Jimin',
#   'Scarlet House',
#   'Lida',
#   'Rotimi',
#   'Poshlaya Molly',
#   'Peder Elias, 吴宇恒',
#   'Djordan',
#   'Gracie Abrams',
#   'Tsvetelina Yaneva',
#   'OneRepublic',
#   'Emanuela, Monkey',
#   'Lah Pat, Flo Milli',
#   'Medi, Sabi',
#   'SAINt JHN',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Dessita, Djordan',
#   'D.T.E, PREZIOSO',
#   'DJ Damyan, Emanuela',
#   '††† (Crosses)',
#   'Medi',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Krissy, Tedi Aleksandrova',
#   'Still Woozy',
#   'Tedi Aleksandrova, Silver',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Jimin',
#   'Kate Miller-Heidke',
#   'The Weeknd, Playboi Carti',
#   'Aminé, Smino',
#   'Selina, Medi',
#   'Team Karacho, Roger Rekless',
#   'Djordan',
#   'Capo Plaza, Luciano',
#   'Alex Robov, Tedi Aleksandrova',
#   'Lil Uzi Vert',
#   'Billie Eilish',
#   'Teejay, Inner Circle',
#   'Kendrick Lamar',
#   'Dima Bilan, Nataliya Vlasova',
#   'VANE$$A, Konstantin',
#   'Konan',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Robin Schulz, KIDDO',
#   'Danna, Konstantin',
#   'William Orbit, Georgia',
#   'Tomas, Fiki, Danna',
#   'Jamie Brown, Marshmello',
#   'VANE$$A, Alisia',
#   'Einar, A36',
#   'Galena',
#   'Lola Young',
#   'Tsvetelina Yaneva, Medi',
#   'Emanuela',
#   'ROSÉ, Bruno Mars',
#   'Rotimi',
#   'Calin, Sofian Medjmedj',
#   'OneRepublic',
#   'Calin, STEIN27',
#   'Gracie Abrams',
#   'Viktor Sheen',
#   'Gracie Abrams',
#   'Viktor Sheen, Saul',
#   'Robin Schulz, KIDDO',
#   'Yzomandias, P T K',
#   'SAINt JHN',
#   'Lady Gaga, Bruno Mars',
#   'Billie Eilish',
#   'Gigi Perez',
#   'FINNEAS',
#   'Gracie Abrams',
#   'D.T.E, PREZIOSO',
#   'Viktor Sheen',
#   'Vojtech Dyk, D.Y.K.',
#   'Billie Eilish',
#   'Billie Eilish',
#   'Viktor Sheen',
#   'Jamie Brown, Marshmello',
#   'Wesley Safadão, Natanzinho Lima',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Calin, Viktor Sheen',
#   'Lah Pat, Flo Milli',
#   'Kleyton Souza',
#   'Lil Uzi Vert',
#   'Calin',
#   'Earth Pirapat, Mix Sahaphap',
#   'Viktor Sheen',
#   'Aminé, Smino',
#   'ROSÉ, Bruno Mars',
#   'A Boogie Wit da Hoodie, Ella Bands',
#   'Yzomandias, P T K, Luca Brassi10x, Le Winter',
#   'Konan',
#   'Natanzinho Lima',
#   'CQ Wrestling',
#   'Hard Rico',
#   'FINNEAS',
#   'Viktor Sheen',
#   'DANNY AVILA',
#   'Ektor',
#   'Mackenzy Mackay',
#   'P T K, Yzomandias, Viktor Sheen',
#   'Foals',
#   'Ben Cristovao',
#   '††† (Crosses)',
#   'Chrystal, NOTION',
#   'Lola Young',
#   'Calin, Sofian Medjmedj',
#   'OneRepublic',
#   'Lady Gaga, Bruno Mars',
#   'SAINt JHN',
#   'Viktor Sheen, Saul',
#   'Gracie Abrams',
#   'Yzomandias, P T K, Luca Brassi10x, Le Winter',
#   'Robin Schulz, KIDDO',
#   'Billie Eilish',
#   'Tamino',
#   'Viktor Sheen',
#   'Aminé, Smino',
#   'Calin, STEIN27',
#   'Gracie Abrams',
#   'ROSÉ, Bruno Mars',
#   'FINNEAS',
#   'Pil C, Luca Brassi10x, Separ',
#   'Calema',
#   'Gigi Perez',
#   'New Hope Club',
#   'Gracie Abrams',
#   'Billie Eilish',
#   'Kendrick Lamar',
#   'TAELA',
#   'Sara Rikas, Viktor Sheen',
#   'Damiano David',
#   'Separ, Peter Pann',
#   'Lookmhee Punyapat, Sonya Saranphat',
#   'Yzomandias, P T K',
#   'Sonya Saranphat, Lookmhee Punyapat',
#   'Shimmi, SIMILIVINLIFE, GABRIELL',
#   'Foals',
#   'Biely Šum, Biely Šum Spať',
#   'D.T.E, PREZIOSO',
#   'Calin, Viktor Sheen',
#   'Lah Pat, Flo Milli',
#   'Separ',
#   'Lola Young',
#   'Dream Supplier, Baby Sleeps, Background White Noise',
#   'Lil Uzi Vert',
#   'The Weeknd, Playboi Carti',
#   '††† (Crosses)',
#   'Chrystal, NOTION',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Separ, Jerry Lee, P T K',
#   'Tommy Saint',
#   'Calin',
#   'Jamie Brown, Marshmello',
#   'Calin, Shimmi',
#   'Glukoza, KYIVSTONER',
#   'DESH, Young Fly, Azahriah',
#   'Gracie Abrams',
#   'DESH, Young Fly',
#   'Robin Schulz, KIDDO',
#   'DESH, Young Fly',
#   'OneRepublic',
#   'Lady Gaga, Bruno Mars',
#   'SAINt JHN',
#   'BSW',
#   'Gracie Abrams',
#   'Dzsúdló, DESH',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'T. Danny',
#   'Lah Pat, Flo Milli',
#   'Pogány Induló',
#   'D.T.E, PREZIOSO',
#   'DESH, Young Fly, Azahriah',
#   'Aminé, Smino',
#   'BSW, ByeAlex és a Slepp',
#   'Tamino',
#   'Kendrick Lamar',
#   'New Hope Club',
#   'DESH',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Gracie Abrams',
#   'Lil Uzi Vert',
#   'Pogány Induló',
#   'FINNEAS',
#   'Billie Eilish',
#   'TAELA',
#   'DESH',
#   'Haze, Mucco',
#   'ROSÉ, Bruno Mars',
#   '††† (Crosses)',
#   'Pogány Induló',
#   'FINNEAS',
#   'KKevin, DESH, Young Fly',
#   'Jamie Brown, Marshmello',
#   'Azahriah, DESH',
#   'Teejay, Inner Circle',
#   'Gigi Perez',
#   'Lola Young',
#   'Manuel',
#   'Money Man, Danny Towers',
#   'HENN',
#   'Einar, A36',
#   'Pogány Induló, ANUBII$',
#   'William Orbit, Georgia',
#   'KKevin, Bruno X Spacc',
#   'Felix Harrer, Leopold Franz',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Skryptonite',
#   'OneRepublic',
#   'MACAN, Kiliana',
#   'Fiorella',
#   'Billie Eilish',
#   'Gracie Abrams',
#   'Miyagi & Andy Panda',
#   'SAINt JHN',
#   'Jakone, Kiliana',
#   'Haze, Mucco',
#   'MiyaGi',
#   'Marcianeke, Crismj',
#   'Billie Eilish',
#   'Team Karacho, Roger Rekless',
#   'Kendrick Lamar',
#   'Tamino',
#   'Endspiel, Ollane',
#   'Billie Eilish',
#   'Endspiel',
#   'FINNEAS',
#   'NAVAI, MONA',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'The Weeknd, Playboi Carti',
#   'Still Woozy',
#   'Jakone, SCIRENA',
#   'Billie Eilish',
#   'Miyagi & Andy Panda',
#   'Konan',
#   'Icegergert',
#   'Jordan Davis',
#   'Wallem',
#   'Jamie Brown, Marshmello',
#   'Jakone',
#   'FINNEAS',
#   'MACAN, SCIRENA',
#   'Calema',
#   'Irina Rimes, Grasu XXL',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'FRIENDLY THUG 52 NGG',
#   'MACAN',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'FORTUNA 812',
#   'Fiorella',
#   'A.V.G, MACAN',
#   'Rodriguinho, Gaab, Mr. Dan',
#   'Icegergert',
#   'Fiorella',
#   'Sobel, francis, Deemz',
#   'Lemon',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Pezet, Auer',
#   'Robin Schulz, KIDDO',
#   'Billie Eilish',
#   'Lah Pat, Flo Milli',
#   'Tymek, Urbanski',
#   'OneRepublic',
#   'Mata',
#   'Billie Eilish',
#   'ROSÉ, Bruno Mars',
#   'Gracie Abrams',
#   'Kleks, Sobel, sanah',
#   'Shinsei Kamattechan, Ano',
#   'Dawid Podsiadło',
#   'SAINt JHN',
#   'Chrystal, NOTION',
#   'D.T.E, PREZIOSO',
#   'Gracie Abrams',
#   'Billie Eilish',
#   'Kendrick Lamar',
#   'Aminé, Smino',
#   'Chappell Roan',
#   'Jamie Brown, Marshmello',
#   'sanah',
#   'MONSTA X',
#   'Gigi Perez',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Pezet, Auer',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'kuqe 2115, francis',
#   'Lil Uzi Vert',
#   'CYRIL, maryjo',
#   'FINNEAS',
#   'bambi, FUJU, francis, Def Jam World Tour',
#   'FINNEAS',
#   'Lola Young',
#   '††† (Crosses)',
#   'kuqe 2115, Kubi Producent',
#   'Tamino',
#   'Teddy Swims',
#   'Lola Young',
#   'Roxie, Mata',
#   'Białas, Muniek Staszczyk, Kuba Więcek, Sir Mich',
#   'Żabson, Sir Mich',
#   'Tommy Saint',
#   'SVM!R',
#   'William Orbit, Georgia',
#   'Dani Mocanu',
#   'Gracie Abrams',
#   'Tzanca Uraganu, Costel Biju',
#   'OneRepublic',
#   'Dani Mocanu',
#   'FINNEAS',
#   'Iuly Neamtu, Manele Mentolate',
#   'SAINt JHN',
#   'Gya, Babasha',
#   'Robin Schulz, KIDDO',
#   'Lady Gaga, Bruno Mars',
#   'Lah Pat, Flo Milli',
#   'Sami G',
#   '††† (Crosses)',
#   'Jimin',
#   'Aminé, Smino',
#   'Dani Mocanu',
#   'Gracie Abrams',
#   'Dani Mocanu',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Dani Mocanu',
#   'Tamino',
#   'Theo Rose',
#   'Lil Uzi Vert',
#   'Babasha, Ministerul Manelelor',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Luis Gabriel, Haziran',
#   'Billie Eilish',
#   'Adrian Norocel',
#   'Imagine Dragons',
#   'Sami G',
#   'D.T.E, PREZIOSO',
#   'Babasha, Ministerul Manelelor',
#   'A Boogie Wit da Hoodie, Ella Bands',
#   'Raihold',
#   'FINNEAS',
#   'Dani Mocanu',
#   'Haze, Mucco',
#   'Dani Mocanu',
#   'Teejay, Inner Circle',
#   'Jimin',
#   'Shaggy, Teejay',
#   'Jimin',
#   'Ricky Rich, Adel',
#   'Jimin',
#   'William Orbit, Georgia',
#   'NOUA UNSPE',
#   'Jamie Brown, Marshmello',
#   'Denis Ramniceanu, Ministerul Manelelor',
#   'Money Man, Danny Towers',
#   'FORTUNA 812',
#   'Gracie Abrams',
#   'Тоня Матвієнко',
#   'OneRepublic',
#   'SadSvit',
#   'Fiorella',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'OSTY, Klavdia Petrivna',
#   'SAINt JHN',
#   'fallen777angel',
#   'Haze, Mucco',
#   'SadSvit, СТРУКТУРА ЩАСТЯ',
#   'Marcianeke, Crismj',
#   'volhey',
#   'Team Karacho, Roger Rekless',
#   'Domiy',
#   'Tamino',
#   'Wellboy, Parfeniuk',
#   'Billie Eilish',
#   'Parfeniuk',
#   'FINNEAS',
#   'SadSvit',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'FRIENDLY THUG 52 NGG',
#   'Still Woozy',
#   'Okean Elzy',
#   'Billie Eilish',
#   'CHEEV',
#   'Konan',
#   'Klavdia Petrivna, Маша Кондратенко',
#   'Jordan Davis',
#   'Nessa Barrett',
#   'Jamie Brown, Marshmello',
#   'Billie Eilish',
#   'FINNEAS',
#   'Геля Зозуля, Adam',
#   'Calema',
#   'MONATIK',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'Poshlaya Molly',
#   'Icegergert',
#   'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#   'MORGENSHTERN',
#   'Fiorella',
#   'Skryptonite',
#   'Rodriguinho, Gaab, Mr. Dan',
#   'паранойя',
#   'Fiorella'],
#  'pais': ['BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BY',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'BG',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'CZ',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'SK',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'HU',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'MD',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'PL',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'RO',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA',
#   'UA'],
#  'genero': []}

# %% [markdown]
# ## De Json a CSV

# %%
import pandas as pd
import requests

# %%
len(dic_med['genero'])
# Out:
# 597

# %% [markdown]
# # 2. Sacar de Lastfm el género de las canciones.

# %%
# Coloca tus credenciales de lastfm aquí
CLIENT_ID = '3377e9e50365058dda182c3667e94f69'
API_KEY = '3377e9e50365058dda182c3667e94f69'

last_fm_connect = requests.get(f"http://www.last.fm/api/auth/?api_key={API_KEY}")

# %%
extra_este_last = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist=Sasha&track=here+she+comes+again&api_key={API_KEY}&autocorrect=1&format=json")

# %% [markdown]
# Llamada a API Last.FM y filtro para conseguir el género

# %%
extra_este_last.json()
# Out:
# {'toptags': {'tag': [{'count': 100,
#     'name': 'pop',
#     'url': 'https://www.last.fm/tag/pop'},
#    {'count': 25, 'name': 'Love', 'url': 'https://www.last.fm/tag/Love'},
#    {'count': 13, 'name': 'german', 'url': 'https://www.last.fm/tag/german'},
#    {'count': 13,
#     'name': '5 of 10 stars',
#     'url': 'https://www.last.fm/tag/5+of+10+stars'},
#    {'count': 13,
#     'name': 'beautiful english ones',
#     'url': 'https://www.last.fm/tag/beautiful+english+ones'},
#    {'count': 13, 'name': 'lts', 'url': 'https://www.last.fm/tag/lts'},
#    {'count': 13, 'name': 'edhits', 'url': 'https://www.last.fm/tag/edhits'}],
#   '@attr': {'artist': 'Sasha', 'track': 'Here She Comes Again'}}}

# %%
extra_este_last.json()['toptags']['tag'][0]['name']
# Out:
# 'pop'

# %%
lista_nombres_este = list(dic_este.values())[0]
lista_artistas_este = list(dic_este.values())[2]

# %%
lista_nombres_este
# Out:
# ['Who',
#  'Seu Astral / Mistérios',
#  'Who',
#  'Tussi Code Mari',
#  'ParisLove',
#  'Das riecht gut / Ça Sent Bon',
#  'Who',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Who',
#  'Party Jumpin’',
#  'Winter Ahead (with PARK HYO SHIN)',
#  'Cono Hielo',
#  'гладиатор/рыцарь',
#  'Casino',
#  'DUMBAI',
#  'Winter Ahead (with PARK HYO SHIN)',
#  'Pode Ir Embora / Vagalumes / Trânsito Parado',
#  'Winter Ahead (with PARK HYO SHIN)',
#  'Na Nossa Sala / Amor e Amor - Ao Vivo',
#  'Who (Rock Remix)',
#  'Vamos Fugir / Aqui É O Seu Lugar',
#  'мило материшься',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Гектор',
#  'Leilão / Palpite / O Amor Não Deixa',
#  'Lost Angeles',
#  'Postcards - Acoustic Version',
#  'Turbo (Majestic)',
#  'BABY GANGSTA',
#  'Контракт',
#  'LEDI',
#  'Последняя Любовь',
#  'Por Ti / Sou Fã',
#  'ALASKA PUFFER',
#  'Outro Estado',
#  'Be Mine',
#  'Jogado Na Rua / Velha Infância / Seu Polícia',
#  'Amsterdam',
#  'Me Apego / Prisão Sem Grade / Lendas e Mistérios',
#  'Страшный сон 2',
#  'FRI(END)S',
#  'Schifoan',
#  'Be Mine',
#  'Ghosts / Slowing Down',
#  'Фото со звездой',
#  'ILMSY (MOVES)',
#  'Адская колыбельная',
#  'Peder Elias/吴宇恒《First Flight》Special Video',
#  'Мераклия',
#  'That’s So True - Live From Radio City Music Hall',
#  'Питаш ли ме',
#  'Hurt',
#  'Mazalyak',
#  'Rodeo (Remix)',
#  'Уау',
#  'Circles',
#  'Die With A Smile',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Mi Amor',
#  "Don't Play by the Rules",
#  'Окадар',
#  'Vivien',
#  'Дум Так',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Чалга',
#  'Rid Of Me - Live',
#  'AMG Isteria',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Who',
#  'Linger - Live On The Voice Australia 2024',
#  'Timeless (feat. Playboi Carti)',
#  'Passenger Princess',
#  'Откачила',
#  'Das riecht gut / Ça Sent Bon',
#  'Бом, Бом',
#  'Ferrari (feat. Luciano)',
#  'Снайпера',
#  'EA2 (The Beginning of the Era)',
#  'BIRDS OF A FEATHER',
#  'Riches Wii a Pree',
#  'Not Like Us',
#  'Она любила музыку',
#  'Влака',
#  'Last Night In Kingston',
#  'tv off (feat. lefty gunplay)',
#  'All We Got (feat. KIDDO)',
#  'Пуши, пуши',
#  'Bank of Wildflowers (feat. Georgia)',
#  'Рупе Рупе',
#  'Party Jumpin’',
#  'Мания',
#  'Standard',
#  'Зиг-заг',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Филм за нас',
#  'Сиромах',
#  'APT.',
#  'ILMSY (MOVES)',
#  'Pistácie (feat. Sofian Medjmedj)',
#  'Hurt',
#  'Vítej mezi náma (feat. STEIN27)',
#  'That’s So True - Live From Radio City Music Hall',
#  'Syndrom',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Cígo a káva (feat. Saul)',
#  'All We Got (feat. KIDDO)',
#  'KSN',
#  'Circles',
#  'Die With A Smile',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Sailor Song',
#  'Family Feud - Live at The Ford',
#  'That’s So True',
#  "Don't Play by the Rules",
#  'Pátky',
#  'Armáda Lásky',
#  'BIRDS OF A FEATHER',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Roleplay',
#  'Party Jumpin’',
#  'Mentira Estampada',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Safír',
#  'Rodeo (Remix)',
#  'É Que Eu Sofri Demais',
#  'EA2 (The Beginning of the Era)',
#  'Suave',
#  'เพิ่งรู้(Never Knew)',
#  'Ohnivej kruh',
#  'Passenger Princess',
#  'APT.',
#  'Playa (feat. Ella Bands)',
#  'Painkillers',
#  'Last Night In Kingston',
#  'Uma e Quinze da Manhã',
#  'Full Round Table',
#  'Brick na brick',
#  'Little Window - Live Studio Session',
#  'Převlečená žízeň',
#  'My Blood',
#  'Pro štěstí',
#  'Postcards - Acoustic Version',
#  'V Hlavě',
#  '2001 // Life Is Yours - The Colour Wheel Session , London 2022',
#  'omluva',
#  'Vivien',
#  'The Days - NOTION Remix',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Pistácie (feat. Sofian Medjmedj)',
#  'Hurt',
#  'Die With A Smile',
#  'Circles',
#  'Cígo a káva (feat. Saul)',
#  'That’s So True - Live From Radio City Music Hall',
#  'Painkillers',
#  'All We Got (feat. KIDDO)',
#  'BIRDS OF A FEATHER',
#  'Babylon - Live',
#  'Syndrom',
#  'Passenger Princess',
#  'Vítej mezi náma (feat. STEIN27)',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'APT.',
#  'Little Window - Live Studio Session',
#  'NENI STRE$S',
#  'Aimer à moitié',
#  'Sailor Song',
#  'Swimming with Sharks',
#  'That’s So True',
#  'THE DINER - ISOLATED VOCALS/Visualizer',
#  'Not Like Us',
#  "rollin'",
#  'Iné Plemená',
#  'Silverlines Orchestral Version',
#  'Bbejbb',
#  'เปล่าหวง (Jealous)',
#  'KSN',
#  "อย่างที่ฉันนั้นเป็นของเธอ (I'm Yours)",
#  'AM4',
#  '2001 // Life Is Yours - The Colour Wheel Session , London 2022',
#  'Biely šum na spanie',
#  "Don't Play by the Rules",
#  'Safír',
#  'Rodeo (Remix)',
#  '7DIGITS',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Clean Baby Sleep White Noise (Loopable)',
#  'EA2 (The Beginning of the Era)',
#  'Timeless (feat. Playboi Carti)',
#  'Vivien',
#  'The Days - NOTION Remix',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Sunset',
#  'Elixir',
#  'Suave',
#  'Party Jumpin’',
#  'I Got It (feat. Shimmi)',
#  'Мотыльки',
#  'PANNONIA',
#  'That’s So True - Live From Radio City Music Hall',
#  'SUV',
#  'All We Got (feat. KIDDO)',
#  'MOKKA',
#  'Hurt',
#  'Die With A Smile',
#  'Circles',
#  'Passport',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'díva',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'VIDÉKI CSAJSZI',
#  'Rodeo (Remix)',
#  'Úgy Hiszem',
#  "Don't Play by the Rules",
#  'BAKPAKK',
#  'Passenger Princess',
#  'Lidokain',
#  'Babylon - Live',
#  'Not Like Us',
#  'Swimming with Sharks',
#  'Strawberry',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'That’s So True',
#  'EA2 (The Beginning of the Era)',
#  'EGY/KETTŐ',
#  'Family Feud - Live at The Ford',
#  'BIRDS OF A FEATHER',
#  'crocodile tears',
#  'LEVÉL',
#  '04:30',
#  'APT.',
#  'Vivien',
#  'Mámor',
#  'Little Window - Live Studio Session',
#  'BANDANA',
#  'Party Jumpin’',
#  'Felednéd',
#  'Riches Wii a Pree',
#  'Sailor Song',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Tiara',
#  'Tuck Your Chain',
#  'SANDELA',
#  'Standard',
#  'Afro Beat',
#  'Bank of Wildflowers (feat. Georgia)',
#  'PROSECCO',
#  'Schifoan',
#  'Die With A Smile',
#  'That’s So True - Live From Radio City Music Hall',
#  'не расслабляйся',
#  'Hurt',
#  'Как je',
#  'Seu Astral / Mistérios',
#  'WILDFLOWER',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Патрон',
#  'Circles',
#  'Асфальт',
#  '04:30',
#  'Texture - Remastered',
#  'Tussi Code Mari',
#  'BIRDS OF A FEATHER',
#  'Das riecht gut / Ça Sent Bon',
#  'Not Like Us',
#  'Babylon - Live',
#  'Приятная',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Малиновый рассвет',
#  'Little Window - Live Studio Session',
#  'Есенин',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Timeless (feat. Playboi Carti)',
#  'Rid Of Me - Live',
#  'По весне',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Minor',
#  'Last Night In Kingston',
#  'Amsterdam',
#  "I Ain't Sayin' - Performance",
#  'Харизма',
#  'Party Jumpin’',
#  'Дорога дальняя',
#  'Family Feud - Live at The Ford',
#  'IVL',
#  'Aimer à moitié',
#  'Pentru totdeauna',
#  'Cono Hielo',
#  'Lost Angeles',
#  'Заново',
#  'DUMBAI',
#  'ParisLove',
#  'Pode Ir Embora / Vagalumes / Trânsito Parado',
#  'Спой',
#  'Na Nossa Sala / Amor e Amor - Ao Vivo',
#  'Гектор',
#  'Vamos Fugir / Aqui É O Seu Lugar',
#  'KOCHASZ?',
#  'Dużo Ciebie Mi',
#  'Die With A Smile',
#  'That’s So True - Live From Radio City Music Hall',
#  'Dom Nad Wodą',
#  'All We Got (feat. KIDDO)',
#  'BIRDS OF A FEATHER',
#  'Rodeo (Remix)',
#  'Sophia Loren',
#  'Hurt',
#  'Lloret de Mar',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'APT.',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Wynalazek Filipa Golarza',
#  '僕は頑張るよっ feat. ano',
#  'Pięknie płyniesz',
#  'Circles',
#  'The Days - NOTION Remix',
#  "Don't Play by the Rules",
#  'That’s So True',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Not Like Us',
#  'Passenger Princess',
#  'Good Luck, Babe!',
#  'Party Jumpin’',
#  'Miłość jest ślepa',
#  'One Day - Live',
#  'Sailor Song',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Dom Nad Wodą',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'taki mały ja',
#  'EA2 (The Beginning of the Era)',
#  'Still Into You',
#  'Little Window - Live Studio Session',
#  'CZEMU NIE ŚPISZ?',
#  'Family Feud - Live at The Ford',
#  'Messy',
#  'Vivien',
#  'wszystkie noce są samotne',
#  'Babylon - Live',
#  'Bad Dreams',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'Falochrony',
#  'Do Ciebie mówię (Taste The Beat)',
#  'PRZEKAZ MYŚLI',
#  'Elixir',
#  'NDA',
#  'Bank of Wildflowers (feat. Georgia)',
#  'Vino să te f',
#  'That’s So True - Live From Radio City Music Hall',
#  'Meneaito',
#  'Hurt',
#  'Anglia',
#  'Little Window - Live Studio Session',
#  'Mercedes',
#  'Circles',
#  'Baklava',
#  'All We Got (feat. KIDDO)',
#  'Die With A Smile',
#  'Rodeo (Remix)',
#  'Vreau',
#  'Vivien',
#  'Who',
#  'Passenger Princess',
#  'Hai sa ne iubim ca nemtii',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Rusia',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Spania',
#  'Babylon - Live',
#  'A venit poliția - From "Candidatul perfect" The Movie',
#  'EA2 (The Beginning of the Era)',
#  'Yali, Yali',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Vin Sa Te Fur',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'NUMAI FEMEI',
#  'Love Of Mine',
#  'Sper Ca Esti Bine',
#  "Don't Play by the Rules",
#  'Păi naa',
#  'Playa (feat. Ella Bands)',
#  'Jenifer buci de fier',
#  'Family Feud - Live at The Ford',
#  'El chapo',
#  '04:30',
#  'Diss Music Romania',
#  'Riches Wii a Pree',
#  'Who',
#  'Gyal Dem Time (feat. Teejay)',
#  'Who',
#  'Delli (feat. Adel)',
#  'Who',
#  'Bank of Wildflowers (feat. Georgia)',
#  'REGINA',
#  'Party Jumpin’',
#  'Merhaba (Stil Turcesc)',
#  'Tuck Your Chain',
#  'ParisLove',
#  'That’s So True - Live From Radio City Music Hall',
#  'Кульбаби',
#  'Hurt',
#  'Касета',
#  'Seu Astral / Mistérios',
#  'Die With A Smile',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Не лякай',
#  'Circles',
#  'гладиатор/рыцарь',
#  '04:30',
#  'Силуети',
#  'Tussi Code Mari',
#  'мило материшься',
#  'Das riecht gut / Ça Sent Bon',
#  'Нагадай',
#  'Babylon - Live',
#  'Забий',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Врубай',
#  'Little Window - Live Studio Session',
#  'Молодість',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Lost Angeles',
#  'Rid Of Me - Live',
#  'Як ніколи',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Рана',
#  'Last Night In Kingston',
#  'Їде дах',
#  "I Ain't Sayin' - Performance",
#  'P*RNSTAR',
#  'Party Jumpin’',
#  'BIRDS OF A FEATHER',
#  'Family Feud - Live at The Ford',
#  'Особистий рай',
#  'Aimer à moitié',
#  'А що?',
#  'Cono Hielo',
#  'Контракт',
#  'Casino',
#  'DUMBAI',
#  'Последняя Любовь',
#  'Pode Ir Embora / Vagalumes / Trânsito Parado',
#  'не расслабляйся',
#  'Na Nossa Sala / Amor e Amor - Ao Vivo',
#  'ALASKA PUFFER',
#  'Vamos Fugir / Aqui É O Seu Lugar']

# %%
lista_artistas_este
# Out:
# ['Jimin',
#  'Fiorella',
#  'Jimin',
#  'Marcianeke, Crismj',
#  'FORTUNA 812',
#  'Team Karacho, Roger Rekless',
#  'Jimin',
#  'Billie Eilish',
#  'Jimin',
#  'Jamie Brown, Marshmello',
#  'V, Park Hyo Shin',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'fallen777angel',
#  'Icegergert',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'V, Park Hyo Shin',
#  'Fiorella',
#  'V, Park Hyo Shin',
#  'Rodriguinho, Gaab, Mr. Dan',
#  'Jimin',
#  'Fiorella',
#  'volhey',
#  'Lola Young',
#  'Icegergert',
#  'Fiorella',
#  'FRIENDLY THUG 52 NGG',
#  'Mackenzy Mackay',
#  'Big Baby Tape',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'Poshlaya Molly',
#  'Robot95, DJ Maff',
#  'MORGENSHTERN',
#  'Fiorella',
#  'паранойя',
#  'Fiorella, Hugo Henrique',
#  'Jimin',
#  'Fiorella',
#  'Icegergert',
#  'Fiorella',
#  'Раковая Выхухоль',
#  'V',
#  'Felix Harrer, Leopold Franz',
#  'Jimin',
#  'Scarlet House',
#  'Lida',
#  'Rotimi',
#  'Poshlaya Molly',
#  'Peder Elias, 吴宇恒',
#  'Djordan',
#  'Gracie Abrams',
#  'Tsvetelina Yaneva',
#  'OneRepublic',
#  'Emanuela, Monkey',
#  'Lah Pat, Flo Milli',
#  'Medi, Sabi',
#  'SAINt JHN',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Dessita, Djordan',
#  'D.T.E, PREZIOSO',
#  'DJ Damyan, Emanuela',
#  '††† (Crosses)',
#  'Medi',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Krissy, Tedi Aleksandrova',
#  'Still Woozy',
#  'Tedi Aleksandrova, Silver',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Jimin',
#  'Kate Miller-Heidke',
#  'The Weeknd, Playboi Carti',
#  'Aminé, Smino',
#  'Selina, Medi',
#  'Team Karacho, Roger Rekless',
#  'Djordan',
#  'Capo Plaza, Luciano',
#  'Alex Robov, Tedi Aleksandrova',
#  'Lil Uzi Vert',
#  'Billie Eilish',
#  'Teejay, Inner Circle',
#  'Kendrick Lamar',
#  'Dima Bilan, Nataliya Vlasova',
#  'VANE$$A, Konstantin',
#  'Konan',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Robin Schulz, KIDDO',
#  'Danna, Konstantin',
#  'William Orbit, Georgia',
#  'Tomas, Fiki, Danna',
#  'Jamie Brown, Marshmello',
#  'VANE$$A, Alisia',
#  'Einar, A36',
#  'Galena',
#  'Lola Young',
#  'Tsvetelina Yaneva, Medi',
#  'Emanuela',
#  'ROSÉ, Bruno Mars',
#  'Rotimi',
#  'Calin, Sofian Medjmedj',
#  'OneRepublic',
#  'Calin, STEIN27',
#  'Gracie Abrams',
#  'Viktor Sheen',
#  'Gracie Abrams',
#  'Viktor Sheen, Saul',
#  'Robin Schulz, KIDDO',
#  'Yzomandias, P T K',
#  'SAINt JHN',
#  'Lady Gaga, Bruno Mars',
#  'Billie Eilish',
#  'Gigi Perez',
#  'FINNEAS',
#  'Gracie Abrams',
#  'D.T.E, PREZIOSO',
#  'Viktor Sheen',
#  'Vojtech Dyk, D.Y.K.',
#  'Billie Eilish',
#  'Billie Eilish',
#  'Viktor Sheen',
#  'Jamie Brown, Marshmello',
#  'Wesley Safadão, Natanzinho Lima',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Calin, Viktor Sheen',
#  'Lah Pat, Flo Milli',
#  'Kleyton Souza',
#  'Lil Uzi Vert',
#  'Calin',
#  'Earth Pirapat, Mix Sahaphap',
#  'Viktor Sheen',
#  'Aminé, Smino',
#  'ROSÉ, Bruno Mars',
#  'A Boogie Wit da Hoodie, Ella Bands',
#  'Yzomandias, P T K, Luca Brassi10x, Le Winter',
#  'Konan',
#  'Natanzinho Lima',
#  'CQ Wrestling',
#  'Hard Rico',
#  'FINNEAS',
#  'Viktor Sheen',
#  'DANNY AVILA',
#  'Ektor',
#  'Mackenzy Mackay',
#  'P T K, Yzomandias, Viktor Sheen',
#  'Foals',
#  'Ben Cristovao',
#  '††† (Crosses)',
#  'Chrystal, NOTION',
#  'Lola Young',
#  'Calin, Sofian Medjmedj',
#  'OneRepublic',
#  'Lady Gaga, Bruno Mars',
#  'SAINt JHN',
#  'Viktor Sheen, Saul',
#  'Gracie Abrams',
#  'Yzomandias, P T K, Luca Brassi10x, Le Winter',
#  'Robin Schulz, KIDDO',
#  'Billie Eilish',
#  'Tamino',
#  'Viktor Sheen',
#  'Aminé, Smino',
#  'Calin, STEIN27',
#  'Gracie Abrams',
#  'ROSÉ, Bruno Mars',
#  'FINNEAS',
#  'Pil C, Luca Brassi10x, Separ',
#  'Calema',
#  'Gigi Perez',
#  'New Hope Club',
#  'Gracie Abrams',
#  'Billie Eilish',
#  'Kendrick Lamar',
#  'TAELA',
#  'Sara Rikas, Viktor Sheen',
#  'Damiano David',
#  'Separ, Peter Pann',
#  'Lookmhee Punyapat, Sonya Saranphat',
#  'Yzomandias, P T K',
#  'Sonya Saranphat, Lookmhee Punyapat',
#  'Shimmi, SIMILIVINLIFE, GABRIELL',
#  'Foals',
#  'Biely Šum, Biely Šum Spať',
#  'D.T.E, PREZIOSO',
#  'Calin, Viktor Sheen',
#  'Lah Pat, Flo Milli',
#  'Separ',
#  'Lola Young',
#  'Dream Supplier, Baby Sleeps, Background White Noise',
#  'Lil Uzi Vert',
#  'The Weeknd, Playboi Carti',
#  '††† (Crosses)',
#  'Chrystal, NOTION',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Separ, Jerry Lee, P T K',
#  'Tommy Saint',
#  'Calin',
#  'Jamie Brown, Marshmello',
#  'Calin, Shimmi',
#  'Glukoza, KYIVSTONER',
#  'DESH, Young Fly, Azahriah',
#  'Gracie Abrams',
#  'DESH, Young Fly',
#  'Robin Schulz, KIDDO',
#  'DESH, Young Fly',
#  'OneRepublic',
#  'Lady Gaga, Bruno Mars',
#  'SAINt JHN',
#  'BSW',
#  'Gracie Abrams',
#  'Dzsúdló, DESH',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'T. Danny',
#  'Lah Pat, Flo Milli',
#  'Pogány Induló',
#  'D.T.E, PREZIOSO',
#  'DESH, Young Fly, Azahriah',
#  'Aminé, Smino',
#  'BSW, ByeAlex és a Slepp',
#  'Tamino',
#  'Kendrick Lamar',
#  'New Hope Club',
#  'DESH',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Gracie Abrams',
#  'Lil Uzi Vert',
#  'Pogány Induló',
#  'FINNEAS',
#  'Billie Eilish',
#  'TAELA',
#  'DESH',
#  'Haze, Mucco',
#  'ROSÉ, Bruno Mars',
#  '††† (Crosses)',
#  'Pogány Induló',
#  'FINNEAS',
#  'KKevin, DESH, Young Fly',
#  'Jamie Brown, Marshmello',
#  'Azahriah, DESH',
#  'Teejay, Inner Circle',
#  'Gigi Perez',
#  'Lola Young',
#  'Manuel',
#  'Money Man, Danny Towers',
#  'HENN',
#  'Einar, A36',
#  'Pogány Induló, ANUBII$',
#  'William Orbit, Georgia',
#  'KKevin, Bruno X Spacc',
#  'Felix Harrer, Leopold Franz',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Skryptonite',
#  'OneRepublic',
#  'MACAN, Kiliana',
#  'Fiorella',
#  'Billie Eilish',
#  'Gracie Abrams',
#  'Miyagi & Andy Panda',
#  'SAINt JHN',
#  'Jakone, Kiliana',
#  'Haze, Mucco',
#  'MiyaGi',
#  'Marcianeke, Crismj',
#  'Billie Eilish',
#  'Team Karacho, Roger Rekless',
#  'Kendrick Lamar',
#  'Tamino',
#  'Endspiel, Ollane',
#  'Billie Eilish',
#  'Endspiel',
#  'FINNEAS',
#  'NAVAI, MONA',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'The Weeknd, Playboi Carti',
#  'Still Woozy',
#  'Jakone, SCIRENA',
#  'Billie Eilish',
#  'Miyagi & Andy Panda',
#  'Konan',
#  'Icegergert',
#  'Jordan Davis',
#  'Wallem',
#  'Jamie Brown, Marshmello',
#  'Jakone',
#  'FINNEAS',
#  'MACAN, SCIRENA',
#  'Calema',
#  'Irina Rimes, Grasu XXL',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'FRIENDLY THUG 52 NGG',
#  'MACAN',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'FORTUNA 812',
#  'Fiorella',
#  'A.V.G, MACAN',
#  'Rodriguinho, Gaab, Mr. Dan',
#  'Icegergert',
#  'Fiorella',
#  'Sobel, francis, Deemz',
#  'Lemon',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Pezet, Auer',
#  'Robin Schulz, KIDDO',
#  'Billie Eilish',
#  'Lah Pat, Flo Milli',
#  'Tymek, Urbanski',
#  'OneRepublic',
#  'Mata',
#  'Billie Eilish',
#  'ROSÉ, Bruno Mars',
#  'Gracie Abrams',
#  'Kleks, Sobel, sanah',
#  'Shinsei Kamattechan, Ano',
#  'Dawid Podsiadło',
#  'SAINt JHN',
#  'Chrystal, NOTION',
#  'D.T.E, PREZIOSO',
#  'Gracie Abrams',
#  'Billie Eilish',
#  'Kendrick Lamar',
#  'Aminé, Smino',
#  'Chappell Roan',
#  'Jamie Brown, Marshmello',
#  'sanah',
#  'MONSTA X',
#  'Gigi Perez',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Pezet, Auer',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'kuqe 2115, francis',
#  'Lil Uzi Vert',
#  'CYRIL, maryjo',
#  'FINNEAS',
#  'bambi, FUJU, francis, Def Jam World Tour',
#  'FINNEAS',
#  'Lola Young',
#  '††† (Crosses)',
#  'kuqe 2115, Kubi Producent',
#  'Tamino',
#  'Teddy Swims',
#  'Lola Young',
#  'Roxie, Mata',
#  'Białas, Muniek Staszczyk, Kuba Więcek, Sir Mich',
#  'Żabson, Sir Mich',
#  'Tommy Saint',
#  'SVM!R',
#  'William Orbit, Georgia',
#  'Dani Mocanu',
#  'Gracie Abrams',
#  'Tzanca Uraganu, Costel Biju',
#  'OneRepublic',
#  'Dani Mocanu',
#  'FINNEAS',
#  'Iuly Neamtu, Manele Mentolate',
#  'SAINt JHN',
#  'Gya, Babasha',
#  'Robin Schulz, KIDDO',
#  'Lady Gaga, Bruno Mars',
#  'Lah Pat, Flo Milli',
#  'Sami G',
#  '††† (Crosses)',
#  'Jimin',
#  'Aminé, Smino',
#  'Dani Mocanu',
#  'Gracie Abrams',
#  'Dani Mocanu',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Dani Mocanu',
#  'Tamino',
#  'Theo Rose',
#  'Lil Uzi Vert',
#  'Babasha, Ministerul Manelelor',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Luis Gabriel, Haziran',
#  'Billie Eilish',
#  'Adrian Norocel',
#  'Imagine Dragons',
#  'Sami G',
#  'D.T.E, PREZIOSO',
#  'Babasha, Ministerul Manelelor',
#  'A Boogie Wit da Hoodie, Ella Bands',
#  'Raihold',
#  'FINNEAS',
#  'Dani Mocanu',
#  'Haze, Mucco',
#  'Dani Mocanu',
#  'Teejay, Inner Circle',
#  'Jimin',
#  'Shaggy, Teejay',
#  'Jimin',
#  'Ricky Rich, Adel',
#  'Jimin',
#  'William Orbit, Georgia',
#  'NOUA UNSPE',
#  'Jamie Brown, Marshmello',
#  'Denis Ramniceanu, Ministerul Manelelor',
#  'Money Man, Danny Towers',
#  'FORTUNA 812',
#  'Gracie Abrams',
#  'Тоня Матвієнко',
#  'OneRepublic',
#  'SadSvit',
#  'Fiorella',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'OSTY, Klavdia Petrivna',
#  'SAINt JHN',
#  'fallen777angel',
#  'Haze, Mucco',
#  'SadSvit, СТРУКТУРА ЩАСТЯ',
#  'Marcianeke, Crismj',
#  'volhey',
#  'Team Karacho, Roger Rekless',
#  'Domiy',
#  'Tamino',
#  'Wellboy, Parfeniuk',
#  'Billie Eilish',
#  'Parfeniuk',
#  'FINNEAS',
#  'SadSvit',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'FRIENDLY THUG 52 NGG',
#  'Still Woozy',
#  'Okean Elzy',
#  'Billie Eilish',
#  'CHEEV',
#  'Konan',
#  'Klavdia Petrivna, Маша Кондратенко',
#  'Jordan Davis',
#  'Nessa Barrett',
#  'Jamie Brown, Marshmello',
#  'Billie Eilish',
#  'FINNEAS',
#  'Геля Зозуля, Adam',
#  'Calema',
#  'MONATIK',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'Poshlaya Molly',
#  'Icegergert',
#  'CA7RIEL & Paco Amoroso, CA7RIEL, Paco Amoroso',
#  'MORGENSHTERN',
#  'Fiorella',
#  'Skryptonite',
#  'Rodriguinho, Gaab, Mr. Dan',
#  'паранойя',
#  'Fiorella']

# %%
def llamada_lastfm(lista_nombres, lista_artistas,datos):
    for i in range(len(lista_nombres)):
        try:
            nombre = str(lista_nombres[i]).replace(' ', '+')
            artista = lista_artistas[i].replace(' ', '+').replace(',', '+&')
            llamada_genero = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist={artista}&track={nombre}&api_key={API_KEY}&autocorrect=1&format=json")
            try:
                genero_cancion = llamada_genero.json()['toptags']['tag'][0]['name']
                datos['genero'].append(genero_cancion)
            except KeyError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no está registrada en lastfm")
                
            except IndexError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no tiene tags")
            
        except:
            datos['genero'].append("NULL")
            print(f"Hay problemas con la canción {lista_nombres[i]}")

# %%
llamada_lastfm(lista_nombres_este, lista_artistas_este, dic_este)
# Out:
# La canción Seu Astral / Mistérios no tiene tags
# La canción Tussi Code Mari no está registrada en lastfm
# La canción ParisLove no tiene tags
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Winter Ahead (with PARK HYO SHIN) no está registrada en lastfm
# La canción Cono Hielo no está registrada en lastfm
# La canción Casino no tiene tags
# La canción DUMBAI no está registrada en lastfm
# La canción Winter Ahead (with PARK HYO SHIN) no está registrada en lastfm
# La canción Pode Ir Embora / Vagalumes / Trânsito Parado no tiene tags
# La canción Winter Ahead (with PARK HYO SHIN) no está registrada en lastfm
# La canción Na Nossa Sala / Amor e Amor - Ao Vivo no está registrada en lastfm
# La canción Vamos Fugir / Aqui É O Seu Lugar no tiene tags
# La canción мило материшься no tiene tags
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Гектор no tiene tags
# La canción Leilão / Palpite / O Amor Não Deixa no tiene tags
# La canción Lost Angeles no tiene tags
# La canción Postcards - Acoustic Version no tiene tags
# La canción Turbo (Majestic) no tiene tags
# La canción BABY GANGSTA no está registrada en lastfm
# La canción LEDI no está registrada en lastfm
# La canción Последняя Любовь no tiene tags
# La canción Por Ti / Sou Fã no tiene tags
# La canción ALASKA PUFFER no tiene tags
# La canción Outro Estado no está registrada en lastfm
# La canción Jogado Na Rua / Velha Infância / Seu Polícia no tiene tags
# La canción Amsterdam no tiene tags
# La canción Me Apego / Prisão Sem Grade / Lendas e Mistérios no tiene tags
# La canción Страшный сон 2 no tiene tags
# La canción Schifoan no está registrada en lastfm
# La canción Ghosts / Slowing Down no tiene tags
# La canción Фото со звездой no tiene tags
# La canción ILMSY (MOVES) no tiene tags
# La canción Адская колыбельная no tiene tags
# La canción Peder Elias/吴宇恒《First Flight》Special Video no está registrada en lastfm
# La canción Мераклия no tiene tags
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Питаш ли ме no tiene tags
# La canción Hurt no tiene tags
# La canción Mazalyak no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Уау no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Mi Amor no está registrada en lastfm
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Окадар no está registrada en lastfm
# La canción Vivien no tiene tags
# La canción Дум Так no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Чалга no está registrada en lastfm
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción AMG Isteria no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Linger - Live On The Voice Australia 2024 no tiene tags
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Откачила no está registrada en lastfm
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Бом, Бом no tiene tags
# La canción Ferrari (feat. Luciano) no está registrada en lastfm
# La canción Снайпера no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Riches Wii a Pree no está registrada en lastfm
# La canción Она любила музыку no está registrada en lastfm
# La canción Влака no está registrada en lastfm
# La canción Last Night In Kingston no tiene tags
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Пуши, пуши no está registrada en lastfm
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm
# La canción Рупе Рупе no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Мания no está registrada en lastfm
# La canción Standard no está registrada en lastfm
# La canción Зиг-заг no tiene tags
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Филм за нас no está registrada en lastfm
# La canción Сиромах no tiene tags
# La canción APT. no está registrada en lastfm
# La canción ILMSY (MOVES) no tiene tags
# La canción Pistácie (feat. Sofian Medjmedj) no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Vítej mezi náma (feat. STEIN27) no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Syndrom no tiene tags
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Cígo a káva (feat. Saul) no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción KSN no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Pátky no tiene tags
# La canción Armáda Lásky no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Roleplay no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Mentira Estampada no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Safír no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción É Que Eu Sofri Demais no tiene tags
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Suave no tiene tags
# La canción เพิ่งรู้(Never Knew) no está registrada en lastfm
# La canción Ohnivej kruh no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Playa (feat. Ella Bands) no está registrada en lastfm
# La canción Painkillers no está registrada en lastfm
# La canción Last Night In Kingston no tiene tags
# La canción Uma e Quinze da Manhã no tiene tags
# La canción Full Round Table no tiene tags
# La canción Brick na brick no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Převlečená žízeň no tiene tags
# La canción My Blood no tiene tags
# La canción Pro štěstí no tiene tags
# La canción Postcards - Acoustic Version no tiene tags
# La canción V Hlavě no está registrada en lastfm
# La canción 2001 // Life Is Yours - The Colour Wheel Session , London 2022 no tiene tags
# La canción omluva no tiene tags
# La canción Vivien no tiene tags
# La canción The Days - NOTION Remix no está registrada en lastfm
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Pistácie (feat. Sofian Medjmedj) no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Cígo a káva (feat. Saul) no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Painkillers no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción Syndrom no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción Vítej mezi náma (feat. STEIN27) no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción APT. no está registrada en lastfm
# La canción Little Window - Live Studio Session no tiene tags
# La canción NENI STRE$S no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción Swimming with Sharks no tiene tags
# La canción THE DINER - ISOLATED VOCALS/Visualizer no está registrada en lastfm
# La canción rollin' no tiene tags
# La canción Iné Plemená no está registrada en lastfm
# La canción Silverlines Orchestral Version no tiene tags
# La canción Bbejbb no está registrada en lastfm
# La canción เปล่าหวง (Jealous) no está registrada en lastfm
# La canción KSN no está registrada en lastfm
# La canción อย่างที่ฉันนั้นเป็นของเธอ (I'm Yours) no está registrada en lastfm
# La canción AM4 no está registrada en lastfm
# La canción 2001 // Life Is Yours - The Colour Wheel Session , London 2022 no tiene tags
# La canción Biely šum na spanie no está registrada en lastfm
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Safír no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción 7DIGITS no tiene tags
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Clean Baby Sleep White Noise (Loopable) no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Vivien no tiene tags
# La canción The Days - NOTION Remix no está registrada en lastfm
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Sunset no está registrada en lastfm
# La canción Elixir no tiene tags
# La canción Suave no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción I Got It (feat. Shimmi) no está registrada en lastfm
# La canción Мотыльки no está registrada en lastfm
# La canción PANNONIA no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción SUV no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción MOKKA no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Passport no tiene tags
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción díva no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción VIDÉKI CSAJSZI no tiene tags
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Úgy Hiszem no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción BAKPAKK no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Lidokain no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción Swimming with Sharks no tiene tags
# La canción Strawberry no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción EGY/KETTŐ no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción crocodile tears no tiene tags
# La canción LEVÉL no tiene tags
# La canción 04:30 no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Vivien no tiene tags
# La canción Mámor no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción BANDANA no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Felednéd no está registrada en lastfm
# La canción Riches Wii a Pree no está registrada en lastfm
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Tiara no tiene tags
# La canción Tuck Your Chain no está registrada en lastfm
# La canción SANDELA no tiene tags
# La canción Standard no está registrada en lastfm
# La canción Afro Beat no está registrada en lastfm
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm
# La canción PROSECCO no está registrada en lastfm
# La canción Schifoan no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción не расслабляйся no tiene tags
# La canción Hurt no tiene tags
# La canción Как je no está registrada en lastfm
# La canción Seu Astral / Mistérios no tiene tags
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Патрон no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Асфальт no está registrada en lastfm
# La canción 04:30 no está registrada en lastfm
# La canción Texture - Remastered no tiene tags
# La canción Tussi Code Mari no está registrada en lastfm
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción Приятная no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Малиновый рассвет no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Есенин no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción По весне no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Minor no está registrada en lastfm
# La canción Last Night In Kingston no tiene tags
# La canción Amsterdam no tiene tags
# La canción I Ain't Sayin' - Performance no tiene tags
# La canción Харизма no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Дорога дальняя no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción IVL no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción Pentru totdeauna no está registrada en lastfm
# La canción Cono Hielo no está registrada en lastfm
# La canción Lost Angeles no tiene tags
# La canción Заново no tiene tags
# La canción DUMBAI no está registrada en lastfm
# La canción ParisLove no tiene tags
# La canción Pode Ir Embora / Vagalumes / Trânsito Parado no tiene tags
# La canción Спой no está registrada en lastfm
# La canción Na Nossa Sala / Amor e Amor - Ao Vivo no está registrada en lastfm
# La canción Гектор no tiene tags
# La canción Vamos Fugir / Aqui É O Seu Lugar no tiene tags
# La canción KOCHASZ? no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Dom Nad Wodą no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Sophia Loren no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Lloret de Mar no tiene tags
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción APT. no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Wynalazek Filipa Golarza no está registrada en lastfm
# La canción 僕は頑張るよっ feat. ano no está registrada en lastfm
# La canción Circles no tiene tags
# La canción The Days - NOTION Remix no está registrada en lastfm
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción One Day - Live no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Dom Nad Wodą no está registrada en lastfm
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción taki mały ja no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Still Into You no está registrada en lastfm
# La canción Little Window - Live Studio Session no tiene tags
# La canción CZEMU NIE ŚPISZ? no está registrada en lastfm
# La canción Family Feud - Live at The Ford no tiene tags
# La canción Vivien no tiene tags
# La canción wszystkie noce są samotne no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Falochrony no está registrada en lastfm
# La canción Do Ciebie mówię (Taste The Beat) no está registrada en lastfm
# La canción PRZEKAZ MYŚLI no está registrada en lastfm
# La canción Elixir no tiene tags
# La canción NDA no tiene tags
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm
# La canción Vino să te f no tiene tags
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Meneaito no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Anglia no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Mercedes no está registrada en lastfm
# La canción Circles no tiene tags
# La canción Baklava no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Vreau no tiene tags
# La canción Vivien no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción Hai sa ne iubim ca nemtii no tiene tags
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Rusia no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Spania no tiene tags
# La canción Babylon - Live no tiene tags
# La canción A venit poliția - From "Candidatul perfect" The Movie no tiene tags
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Yali, Yali no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Vin Sa Te Fur no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción NUMAI FEMEI no tiene tags
# La canción Love Of Mine no tiene tags
# La canción Sper Ca Esti Bine no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Păi naa no está registrada en lastfm
# La canción Playa (feat. Ella Bands) no está registrada en lastfm
# La canción Jenifer buci de fier no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción El chapo no tiene tags
# La canción 04:30 no está registrada en lastfm
# La canción Diss Music Romania no tiene tags
# La canción Riches Wii a Pree no está registrada en lastfm
# La canción Gyal Dem Time (feat. Teejay) no está registrada en lastfm
# La canción Delli (feat. Adel) no está registrada en lastfm
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm
# La canción REGINA no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Merhaba (Stil Turcesc) no está registrada en lastfm
# La canción Tuck Your Chain no está registrada en lastfm
# La canción ParisLove no tiene tags
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Кульбаби no tiene tags
# La canción Hurt no tiene tags
# La canción Seu Astral / Mistérios no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Не лякай no está registrada en lastfm
# La canción Circles no tiene tags
# La canción 04:30 no está registrada en lastfm
# La canción Силуети no está registrada en lastfm
# La canción Tussi Code Mari no está registrada en lastfm
# La canción мило материшься no tiene tags
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Нагадай no tiene tags
# La canción Babylon - Live no tiene tags
# La canción Забий no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Врубай no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Молодість no tiene tags
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Lost Angeles no tiene tags
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción Як ніколи no tiene tags
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Рана no tiene tags
# La canción Last Night In Kingston no tiene tags
# La canción Їде дах no está registrada en lastfm
# La canción I Ain't Sayin' - Performance no tiene tags
# La canción P*RNSTAR no tiene tags
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Family Feud - Live at The Ford no tiene tags
# La canción Особистий рай no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción А що? no tiene tags
# La canción Cono Hielo no está registrada en lastfm
# La canción Casino no tiene tags
# La canción DUMBAI no está registrada en lastfm
# La canción Последняя Любовь no tiene tags
# La canción Pode Ir Embora / Vagalumes / Trânsito Parado no tiene tags
# La canción не расслабляйся no tiene tags
# La canción Na Nossa Sala / Amor e Amor - Ao Vivo no está registrada en lastfm
# La canción ALASKA PUFFER no tiene tags
# La canción Vamos Fugir / Aqui É O Seu Lugar no tiene tags

# %%
df_este = pd.DataFrame(dic_este)

# %%
df_este.index.name="id"

# %%
df_este
# Out:
#                                            nombre  popularity  \
# id
# 0                                             Who          86
# 1                          Seu Astral / Mistérios          11
# 2                                             Who          82
# 3                                 Tussi Code Mari           5
# 4                                       ParisLove          62
# ..                                            ...         ...
# 441  Pode Ir Embora / Vagalumes / Trânsito Parado           1
# 442                               не расслабляйся          60
# 443         Na Nossa Sala / Amor e Amor - Ao Vivo           1
# 444                                 ALASKA PUFFER          57
# 445              Vamos Fugir / Aqui É O Seu Lugar           1
#
#                         artista pais      genero
# id
# 0                         Jimin   BY  homosexual
# 1                      Fiorella   BY        NULL
# 2                         Jimin   BY  homosexual
# 3            Marcianeke, Crismj   BY        NULL
# 4                   FORTUNA 812   BY        NULL
# ..                          ...  ...         ...
# 441                    Fiorella   UA        NULL
# 442                 Skryptonite   UA        NULL
# 443  Rodriguinho, Gaab, Mr. Dan   UA        NULL
# 444                    паранойя   UA        NULL
# 445                    Fiorella   UA        NULL
#
# [446 rows x 5 columns]

# %% [markdown]
# 🧠Recordatorio: Como la llamada test_2 nos devuelve varios géneros (tags), decidimos quedarnos con el primero, que es el más utilizado.

# %% [markdown]
# Queremos extraer el género para introducirlo en el diccionario `prueba`, por lo que hacemos dos listas, una con los nombres de las canciones y otra con los artistas. Iremos iterando por las dos a la vez para poder hacer la llamada a la API de lastfm.

# %%
df_este.to_csv("paises_este_europa_2020_2024.csv")

# %% [markdown]
# # 3. Crear la bbdd

# %% [markdown]
# # 4. Alimentar la bbdd

# %% [markdown]
# # 5. Next steps
#
# - Sacar más de 50 canciones por llamadas
