# %% [markdown]
# # 0. Justificación de uso de Spotify para sacar toptracks.

# %% [markdown]
# # 1. Sacar datos Spotify de 5 años, por países.

# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = ''
CLIENT_SECRET = ''
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# Aquí está el diccionario de países por el que hay que iterar. Sacaremos cada una 4 df, uno por cada grupo de países.

# %%
paises_mediterraneos = {
    "ES": "España",
    "FR": "Francia",
    "MC": "Mónaco",
    "IT": "Italia",
    "SI": "Eslovenia",
    "HR": "Croacia",
    "BA": "Bosnia y Herzegovina",
    "ME": "Montenegro",
    "AL": "Albania",
    "GR": "Grecia",
    "MT": "Malta",
    "CY": "Chipre"}
paises_este_europa = {
    "BY": "Bielorrusia",
    "BG": "Bulgaria",
    "CZ": "Chequia",
    "SK": "Eslovaquia",
    "HU": "Hungría",
    "MD": "Moldavia",
    "PL": "Polonia",
    "RO": "Rumanía",
    "UA": "Ucrania"}
paises_norte_europa = {
    "DK": "Dinamarca",
    "EE": "Estonia",
    "FI": "Finlandia",
    "IS": "Islandia",
    "IE": "Irlanda",
    "LT": "Lituania",
    "LV": "Letonia",
    "NO": "Noruega",
    "SE": "Suecia",
    "GB": "Reino Unido"}
paises_europa_central = {
    "AT": "Austria",
    "DE": "Alemania",
    "CH": "Suiza",
    "LI": "Liechtenstein",
    "BE": "Bélgica",
    "LU": "Luxemburgo",
    "NL": "Países Bajos"}

# %%
datos_rango = sp.search(q = "year:2000-2004", limit=50, offset=0, type='track', market="ES")

# %% [markdown]
# Esta función sirve para ir sacando los datos para cada grupo de países. Habrá que hacer una llamada para cada grupo de países (cada diccionario de los de arriba).
#
# La función toma como argumentos el diccionario y el rango de años que nos interese en el formato `2000-2004`

# %%
def extraccion_por_paises(diccionario_zonas, años):
    todos_los_datos = [] # Esto es una lista de dicts donde se van guardando los diccionarios de cada país
    for pais in diccionario_zonas.keys():
        datos_rango = sp.search(q = f'year:{años}', limit=50, offset=0, type='track', market={pais}) # Cada una tiene que cambiar en q el rango de años
        datos_por_pais = {}
        datos_por_pais['pais'] = pais
        datos_por_pais['datos'] = datos_rango
        todos_los_datos.append(datos_por_pais)
    return todos_los_datos

# %% [markdown]
# Aquí dejamos un ejemplo de utilización de la función:

# %%
prueba_con_miedo = extraccion_por_paises(paises_europa_central, "2000-2004")

# %%
for element in prueba_con_miedo:
    print(element)
# Out:
# {'pais': 'AT', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=AT', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'}, 'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a', 'id': '7o95ZoZt5ZYn31e9z1Hc0a', 'name': 'Natasha Bedingfield', 'type': 'artist', 'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/3PEzTAuPW5IjLJ58FzwQeL'}, 'href': 'https://api.spotify.com/v1/albums/3PEzTAuPW5IjLJ58FzwQeL', 'id': '3PEzTAuPW5IjLJ58FzwQeL', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b337e1ca6629a53c66a3b0d4'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b337e1ca6629a53c66a3b0d4'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b337e1ca6629a53c66a3b0d4'}], 'is_playable': True, 'name': 'Unwritten', 'release_date': '2004-08-30', 'release_date_precision': 'day', 'total_tracks': 14, 'type': 'album', 'uri': 'spotify:album:3PEzTAuPW5IjLJ58FzwQeL'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'}, 'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a', 'id': '7o95ZoZt5ZYn31e9z1Hc0a', 'name': 'Natasha Bedingfield', 'type': 'artist', 'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'}], 'disc_number': 1, 'duration_ms': 259333, 'explicit': False, 'external_ids': {'isrc': 'GBARL0400707'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3U5JVgI2x4rDyHGObzJfNf'}, 'href': 'https://api.spotify.com/v1/tracks/3U5JVgI2x4rDyHGObzJfNf', 'id': '3U5JVgI2x4rDyHGObzJfNf', 'is_local': False, 'is_playable': True, 'name': 'Unwritten', 'popularity': 81, 'preview_url': None, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:3U5JVgI2x4rDyHGObzJfNf'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'}, 'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu', 'id': '0C0XlULifJtAgn6ZNCW2eu', 'name': 'The Killers', 'type': 'artist', 'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4piJq7R3gjUOxnYs6lDCTg'}, 'href': 'https://api.spotify.com/v1/albums/4piJq7R3gjUOxnYs6lDCTg', 'id': '4piJq7R3gjUOxnYs6lDCTg', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ccddd ...
# {'pais': 'DE', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=DE', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'}, 'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a', 'id': '7o95ZoZt5ZYn31e9z1Hc0a', 'name': 'Natasha Bedingfield', 'type': 'artist', 'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/3PEzTAuPW5IjLJ58FzwQeL'}, 'href': 'https://api.spotify.com/v1/albums/3PEzTAuPW5IjLJ58FzwQeL', 'id': '3PEzTAuPW5IjLJ58FzwQeL', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b337e1ca6629a53c66a3b0d4'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b337e1ca6629a53c66a3b0d4'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b337e1ca6629a53c66a3b0d4'}], 'is_playable': True, 'name': 'Unwritten', 'release_date': '2004-08-30', 'release_date_precision': 'day', 'total_tracks': 14, 'type': 'album', 'uri': 'spotify:album:3PEzTAuPW5IjLJ58FzwQeL'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'}, 'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a', 'id': '7o95ZoZt5ZYn31e9z1Hc0a', 'name': 'Natasha Bedingfield', 'type': 'artist', 'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'}], 'disc_number': 1, 'duration_ms': 259333, 'explicit': False, 'external_ids': {'isrc': 'GBARL0400707'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3U5JVgI2x4rDyHGObzJfNf'}, 'href': 'https://api.spotify.com/v1/tracks/3U5JVgI2x4rDyHGObzJfNf', 'id': '3U5JVgI2x4rDyHGObzJfNf', 'is_local': False, 'is_playable': True, 'name': 'Unwritten', 'popularity': 81, 'preview_url': None, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:3U5JVgI2x4rDyHGObzJfNf'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'}, 'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz', 'id': '6XyY86QOPPrYVGvF9ch6wz', 'name': 'Linkin Park', 'type': 'artist', 'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'}, 'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3', 'id': '4Gfnly5CzMJQqkUFfoHaP3', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735f1f5 ...
# {'pais': 'CH', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=CH', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1kTlYbs28MXw7hwO0NLYif'}, 'href': 'https://api.spotify.com/v1/albums/1kTlYbs28MXw7hwO0NLYif', 'id': '1kTlYbs28MXw7hwO0NLYif', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273726d48d93d02e1271774f023'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02726d48d93d02e1271774f023'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851726d48d93d02e1271774f023'}], 'is_playable': True, 'name': 'Encore (Deluxe Version)', 'release_date': '2004-11-12', 'release_date_precision': 'day', 'total_tracks': 23, 'type': 'album', 'uri': 'spotify:album:1kTlYbs28MXw7hwO0NLYif'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'disc_number': 1, 'duration_ms': 250760, 'explicit': True, 'external_ids': {'isrc': 'USIR10400813'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/561jH07mF1jHuk7KlaeF0s'}, 'href': 'https://api.spotify.com/v1/tracks/561jH07mF1jHuk7KlaeF0s', 'id': '561jH07mF1jHuk7KlaeF0s', 'is_local': False, 'is_playable': True, 'name': 'Mockingbird', 'popularity': 81, 'preview_url': None, 'track_number': 16, 'type': 'track', 'uri': 'spotify:track:561jH07mF1jHuk7KlaeF0s'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'}, 'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz', 'id': '6XyY86QOPPrYVGvF9ch6wz', 'name': 'Linkin Park', 'type': 'artist', 'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'}, 'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3', 'id': '4Gfnly5CzMJQqkUFfoHaP3', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735f1f51d14e8bea8 ...
# {'pais': 'LI', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=LI', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2000-2004&type=track&market=LI', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'}, 'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra', 'id': '6ZG5lRT77aJ3btmArcykra', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739164bafe9aaa168d93f4816a'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029164bafe9aaa168d93f4816a'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519164bafe9aaa168d93f4816a'}], 'is_playable': True, 'name': 'Parachutes', 'release_date': '2000-07-10', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'disc_number': 1, 'duration_ms': 266773, 'explicit': False, 'external_ids': {'isrc': 'GBAYE0000267'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'}, 'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg', 'id': '3AJwUDP919kvQ9QcozQPxg', 'is_local': False, 'is_playable': True, 'name': 'Yellow', 'popularity': 86, 'preview_url': None, 'track_number': 5, 'type': 'track', 'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/0RHX9XECH8IVI3LNgWDpmQ'}, 'href': 'https://api.spotify.com/v1/albums/0RHX9XECH8IVI3LNgWDpmQ', 'id': '0RHX9XECH8IVI3LNgWDpmQ', 'images': [{'height': 640 ...
# {'pais': 'BE', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=BE', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2000-2004&type=track&market=BE', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'}, 'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra', 'id': '6ZG5lRT77aJ3btmArcykra', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739164bafe9aaa168d93f4816a'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029164bafe9aaa168d93f4816a'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519164bafe9aaa168d93f4816a'}], 'is_playable': True, 'name': 'Parachutes', 'release_date': '2000-07-10', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'disc_number': 1, 'duration_ms': 266773, 'explicit': False, 'external_ids': {'isrc': 'GBAYE0000267'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'}, 'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg', 'id': '3AJwUDP919kvQ9QcozQPxg', 'is_local': False, 'is_playable': True, 'name': 'Yellow', 'popularity': 86, 'preview_url': None, 'track_number': 5, 'type': 'track', 'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'}, 'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz', 'id': '6XyY86QOPPrYVGvF9ch6wz', 'name': 'Linkin Park', 'type': 'artist', 'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'}, 'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3', 'id': '4Gfnly5CzMJQqkUFfoHaP3', 'images': [{'height':  ...
# {'pais': 'LU', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=LU', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2000-2004&type=track&market=LU', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'}, 'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz', 'id': '6XyY86QOPPrYVGvF9ch6wz', 'name': 'Linkin Park', 'type': 'artist', 'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'}, 'href': 'https://api.spotify.com/v1/albums/4Gfnly5CzMJQqkUFfoHaP3', 'id': '4Gfnly5CzMJQqkUFfoHaP3', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735f1f51d14e8bea89484ecd1b'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e025f1f51d14e8bea89484ecd1b'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048515f1f51d14e8bea89484ecd1b'}], 'is_playable': True, 'name': 'Meteora', 'release_date': '2003-03-25', 'release_date_precision': 'day', 'total_tracks': 13, 'type': 'album', 'uri': 'spotify:album:4Gfnly5CzMJQqkUFfoHaP3'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'}, 'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz', 'id': '6XyY86QOPPrYVGvF9ch6wz', 'name': 'Linkin Park', 'type': 'artist', 'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}], 'disc_number': 1, 'duration_ms': 187520, 'explicit': False, 'external_ids': {'isrc': 'USWB10300474'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2nLtzopw4rPReszdYBJU6h'}, 'href': 'https://api.spotify.com/v1/tracks/2nLtzopw4rPReszdYBJU6h', 'id': '2nLtzopw4rPReszdYBJU6h', 'is_local': False, 'is_playable': True, 'name': 'Numb', 'popularity': 83, 'preview_url': None, 'track_number': 13, 'type': 'track', 'uri': 'spotify:track:2nLtzopw4rPReszdYBJU6h'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'}, 'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra', 'id': '6ZG5lRT77aJ3btmArcykra', 'images': [{'height': 6 ...
# {'pais': 'NL', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2000-2004&type=track&market=NL', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2000-2004&type=track&market=NL', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'}, 'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra', 'id': '6ZG5lRT77aJ3btmArcykra', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2739164bafe9aaa168d93f4816a'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e029164bafe9aaa168d93f4816a'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d000048519164bafe9aaa168d93f4816a'}], 'is_playable': True, 'name': 'Parachutes', 'release_date': '2000-07-10', 'release_date_precision': 'day', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'}, 'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU', 'id': '4gzpq5DPGxSnKTe4SA8HAU', 'name': 'Coldplay', 'type': 'artist', 'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}], 'disc_number': 1, 'duration_ms': 266773, 'explicit': False, 'external_ids': {'isrc': 'GBAYE0000267'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'}, 'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg', 'id': '3AJwUDP919kvQ9QcozQPxg', 'is_local': False, 'is_playable': True, 'name': 'Yellow', 'popularity': 86, 'preview_url': None, 'track_number': 5, 'type': 'track', 'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EvFsr3kj42KNv97ZEnqij'}, 'href': 'https://api.spotify.com/v1/artists/5EvFsr3kj42KNv97ZEnqij', 'id': '5EvFsr3kj42KNv97ZEnqij', 'name': 'Shaggy', 'type': 'artist', 'uri': 'spotify:artist:5EvFsr3kj42KNv97ZEnqij'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4hB4SmzreXMTGWYj7KQ7QN'}, 'href': 'https://api.spotify.com/v1/artists/4hB4SmzreXMTGWYj7KQ7QN', 'id': '4hB4SmzreXMTGWYj7KQ7QN', 'name': 'Rayvon', 'type': 'artist', 'uri': 'spotify:artist:4hB4SmzreXMTGWYj7KQ7QN'}], 'disc_number': 1, 'duration_ms': 248957, 'explicit': False, 'external_ids': {'isrc': 'USMCV0100040'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6X7Eo2VfWfeK6sFo8BbNfp'}, 'href': 'https://api.spotify.com/v1/tracks/6X7Eo2VfWfeK6sFo8BbNfp', 'id': '6X7Eo2VfWfeK6sFo8BbNfp', 'is_local': False, 'is_playable': False, 'name': 'Angel', 'popularity': 28, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:6X7Eo2VfWfeK6sFo8BbNfp'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7o95ZoZt5ZYn31e9z1Hc0a'}, 'href': 'https://api.spotify.com/v1/artists/7o95ZoZt5ZYn31e9z1Hc0a', 'id': '7o95ZoZt5ZYn31e9z1Hc0a', 'name': 'Natasha Bedingfield', 'type': 'artist', 'uri': 'spotify:artist:7o95ZoZt5ZYn31e9z1Hc0a'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/3PEzTAuPW5IjLJ58FzwQeL'}, 'href': 'https://api.spotify.com/v1/albums/3PEzTAuPW5IjLJ58FzwQeL', 'id': '3PEzTAuPW5IjLJ58FzwQeL', 'images': [{'h ...

# %% [markdown]
# ## 1.1. Filtrar ahora los datos que hemos sacado

# %% [markdown]
# En el diccionario `prueba` es donde iremos metiendo los datos que extraigamos

# %%
prueba = {'nombre': [], 'popularity': [], 'artista': [], 'pais': [], 'genero': []}

# %% [markdown]
# Con el código de abajo se extraen los datos de spotify. Luego hacemos una función.
#
# La función `filtro_de_datos` toma como argumento la salida de la función `extraccion_por_paises`, que es una lista donde hemos ido almacenando las salidas de las llamadas.

# %%
for datos_pais in prueba_con_miedo:
    for element in datos_pais['datos']['tracks']['items']:
        prueba['pais'].append(datos_pais['pais'])
        prueba['popularity'].append(element['popularity'])
        prueba['nombre'].append(element['name'])
        artistas = []
        for artista in element['artists']:
            artistas.append(artista['name'])   
        artistas_str = ', '.join(artistas)
        prueba['artista'].append(artistas_str)

# %%
# Un intento de función con el bucle de arriba:

def filtro_de_datos(lista_datos_zonas):
    for datos_pais in lista_datos_zonas:
        for element in datos_pais['datos']['tracks']['items']:
            prueba['pais'].append(datos_pais['pais'])
            prueba['popularity'].append(element['popularity'])
            prueba['nombre'].append(element['name'])
            artistas = []
            for artista in element['artists']:
                artistas.append(artista['name'])   
            artistas_str = ', '.join(artistas)
            prueba['artista'].append(artistas_str)

# %%
import pandas as pd

# %% [markdown]
# # 2. Sacar de Lastfm el género de las canciones.

# %%
import requests

# %%
# Coloca tus credenciales de lastfm aquí
CLIENT_ID = ''
API_KEY = ''

last_fm_connect = requests.get(f"http://www.last.fm/api/auth/?api_key={API_KEY}")

# %% [markdown]
# Aquí hay algunas pruebas que hemos hecho para ver cómo sacar el género de una canción con la API de lastfm.

# %%
test_2 = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist=Sasha&track=here+she+comes+again&api_key={API_KEY}&autocorrect=1&format=json")

# %%
test_2.json()['toptags']['tag'][0]['name'] # Nos quedaríamos con la primera porque es la que más se repite (count más alto)
# Out:
# 'pop'

# %%
for coso in test_2.json()['toptags']['tag']:
    print(coso['name'])
# Out:
# pop
# Love
# german
# 5 of 10 stars
# beautiful english ones
# lts
# edhits

# %% [markdown]
# 🧠Recordatorio: Como la llamada test_2 nos devuelve varios géneros (tags), decidimos quedarnos con el primero, que es el más utilizado.

# %% [markdown]
# Queremos extraer el género para introducirlo en el diccionario `prueba`, por lo que hacemos dos listas, una con los nombres de las canciones y otra con los artistas. Iremos iterando por las dos a la vez para poder hacer la llamada a la API de lastfm.

# %%
lista_nombres = list(prueba.values())[0]
lista_artistas = list(prueba.values())[2]

# %%
lista_nombres[0]
# Out:
# 'Unwritten'

# %%
lista_artistas[0]
# Out:
# 'Natasha Bedingfield'

# %% [markdown]
# Con este bucle hacemos la llamada a la API. El try/except controla que el código no se pare cuando haya alguna llamada que nos de un error o nos devuelva una canción sin tags.

# %%
for i in range(len(lista_nombres)):
    nombre = str(lista_nombres[i]).replace(' ', '+')
    artista = lista_artistas[i].replace(' ', '+').replace(',', '+&')
    llamada_genero = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist={artista}&track={nombre}&api_key={API_KEY}&autocorrect=1&format=json")
    try:
        genero_cancion = llamada_genero.json()['toptags']['tag'][0]['name']
        prueba['genero'].append(genero_cancion)
    except KeyError:
        prueba['genero'].append("NULL")
        print(f"La canción {lista_nombres[i]} no está registrada en lastfm")
        
    except IndexError:
        prueba['genero'].append("NULL")
        print(f"La canción {lista_nombres[i]} no tiene tags")
# Out:
# La canción Angel no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción San Pedro no está registrada en lastfm
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción David's Arm - from Deuce no está registrada en lastfm
# La canción Crazy In Love (feat. JAY-Z) no está registrada en lastfm
# La canción Wierz? w siebie no tiene tags
# La canción Take Me Home no está registrada en lastfm
# La canción Ni na no no tiene tags
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción Till I Collapse no está registrada en lastfm
# La canción Angel no está registrada en lastfm
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción Love Is Alive - Live; 2004 Remaster no está registrada en lastfm
# La canción Crazy In Love (feat. JAY-Z) no está registrada en lastfm
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción Till I Collapse no está registrada en lastfm
# La canción Take Me Home no está registrada en lastfm
# La canción Fuer dich (ZDF-Fernsehgarten 08.06.2003) - VOD no está registrada en lastfm
# La canción Fliegst Du mit mir zu den Sternen (ZDF-Fernsehgarten 06.07.2003) - VOD no está registrada en lastfm
# La canción That's The Way - Live at Earls Court, London, England, 5/1975 no está registrada en lastfm
# La canción New Bibi-Hendl - Rap no tiene tags
# La canción Ergaa Lel Shoua no tiene tags
# La canción Angel no está registrada en lastfm
# La canción '03 Bonnie & Clyde no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción Till I Collapse no está registrada en lastfm
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción Crazy In Love (feat. JAY-Z) no está registrada en lastfm
# La canción The Call - Remix w/out Rap no está registrada en lastfm
# La canción Take Me Home no está registrada en lastfm
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción 05:15 no tiene tags
# La canción Obsesion no está registrada en lastfm
# La canción San Pedro no está registrada en lastfm
# La canción Wierz? w siebie no tiene tags
# La canción Angel no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción San Pedro no está registrada en lastfm
# La canción Till I Collapse no está registrada en lastfm
# La canción Wierz? w siebie no tiene tags
# La canción Ni na no no tiene tags
# La canción Kashmir - Live at Knebworth Festival, Hertfordshire, England, 8/1979 no está registrada en lastfm
# La canción Angel no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción Take Me Home no está registrada en lastfm
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción Could I Have This Kiss Forever (with Enrique Iglesias) no está registrada en lastfm
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción Crazy In Love (feat. JAY-Z) no está registrada en lastfm
# La canción San Pedro no está registrada en lastfm
# La canción Wierz? w siebie no tiene tags
# La canción Ni na no no tiene tags
# La canción Angel no está registrada en lastfm
# La canción Dímelo bajito no tiene tags
# La canción Dar A Volta No Brasil - Ao Vivo no tiene tags
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción San Pedro no está registrada en lastfm
# La canción Till I Collapse no está registrada en lastfm
# La canción Wierz? w siebie no tiene tags
# La canción Take Me Home no está registrada en lastfm
# La canción Ni na no no tiene tags
# La canción Angel no está registrada en lastfm
# La canción Spaceship no tiene tags
# La canción Dímelo bajito no tiene tags
# La canción Peaches - 2001 Remaster no está registrada en lastfm
# La canción Take Me Home no está registrada en lastfm
# La canción Yeah! (feat. Lil Jon & Ludacris) no está registrada en lastfm
# La canción Kashmir - Live at Knebworth Festival, Hertfordshire, England, 8/1979 no está registrada en lastfm
# La canción New Bibi-Hendl - Rap no tiene tags
# La canción Sing For The Moment - Edited no está registrada en lastfm
# La canción Haste to the Wedding (Pt. 1 & 2) no está registrada en lastfm
# La canción Mzael Kel El Banat no tiene tags
# La canción Ergaa Lel Shoua no tiene tags

# %% [markdown]
# Ahora que ya tenemos todo el diccionario `prueba` completo, lo convertimos a Data Frame.

# %%
import pandas as pd

# %%
MI_MARAVILLOSO_DF = pd.DataFrame(prueba)

# %%
MI_MARAVILLOSO_DF.index.name="id"

# %%
MI_MARAVILLOSO_DF
# Out:
#                      nombre  popularity              artista pais   genero
# id
# 0                 Unwritten          81  Natasha Bedingfield   AT      pop
# 1                     Angel          28       Shaggy, Rayvon   AT     NULL
# 2            Mr. Brightside          82          The Killers   AT     rock
# 3                   Rooftop           0                Sasha   AT      pop
# 4                      Numb          83          Linkin Park   AT     rock
# ..                      ...         ...                  ...  ...      ...
# 345      Mzael Kel El Banat           0          Wael Kfoury   NL     NULL
# 346             Ms. Jackson          78              Outkast   NL  Hip-Hop
# 347         Ergaa Lel Shoua           0               Elissa   NL     NULL
# 348          Dansen Aan Zee          50                 BLØF   NL      pop
# 349  Holding Back the Years           0           Simply Red   NL      80s
#
# [350 rows x 5 columns]

# %% [markdown]
# Por último, pasamos el Data Frame a csv.
#
# 🧠 Recuerda cambiar el nombre del csv antes de ejecutar la celda.

# %%
MI_MARAVILLOSO_DF.to_csv("files/europa_central_2000_2004.csv")

# %% [markdown]
# # 3. Crear la bbdd

# %% [markdown]
# # 4. Alimentar la bbdd

# %% [markdown]
# # 5. Next steps
#
# - Sacar más de 50 canciones por llamadas
