# %% [markdown]
# # 0. Justificación de uso de Spotify para sacar toptracks.

# %% [markdown]
# # 1. Sacar datos Spotify de 5 años, por países.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '13122d95aee54d2e828fdbc53ab27756'
CLIENT_SECRET = '628a3ebb227a4a46a8cdc6cc44327ee6'
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
paises_europa_central = {
    "AT": "Austria",
    "DE": "Alemania",
    "CH": "Suiza",
    "LI": "Liechtenstein",
    "BE": "Bélgica",
    "LU": "Luxemburgo",
    "NL": "Países Bajos"}

# %%
#datos_rango = sp.search(q = "year:2020-2024", limit=50, offset=0, type='track', market="ES")

# %%
def extraccion_por_paises(diccionario_zonas, años):
    todos_los_datos = [] # Esto es una lista de dicts donde se van guardando los diccionarios de cada país
    for pais in diccionario_zonas.keys():
        datos_rango = sp.search(q = f'year:{años}', limit=50, offset=0, type='track', market={pais}) # Cada una tiene que cambiar en q el rango de años
        datos_por_pais = {}
        datos_por_pais['pais'] = pais
        datos_por_pais['datos'] = datos_rango
        todos_los_datos.append(datos_por_pais)
    return todos_los_datos

# %%
lista_datos_zonas = extraccion_por_paises(paises_europa_central, "2020-2024")

# %%
for element in lista_datos_zonas:
    print(element)
# Out:
# {'pais': 'AT', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=AT', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eGuHhstHEA8ipdVjsimYR'}, 'href': 'https://api.spotify.com/v1/artists/7eGuHhstHEA8ipdVjsimYR', 'id': '7eGuHhstHEA8ipdVjsimYR', 'name': 'Oimara', 'type': 'artist', 'uri': 'spotify:artist:7eGuHhstHEA8ipdVjsimYR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/2ntNmfYAflWmhxMiX9sReB'}, 'href': 'https://api.spotify.com/v1/albums/2ntNmfYAflWmhxMiX9sReB', 'id': '2ntNmfYAflWmhxMiX9sReB', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27389b9e48b79603248d4fea627'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0289b9e48b79603248d4fea627'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485189b9e48b79603248d4fea627'}], 'is_playable': True, 'name': 'Wackelkontakt', 'release_date': '2024-08-02', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:2ntNmfYAflWmhxMiX9sReB'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eGuHhstHEA8ipdVjsimYR'}, 'href': 'https://api.spotify.com/v1/artists/7eGuHhstHEA8ipdVjsimYR', 'id': '7eGuHhstHEA8ipdVjsimYR', 'name': 'Oimara', 'type': 'artist', 'uri': 'spotify:artist:7eGuHhstHEA8ipdVjsimYR'}], 'disc_number': 1, 'duration_ms': 168801, 'explicit': False, 'external_ids': {'isrc': 'DEW242400081'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4x7j9ed3FRH6CHj27kiTQ3'}, 'href': 'https://api.spotify.com/v1/tracks/4x7j9ed3FRH6CHj27kiTQ3', 'id': '4x7j9ed3FRH6CHj27kiTQ3', 'is_local': False, 'is_playable': True, 'name': 'Wackelkontakt', 'popularity': 78, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:4x7j9ed3FRH6CHj27kiTQ3'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3t5xRXzsuZmMDkQzgOX35S'}, 'href': 'https://api.spotify.com/v1/artists/3t5xRXzsuZmMDkQzgOX35S', 'id': '3t5xRXzsuZmMDkQzgOX35S', 'name': 'Robin Schulz', 'type': 'artist', 'uri': 'spotify:artist:3t5xRXzsuZmMDkQzgOX35S'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3lLDZNIMUmxMzIE6Vz9Agz'}, 'href': 'https://api.spotify.com/v1/artists/3lLDZNIMUmxMzIE6Vz9Agz', 'id': '3lLDZNIMUmxMzIE6Vz9Agz', 'name': 'KIDDO', 'type': 'artist', 'uri': 'spotify:artist:3lLDZNIMUmxMzIE6Vz9Agz'}], 'disc_number': 1, 'duration_ms': 206613, 'explicit': False, 'external_ids': {'isrc': 'DEA622000935'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5cRUtzkNNqkQblvQYUVH2U'}, 'href': 'https://api.spotify.com/v1/tracks/5cRUtzkNNqkQblvQYUVH2U', 'id': '5cRUtzkNNqkQblvQYUVH2U', 'is_local': False, 'is_playable': False, 'name': 'All We Got (feat. KIDDO)', 'popularity': 14, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5cRUtzkNNqkQblvQYUVH2U'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'} ...
# {'pais': 'DE', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=DE', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eGuHhstHEA8ipdVjsimYR'}, 'href': 'https://api.spotify.com/v1/artists/7eGuHhstHEA8ipdVjsimYR', 'id': '7eGuHhstHEA8ipdVjsimYR', 'name': 'Oimara', 'type': 'artist', 'uri': 'spotify:artist:7eGuHhstHEA8ipdVjsimYR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/2ntNmfYAflWmhxMiX9sReB'}, 'href': 'https://api.spotify.com/v1/albums/2ntNmfYAflWmhxMiX9sReB', 'id': '2ntNmfYAflWmhxMiX9sReB', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27389b9e48b79603248d4fea627'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0289b9e48b79603248d4fea627'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485189b9e48b79603248d4fea627'}], 'is_playable': True, 'name': 'Wackelkontakt', 'release_date': '2024-08-02', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:2ntNmfYAflWmhxMiX9sReB'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eGuHhstHEA8ipdVjsimYR'}, 'href': 'https://api.spotify.com/v1/artists/7eGuHhstHEA8ipdVjsimYR', 'id': '7eGuHhstHEA8ipdVjsimYR', 'name': 'Oimara', 'type': 'artist', 'uri': 'spotify:artist:7eGuHhstHEA8ipdVjsimYR'}], 'disc_number': 1, 'duration_ms': 168801, 'explicit': False, 'external_ids': {'isrc': 'DEW242400081'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4x7j9ed3FRH6CHj27kiTQ3'}, 'href': 'https://api.spotify.com/v1/tracks/4x7j9ed3FRH6CHj27kiTQ3', 'id': '4x7j9ed3FRH6CHj27kiTQ3', 'is_local': False, 'is_playable': True, 'name': 'Wackelkontakt', 'popularity': 78, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:4x7j9ed3FRH6CHj27kiTQ3'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3t5xRXzsuZmMDkQzgOX35S'}, 'href': 'https://api.spotify.com/v1/artists/3t5xRXzsuZmMDkQzgOX35S', 'id': '3t5xRXzsuZmMDkQzgOX35S', 'name': 'Robin Schulz', 'type': 'artist', 'uri': 'spotify:artist:3t5xRXzsuZmMDkQzgOX35S'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3lLDZNIMUmxMzIE6Vz9Agz'}, 'href': 'https://api.spotify.com/v1/artists/3lLDZNIMUmxMzIE6Vz9Agz', 'id': '3lLDZNIMUmxMzIE6Vz9Agz', 'name': 'KIDDO', 'type': 'artist', 'uri': 'spotify:artist:3lLDZNIMUmxMzIE6Vz9Agz'}], 'disc_number': 1, 'duration_ms': 206613, 'explicit': False, 'external_ids': {'isrc': 'DEA622000935'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5cRUtzkNNqkQblvQYUVH2U'}, 'href': 'https://api.spotify.com/v1/tracks/5cRUtzkNNqkQblvQYUVH2U', 'id': '5cRUtzkNNqkQblvQYUVH2U', 'is_local': False, 'is_playable': False, 'name': 'All We Got (feat. KIDDO)', 'popularity': 14, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5cRUtzkNNqkQblvQYUVH2U'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'} ...
# {'pais': 'CH', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=CH', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 50, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}, 'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N', 'id': '10FLjwfpbxLmW8c25Xyc2N', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}], 'is_playable': True, 'name': 'Die With A Smile', 'release_date': '2024-08-16', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'disc_number': 1, 'duration_ms': 251667, 'explicit': False, 'external_ids': {'isrc': 'USUM72409273'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'}, 'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe', 'id': '2plbrEY59IikOBgBGLjaoe', 'is_local': False, 'is_playable': True, 'name': 'Die With A Smile', 'popularity': 96, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3t5xRXzsuZmMDkQzgOX35S'}, 'href': 'https://api.spotify.com/v1/artists/3t5xRXzsuZmMDkQzgOX35S', 'id': '3t5xRXzsuZmMDkQzgOX35S', 'name': 'Robin Schulz', 'type': 'artist', 'uri': 'spotify:artist:3t5xRXzsuZmMDkQzgOX35S'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3lLDZNIMUmxMzIE6Vz9Agz'}, 'href': 'https://api.spotify.com/v1/artists/3lLDZNIMUmxMzIE6Vz9Agz', 'id': '3lLDZNIMUmxMzIE6Vz9Agz', 'name': 'KIDDO', 'type': 'artist', 'uri': 'spotify:artist:3lLDZNIMUmxMzIE6Vz9Agz'}], 'disc_number': 1, 'duration_ms': 206613, 'explicit': False, 'external_ids': {'isrc': 'DEA622000935'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5cRUtzkNNqkQblvQYUVH2U'}, 'href': 'https://api.spotify.com/v1/tracks/5cRUtzkNNqkQblvQYUVH2U', 'id': '5cRUtzkNNqkQblvQYUVH2U', 'is_local': False, 'is_playable': False, 'name': 'All We Got (feat. KIDDO)', 'popularity': 14, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5cRUtzkNNqkQblvQYUVH2U'}, {'album': {'album_type': 'album' ...
# {'pais': 'LI', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=LI', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=LI', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}, 'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N', 'id': '10FLjwfpbxLmW8c25Xyc2N', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}], 'is_playable': True, 'name': 'Die With A Smile', 'release_date': '2024-08-16', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'disc_number': 1, 'duration_ms': 251667, 'explicit': False, 'external_ids': {'isrc': 'USUM72409273'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'}, 'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe', 'id': '2plbrEY59IikOBgBGLjaoe', 'is_local': False, 'is_playable': True, 'name': 'Die With A Smile', 'popularity': 96, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28WNtilgFPn1mdz3h0FjHl'}, 'href': 'https://api.spotify.com/v1/artists/28WNtilgFPn1mdz3h0FjHl', 'id': '28WNtilgFPn1mdz3h0FjHl', 'name': 'Mackenzy Mackay', 'type': 'artist', 'uri': 'spotify:artist:28WNtilgFPn1mdz3h0FjHl'}], 'disc_number': 1, 'duration_ms': 147968, 'explicit': False, 'external_ids': {'isrc': 'GB1102401536'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3o1zb91zucIFu6TB51HaR6'}, 'href': 'https://api.spotify.com/v1/tracks/3o1zb91zucIFu6TB51HaR6', 'id': '3o1zb91zucIFu6TB51HaR6', 'is_local': False, 'is_playable': False, 'name': 'Postcards - Acoustic Version', 'popularity': 1, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:3o1zb91zucIFu6TB51HaR6'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',  ...
# {'pais': 'BE', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=BE', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=BE', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}, 'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N', 'id': '10FLjwfpbxLmW8c25Xyc2N', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}], 'is_playable': True, 'name': 'Die With A Smile', 'release_date': '2024-08-16', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'disc_number': 1, 'duration_ms': 251667, 'explicit': False, 'external_ids': {'isrc': 'USUM72409273'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'}, 'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe', 'id': '2plbrEY59IikOBgBGLjaoe', 'is_local': False, 'is_playable': True, 'name': 'Die With A Smile', 'popularity': 96, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bM ...
# {'pais': 'LU', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=LU', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=LU', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11oaKJc8rsz6x8YPVjca4X'}, 'href': 'https://api.spotify.com/v1/artists/11oaKJc8rsz6x8YPVjca4X', 'id': '11oaKJc8rsz6x8YPVjca4X', 'name': 'Engel Montaz', 'type': 'artist', 'uri': 'spotify:artist:11oaKJc8rsz6x8YPVjca4X'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/14Hne9pWpQnWu7SxVcapIT'}, 'href': 'https://api.spotify.com/v1/albums/14Hne9pWpQnWu7SxVcapIT', 'id': '14Hne9pWpQnWu7SxVcapIT', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b174a1512ca42db344dca2fd'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b174a1512ca42db344dca2fd'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b174a1512ca42db344dca2fd'}], 'is_playable': True, 'name': 'Desire', 'release_date': '2024-07-10', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:14Hne9pWpQnWu7SxVcapIT'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11oaKJc8rsz6x8YPVjca4X'}, 'href': 'https://api.spotify.com/v1/artists/11oaKJc8rsz6x8YPVjca4X', 'id': '11oaKJc8rsz6x8YPVjca4X', 'name': 'Engel Montaz', 'type': 'artist', 'uri': 'spotify:artist:11oaKJc8rsz6x8YPVjca4X'}], 'disc_number': 1, 'duration_ms': 186666, 'explicit': True, 'external_ids': {'isrc': 'BK4DA2416093'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4h3i4yz7mkw1H9XG9VMkjQ'}, 'href': 'https://api.spotify.com/v1/tracks/4h3i4yz7mkw1H9XG9VMkjQ', 'id': '4h3i4yz7mkw1H9XG9VMkjQ', 'is_local': False, 'is_playable': True, 'name': 'Vibrador', 'popularity': 68, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:4h3i4yz7mkw1H9XG9VMkjQ'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3L774tiJRvPmAS90pOLB44'}, 'href': 'https://api.spotify.com/v1/artists/3L774tiJRvPmAS90pOLB44', 'id': '3L774tiJRvPmAS90pOLB44', 'name': 'Rsko', 'type': 'artist', 'uri': 'spotify:artist:3L774tiJRvPmAS90pOLB44'}], 'disc_number': 1, 'duration_ms': 266645, 'explicit': True, 'external_ids': {'isrc': 'FR1A92403470'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5mMLix9brBOzvDfTaZmQq9'}, 'href': 'https://api.spotify.com/v1/tracks/5mMLix9brBOzvDfTaZmQq9', 'id': '5mMLix9brBOzvDfTaZmQq9', 'is_local': False, 'is_playable': False, 'name': 'Oublier', 'popularity': 1, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:5mMLix9brBOzvDfTaZmQq9'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11oaKJc8rsz6x8YPVjca4X'}, 'href': 'https://api.spotify.com/v1/artists/11oaKJc8rsz6x8YPVjca4X', 'id': '11oaKJc8rsz6x8YPVjca4X', 'name': 'Engel Montaz', 'type': 'artist', 'uri': 'spotify:artist:11oaKJc8rsz6x8YPVjca4X'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/14Hne9pWpQnWu7SxVcapIT'}, 'href': 'https://api.spotify.com/v1/albums/14Hne9pWpQnWu7SxVcapIT', 'id': '14Hne9pWpQnWu7SxVcapIT', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b174a1512ca42db344dca2fd'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b174a1512ca42db344dca2fd'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d00 ...
# {'pais': 'NL', 'datos': {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=year%3A2020-2024&type=track&market=NL', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=year%3A2020-2024&type=track&market=NL', 'offset': 0, 'previous': None, 'total': 1000, 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'}, 'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N', 'id': '10FLjwfpbxLmW8c25Xyc2N', 'images': [{'height': 640, 'width': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'}, {'height': 300, 'width': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'}, {'height': 64, 'width': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}], 'is_playable': True, 'name': 'Die With A Smile', 'release_date': '2024-08-16', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}, 'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C', 'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars', 'type': 'artist', 'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}], 'disc_number': 1, 'duration_ms': 251667, 'explicit': False, 'external_ids': {'isrc': 'USUM72409273'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'}, 'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe', 'id': '2plbrEY59IikOBgBGLjaoe', 'is_local': False, 'is_playable': True, 'name': 'Die With A Smile', 'popularity': 96, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'}, {'album': {'album_type': 'album', 'artists': None, 'external_urls': {'spotify': 'https://open.spotify.com/album/null'}, 'href': 'https://api.spotify.com/v1/albums/null', 'id': None, 'images': [], 'name': None, 'release_date': '0000', 'release_date_precision': 'year', 'total_tracks': None, 'type': 'album', 'uri': None}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5', 'id': '4tuJ0bMpJh08umKkEXKUI5', 'name': 'Gracie Abrams', 'type': 'artist', 'uri': 'spotify:artist:4tuJ0bMpJh08umKkEXKUI5'}], 'disc_number': 1, 'duration_ms': 217809, 'explicit': True, 'external_ids': {'isrc': 'USUMV2403959'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/54yB91VOJg6DeH9A101Iw6'}, 'href': 'https://api.spotify.com/v1/tracks/54yB91VOJg6DeH9A101Iw6', 'id': '54yB91VOJg6DeH9A101Iw6', 'is_local': False, 'is_playable': False, 'name': 'That’s So True - Live From Radio City Music Hall', 'popularity': 20, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:54yB91VOJg6DeH9A101Iw6'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'}, 'href': 'https://api.spotify.com/v1/artists/4tuJ0bM ...

# %% [markdown]
# ## 1.1. Filtrar ahora los datos que hemos sacado

# %%
# Un intento de función con el bucle de arriba:

# %%
def filtro_de_datos(lista_datos_zonas, datos):
    for datos_pais in lista_datos_zonas:
            for element in datos_pais['datos']['tracks']['items']:
                datos['pais'].append(datos_pais['pais'])
                datos['popularity'].append(element['popularity'])
                datos['nombre'].append(element['name'])
                
                artistas = []
                for artista in element['artists']:
                    artistas.append(artista['name'])   
                artistas_str = ', '.join(artistas)
                datos['artista'].append(artistas_str)

# %%
ext_central= extraccion_por_paises(paises_europa_central, '2020-2024')

# %%
dic_central = {'nombre': [], 'popularity': [], 'artista': [], 'pais': [], 'genero': []}

# %%
filtro_de_datos(ext_central, dic_central)

# %%
dic_central
# Out:
# {'nombre': ['Wackelkontakt',
#   'All We Got (feat. KIDDO)',
#   'Die With A Smile',
#   'That’s So True - Live From Radio City Music Hall',
#   'That’s So True',
#   '04:30',
#   'APT.',
#   'Hurt',
#   'BIRDS OF A FEATHER',
#   'Circles',
#   'Not Like Us',
#   'Das riecht gut / Ça Sent Bon',
#   'Sailor Song',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'The Emptiness Machine',
#   'Selfmade Babylon',
#   'The Days - NOTION Remix',
#   'Postcards - Acoustic Version',
#   'Verwandtschaftstreffen',
#   "Don't Play by the Rules",
#   'Good Luck, Babe!',
#   'Passenger Princess',
#   'WILDFLOWER',
#   'Aimer à moitié',
#   'Ma Baby',
#   'Rodeo (Remix)',
#   'Timeless (feat. Playboi Carti)',
#   'Schifoan',
#   'tv off (feat. lefty gunplay)',
#   'EA2 (The Beginning of the Era)',
#   'Messy',
#   'Little Window - Live Studio Session',
#   'The Emptiness Machine',
#   'Anders',
#   'ALL IN (Lieblingslieder)',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'I Adore You (feat. Daecolm)',
#   'Egoist - Live At Elbphilharmonie Hamburg',
#   'eehhhyyy',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Kisses (feat. bbyclose)',
#   "Un'estate normale",
#   "Stumblin' In",
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Fata Morgana',
#   'Bank of Wildflowers (feat. Georgia)',
#   'APT.',
#   'Bruder',
#   'DENIAL IS A RIVER',
#   'Party Jumpin’',
#   'Wackelkontakt',
#   'All We Got (feat. KIDDO)',
#   'Die With A Smile',
#   'Selfmade Babylon',
#   'APT.',
#   '04:30',
#   'That’s So True',
#   'That’s So True - Live From Radio City Music Hall',
#   'Not Like Us',
#   'Das riecht gut / Ça Sent Bon',
#   'Fata Morgana',
#   'Hurt',
#   'BIRDS OF A FEATHER',
#   'Rodeo (Remix)',
#   'Ma Baby',
#   'Circles',
#   'The Days - NOTION Remix',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Sailor Song',
#   'Anders',
#   'The Emptiness Machine',
#   'Bruder',
#   'eehhhyyy',
#   'Schifoan',
#   'I Adore You (feat. Daecolm)',
#   "Don't Play by the Rules",
#   'Rote Flaggen',
#   'Passenger Princess',
#   'Timeless (feat. Playboi Carti)',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Kisses (feat. bbyclose)',
#   'Aimer à moitié',
#   'Butcher',
#   'Postcards - Acoustic Version',
#   'WILDFLOWER',
#   'Little Window - Live Studio Session',
#   'Messy',
#   'Babylon - Live',
#   'tv off (feat. lefty gunplay)',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'The Emptiness Machine',
#   'Family Feud - Live at The Ford',
#   'PLAYBOYBUNNIES',
#   'Elixir',
#   'Thank You (Not So Bad)',
#   'Rid Of Me - Live',
#   'Vois sur ton chemin - Techno Mix',
#   'ARIES "The Charismatic" - Official Piano Tutorial',
#   'Good Luck, Babe!',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Die With A Smile',
#   'All We Got (feat. KIDDO)',
#   'That’s So True',
#   'Hurt',
#   'APT.',
#   'That’s So True - Live From Radio City Music Hall',
#   'BIRDS OF A FEATHER',
#   'Oublier',
#   'Not Like Us',
#   '04:30',
#   'Wackelkontakt',
#   'Aimer à moitié',
#   'Sailor Song',
#   'Circles',
#   'I Adore You (feat. Daecolm)',
#   'Das riecht gut / Ça Sent Bon',
#   'Si Antes Te Hubiera Conocido',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'WILDFLOWER',
#   'Passenger Princess',
#   'Messy',
#   'Rodeo (Remix)',
#   'Timeless (feat. Playboi Carti)',
#   'Little Window - Live Studio Session',
#   'tv off (feat. lefty gunplay)',
#   'Party Jumpin’',
#   'Lose Control',
#   'Selfmade Babylon',
#   'Beautiful Things',
#   'Postcards - Acoustic Version',
#   'Move',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'APT.',
#   'TV - Live From Singapore’s Cloud Forest',
#   "Stumblin' In",
#   "I Ain't Sayin' - Performance",
#   'Good Luck, Babe!',
#   "Don't Play by the Rules",
#   'The Sound of Silence - CYRIL Remix',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Black Friday (pretty like the sun)',
#   'Dingue de toi (Turn me on) [feat. Dana]',
#   'NANANI NANANA',
#   'Babylon - Live',
#   'Gata Only',
#   'EA2 (The Beginning of the Era)',
#   "I Don't Wanna Wait",
#   'Tuck Your Chain',
#   'Bad Dreams',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Die With A Smile',
#   'Postcards - Acoustic Version',
#   'BIRDS OF A FEATHER',
#   'All We Got (feat. KIDDO)',
#   'Not Like Us',
#   'That’s So True - Live From Radio City Music Hall',
#   'That’s So True',
#   'Hurt',
#   'Clean Baby Sleep White Noise (Loopable)',
#   '04:30',
#   'APT.',
#   'Babylon - Live',
#   'tv off (feat. lefty gunplay)',
#   'Lindo Momento',
#   'WILDFLOWER',
#   'Seu Astral / Mistérios',
#   'Sailor Song',
#   'Rodeo (Remix)',
#   'Good Luck, Babe!',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'luther (with sza)',
#   'Circles',
#   'luther (with sza)',
#   'Selfmade Babylon',
#   'DENIAL IS A RIVER',
#   'Standard',
#   'Si Antes Te Hubiera Conocido',
#   'Passenger Princess',
#   'APT.',
#   'Tussi Code Mari',
#   'squabble up',
#   'Pasatiempo',
#   'Timeless (feat. Playboi Carti)',
#   'Das riecht gut / Ça Sent Bon',
#   'One Of The Girls (with JENNIE, Lily Rose Depp)',
#   'Dużo Ciebie Mi',
#   'Like Him (feat. Lola Young)',
#   'Fam*ly (feat. Tiji Jojo, DADA & LEX)',
#   'Messy',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'blue',
#   'Little Window - Live Studio Session',
#   'Qué Pasaría...',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Taste',
#   'Rid Of Me - Live',
#   'Loco',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Who',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Die With A Smile',
#   'That’s So True - Live From Radio City Music Hall',
#   'That’s So True',
#   'All We Got (feat. KIDDO)',
#   'APT.',
#   'Oublier',
#   'BIRDS OF A FEATHER',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Sailor Song',
#   'Hurt',
#   'Beautiful Things',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Messy',
#   'Babylon - Live',
#   'Not Like Us',
#   'Aimer à moitié',
#   'Dirty Cash (Money Talks)',
#   'TV - Live From Singapore’s Cloud Forest',
#   'Born With a Broken Heart',
#   "Ballade Vir 'n Enkeling - Live At Mothership Studios",
#   'CIEL',
#   'Circles',
#   'WILDFLOWER',
#   'crocodile tears',
#   'NANANI NANANA',
#   'Ek Verlang Na Jou - Live at Mothership Studios',
#   'Lose Control',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Kisses (feat. bbyclose)',
#   "J'suis mal",
#   'Black Friday (pretty like the sun)',
#   'Indigo Girl - Live at Mothership Studios',
#   'Mauvais Garçon',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'The Emptiness Machine',
#   'Passenger Princess',
#   'Carry You Home',
#   'Rodeo (Remix)',
#   'Messy',
#   'Dingue de toi (Turn me on) [feat. Dana]',
#   'I Adore You (feat. Daecolm)',
#   'Little Window - Live Studio Session',
#   'Good Luck, Babe!',
#   'Family Feud - Live at The Ford',
#   'Si Antes Te Hubiera Conocido',
#   "Don't Play by the Rules",
#   'CIEL',
#   'Postcards - Acoustic Version',
#   'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#   'Meisie Wat Haar Potlood Kou - Live at Mothership Studios',
#   'Vibrador',
#   'Oublier',
#   'Cupido',
#   'Aimer à moitié',
#   'Kikito',
#   'All We Got (feat. KIDDO)',
#   'Die With A Smile',
#   'Hurt',
#   'APT.',
#   'Kreepin',
#   'BIRDS OF A FEATHER',
#   '04:30',
#   'That’s So True',
#   'Das riecht gut / Ça Sent Bon',
#   'Not Like Us',
#   'That’s So True - Live From Radio City Music Hall',
#   'Beautiful Things',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'The Emptiness Machine',
#   'Lindo Momento',
#   'Sailor Song',
#   'Tarde Demais',
#   'NANANI NANANA',
#   "Don't Play by the Rules",
#   'Messy',
#   "J'suis mal",
#   'Si Antes Te Hubiera Conocido',
#   'Dingue de toi (Turn me on) [feat. Dana]',
#   'Sujeito Homem - Ao Vivo',
#   'Party Jumpin’',
#   'I Adore You (feat. Daecolm)',
#   'Rodeo (Remix)',
#   'WILDFLOWER',
#   'Standard',
#   'tv off (feat. lefty gunplay)',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Wackelkontakt',
#   'Circles',
#   'Lose Control',
#   'Seu Astral / Mistérios',
#   'Timeless (feat. Playboi Carti)',
#   'EA2 (The Beginning of the Era)',
#   '4 Kampé',
#   'Bruder',
#   'Good Luck, Babe!',
#   'Postcards - Acoustic Version',
#   'APT.',
#   'Passenger Princess',
#   'Move',
#   'RESPECT MY MOOD (Official Music Video)',
#   'Die With A Smile',
#   'That’s So True - Live From Radio City Music Hall',
#   'That’s So True',
#   'All We Got (feat. KIDDO)',
#   'BIRDS OF A FEATHER',
#   'Hurt',
#   'Clean Baby Sleep White Noise (Loopable)',
#   'Risk - Live From The Tonight Show With Jimmy Fallon',
#   'Terug In De Tijd',
#   'Circles',
#   'Dirty Cash (Money Talks)',
#   'Rid Of Me - Live',
#   'APT.',
#   'Babylon - Live',
#   'Alleen Met Jou',
#   'Rodeo (Remix)',
#   'Blikkendag',
#   "Ballade Vir 'n Enkeling - Live At Mothership Studios",
#   'Messy',
#   'Little Window - Live Studio Session',
#   'Spijt Is Voor Later',
#   'Passenger Princess',
#   'Still Into You',
#   'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#   'Sailor Song',
#   'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#   'Told You So',
#   'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#   'Not Like Us',
#   'Ek Verlang Na Jou - Live at Mothership Studios',
#   'Lose Control',
#   'Family Feud - Live at The Ford',
#   'I Surrender - Remix',
#   'ILMSY (MOVES)',
#   'SOS',
#   "Don't Play by the Rules",
#   'Carry You Home',
#   'Meisie Wat Haar Potlood Kou - Live at Mothership Studios',
#   'Hier Mag Alles',
#   'Indigo Girl - Live at Mothership Studios',
#   'I Adore You (feat. Daecolm)',
#   'Party Jumpin’',
#   'Black Friday (pretty like the sun)',
#   'Oublier',
#   'Zoet, Zout, Zuur',
#   'Aimer à moitié',
#   'Love Somebody',
#   'FAKE - BRITs 2022 Rising Star Live Session',
#   'WILDFLOWER',
#   'Bank of Wildflowers (feat. Georgia)'],
#  'popularity': [78,
#   14,
#   96,
#   20,
#   91,
#   7,
#   91,
#   12,
#   93,
#   7,
#   92,
#   4,
#   89,
#   8,
#   78,
#   6,
#   84,
#   1,
#   63,
#   3,
#   89,
#   6,
#   90,
#   2,
#   69,
#   9,
#   87,
#   1,
#   90,
#   1,
#   86,
#   3,
#   78,
#   0,
#   65,
#   3,
#   80,
#   0,
#   67,
#   3,
#   79,
#   0,
#   79,
#   3,
#   70,
#   0,
#   87,
#   0,
#   88,
#   2,
#   78,
#   14,
#   96,
#   6,
#   91,
#   7,
#   91,
#   20,
#   92,
#   4,
#   70,
#   12,
#   93,
#   9,
#   69,
#   7,
#   84,
#   8,
#   89,
#   0,
#   78,
#   0,
#   67,
#   1,
#   80,
#   3,
#   67,
#   6,
#   87,
#   3,
#   79,
#   2,
#   67,
#   1,
#   90,
#   3,
#   86,
#   4,
#   90,
#   3,
#   78,
#   2,
#   67,
#   1,
#   78,
#   3,
#   75,
#   0,
#   89,
#   3,
#   96,
#   14,
#   91,
#   12,
#   91,
#   20,
#   93,
#   1,
#   92,
#   7,
#   78,
#   2,
#   89,
#   7,
#   80,
#   4,
#   87,
#   8,
#   90,
#   6,
#   86,
#   9,
#   87,
#   3,
#   90,
#   2,
#   85,
#   6,
#   85,
#   1,
#   80,
#   3,
#   87,
#   3,
#   79,
#   2,
#   89,
#   3,
#   78,
#   3,
#   78,
#   0,
#   74,
#   4,
#   82,
#   1,
#   80,
#   0,
#   80,
#   3,
#   96,
#   1,
#   93,
#   14,
#   92,
#   20,
#   91,
#   12,
#   91,
#   7,
#   91,
#   4,
#   90,
#   21,
#   90,
#   11,
#   89,
#   9,
#   89,
#   8,
#   89,
#   7,
#   88,
#   6,
#   88,
#   6,
#   87,
#   6,
#   87,
#   5,
#   87,
#   4,
#   87,
#   4,
#   87,
#   4,
#   86,
#   3,
#   86,
#   3,
#   86,
#   3,
#   86,
#   3,
#   86,
#   3,
#   86,
#   3,
#   86,
#   3,
#   96,
#   20,
#   91,
#   14,
#   91,
#   1,
#   93,
#   8,
#   89,
#   12,
#   85,
#   3,
#   86,
#   4,
#   92,
#   2,
#   78,
#   3,
#   77,
#   1,
#   72,
#   7,
#   90,
#   0,
#   74,
#   0,
#   85,
#   3,
#   79,
#   0,
#   78,
#   0,
#   69,
#   3,
#   78,
#   6,
#   79,
#   9,
#   83,
#   0,
#   80,
#   3,
#   89,
#   2,
#   87,
#   3,
#   71,
#   1,
#   79,
#   0,
#   68,
#   1,
#   66,
#   2,
#   63,
#   14,
#   96,
#   12,
#   91,
#   0,
#   93,
#   7,
#   91,
#   4,
#   92,
#   20,
#   85,
#   3,
#   78,
#   21,
#   89,
#   0,
#   74,
#   3,
#   86,
#   0,
#   87,
#   0,
#   76,
#   2,
#   80,
#   9,
#   90,
#   6,
#   90,
#   8,
#   78,
#   7,
#   85,
#   11,
#   87,
#   1,
#   73,
#   0,
#   89,
#   1,
#   87,
#   6,
#   80,
#   0,
#   96,
#   20,
#   91,
#   14,
#   93,
#   12,
#   91,
#   8,
#   65,
#   7,
#   78,
#   3,
#   91,
#   4,
#   64,
#   9,
#   63,
#   1,
#   86,
#   3,
#   63,
#   6,
#   75,
#   3,
#   89,
#   3,
#   72,
#   3,
#   92,
#   0,
#   85,
#   2,
#   61,
#   0,
#   61,
#   3,
#   79,
#   0,
#   61,
#   0,
#   80,
#   2,
#   78,
#   1,
#   61,
#   2,
#   81,
#   1,
#   90,
#   0],
#  'artista': ['Oimara',
#   'Robin Schulz, KIDDO',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Gracie Abrams',
#   'Haze, Mucco',
#   'ROSÉ, Bruno Mars',
#   'OneRepublic',
#   'Billie Eilish',
#   'SAINt JHN',
#   'Kendrick Lamar',
#   'Team Karacho, Roger Rekless',
#   'Gigi Perez',
#   'Gracie Abrams',
#   'Linkin Park',
#   'Bausa, Bozza',
#   'Chrystal, NOTION',
#   'Mackenzy Mackay',
#   'RIAN',
#   'D.T.E, PREZIOSO',
#   'Chappell Roan',
#   'Aminé, Smino',
#   'Billie Eilish',
#   'Calema',
#   'Jazeek',
#   'Lah Pat, Flo Milli',
#   'The Weeknd, Playboi Carti',
#   'Felix Harrer, Leopold Franz',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Lil Uzi Vert',
#   'Lola Young',
#   'FINNEAS',
#   'Linkin Park',
#   'Tommy',
#   'Fäaschtbänkler',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'HUGEL, Topic, Arash, Daecolm',
#   'JEREMIAS',
#   'Zartmann, Drumla, Dauner',
#   'Billie Eilish',
#   'BL3SS, CamrinWatsin, bbyclose',
#   'Nek',
#   'CYRIL',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Nina Chuba',
#   'William Orbit, Georgia',
#   'ROSÉ, Bruno Mars',
#   'Nico K.I.Z, Yassin',
#   'Doechii',
#   'Jamie Brown, Marshmello',
#   'Oimara',
#   'Robin Schulz, KIDDO',
#   'Lady Gaga, Bruno Mars',
#   'Bausa, Bozza',
#   'ROSÉ, Bruno Mars',
#   'Haze, Mucco',
#   'Gracie Abrams',
#   'Gracie Abrams',
#   'Kendrick Lamar',
#   'Team Karacho, Roger Rekless',
#   'Nina Chuba',
#   'OneRepublic',
#   'Billie Eilish',
#   'Lah Pat, Flo Milli',
#   'Jazeek',
#   'SAINt JHN',
#   'Chrystal, NOTION',
#   'Gracie Abrams',
#   'Gigi Perez',
#   'Tommy',
#   'Linkin Park',
#   'Nico K.I.Z, Yassin',
#   'Zartmann, Drumla, Dauner',
#   'Felix Harrer, Leopold Franz',
#   'HUGEL, Topic, Arash, Daecolm',
#   'D.T.E, PREZIOSO',
#   'Berq',
#   'Aminé, Smino',
#   'The Weeknd, Playboi Carti',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'BL3SS, CamrinWatsin, bbyclose',
#   'Calema',
#   'Sosa La M, Luciano',
#   'Mackenzy Mackay',
#   'Billie Eilish',
#   'FINNEAS',
#   'Lola Young',
#   'Tamino',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Billie Eilish',
#   'Linkin Park',
#   'FINNEAS',
#   'Jazeek, Luciano, Miksu / Macloud',
#   'Tommy Saint',
#   'Dimitri Vegas & Like Mike, Tiësto, Dido, W&W, Dimitri Vegas, Like Mike',
#   'Still Woozy',
#   'BENNETT',
#   'Tony Ann',
#   'Chappell Roan',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Lady Gaga, Bruno Mars',
#   'Robin Schulz, KIDDO',
#   'Gracie Abrams',
#   'OneRepublic',
#   'ROSÉ, Bruno Mars',
#   'Gracie Abrams',
#   'Billie Eilish',
#   'Rsko',
#   'Kendrick Lamar',
#   'Haze, Mucco',
#   'Oimara',
#   'Calema',
#   'Gigi Perez',
#   'SAINt JHN',
#   'HUGEL, Topic, Arash, Daecolm',
#   'Team Karacho, Roger Rekless',
#   'KAROL G',
#   'Gracie Abrams',
#   'Billie Eilish',
#   'Aminé, Smino',
#   'Lola Young',
#   'Lah Pat, Flo Milli',
#   'The Weeknd, Playboi Carti',
#   'FINNEAS',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Jamie Brown, Marshmello',
#   'Teddy Swims',
#   'Bausa, Bozza',
#   'Benson Boone',
#   'Mackenzy Mackay',
#   'Adam Port, Stryv, Keinemusik, Orso, Malachiii',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'ROSÉ, Bruno Mars',
#   'Billie Eilish',
#   'CYRIL',
#   'Jordan Davis',
#   'Chappell Roan',
#   'D.T.E, PREZIOSO',
#   'Disturbed, CYRIL',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Lost Frequencies, Tom Odell',
#   'Alexy Large, Dana',
#   'Gazo',
#   'Tamino',
#   'FloyyMenor, Cris Mj',
#   'Lil Uzi Vert',
#   'David Guetta, OneRepublic',
#   'Money Man, Danny Towers',
#   'Teddy Swims',
#   'Billie Eilish',
#   'Lady Gaga, Bruno Mars',
#   'Mackenzy Mackay',
#   'Billie Eilish',
#   'Robin Schulz, KIDDO',
#   'Kendrick Lamar',
#   'Gracie Abrams',
#   'Gracie Abrams',
#   'OneRepublic',
#   'Dream Supplier, Baby Sleeps, Background White Noise',
#   'Haze, Mucco',
#   'ROSÉ, Bruno Mars',
#   'Tamino',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Julliany Souza',
#   'Billie Eilish',
#   'Fiorella',
#   'Gigi Perez',
#   'Lah Pat, Flo Milli',
#   'Chappell Roan',
#   'Gracie Abrams',
#   'Kendrick Lamar, SZA',
#   'SAINt JHN',
#   'Kendrick Lamar, SZA',
#   'Bausa, Bozza',
#   'Doechii',
#   'Einar, A36',
#   'KAROL G',
#   'Aminé, Smino',
#   'ROSÉ, Bruno Mars',
#   'Marcianeke, Crismj',
#   'Kendrick Lamar',
#   'La China, ECKO',
#   'The Weeknd, Playboi Carti',
#   'Team Karacho, Roger Rekless',
#   'The Weeknd, JENNIE, Lily-Rose Depp',
#   'Lemon',
#   'Tyler, The Creator, Lola Young',
#   'BAD HOP, Tiji Jojo, Dada, LEX',
#   'Lola Young',
#   'Billie Eilish',
#   'yung kai',
#   'FINNEAS',
#   'Rauw Alejandro, Bad Bunny',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Sabrina Carpenter',
#   'Still Woozy',
#   'Neton Vega',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Jimin',
#   'Billie Eilish',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Gracie Abrams',
#   'Robin Schulz, KIDDO',
#   'ROSÉ, Bruno Mars',
#   'Rsko',
#   'Billie Eilish',
#   'Gracie Abrams',
#   'Gigi Perez',
#   'OneRepublic',
#   'Benson Boone',
#   'Billie Eilish',
#   'Lola Young',
#   'Tamino',
#   'Kendrick Lamar',
#   'Calema',
#   'PAWSA, The Adventures Of Stevie V',
#   'Billie Eilish',
#   'Damiano David',
#   'Karen Zoid, Richard vd Westhuizen',
#   'GIMS',
#   'SAINt JHN',
#   'Billie Eilish',
#   'TAELA',
#   'Gazo',
#   'Karen Zoid, Sonja Heroldt',
#   'Teddy Swims',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'BL3SS, CamrinWatsin, bbyclose',
#   'Alexy Large',
#   'Lost Frequencies, Tom Odell',
#   'Karen Zoid, Craig Hinds (Watershed)',
#   'Helena',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Linkin Park',
#   'Aminé, Smino',
#   'Alex Warren',
#   'Lah Pat, Flo Milli',
#   'Lola Young',
#   'Alexy Large, Dana',
#   'HUGEL, Topic, Arash, Daecolm',
#   'FINNEAS',
#   'Chappell Roan',
#   'FINNEAS',
#   'KAROL G',
#   'D.T.E, PREZIOSO',
#   'GIMS',
#   'Mackenzy Mackay',
#   'Stromae, Pomme, Arcane',
#   'Karen Zoid, AB De Villiers',
#   'Engel Montaz',
#   'Rsko',
#   'Engel Montaz, Kuv507, Latinnites Music',
#   'Calema',
#   'Engel Montaz, Chimbala, Leo RD',
#   'Robin Schulz, KIDDO',
#   'Lady Gaga, Bruno Mars',
#   'OneRepublic',
#   'ROSÉ, Bruno Mars',
#   'Jay Worthy, DJ.Fresh',
#   'Billie Eilish',
#   'Haze, Mucco',
#   'Gracie Abrams',
#   'Team Karacho, Roger Rekless',
#   'Kendrick Lamar',
#   'Gracie Abrams',
#   'Benson Boone',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Linkin Park',
#   'Julliany Souza',
#   'Gigi Perez',
#   'Nuno Ribeiro',
#   'Gazo',
#   'D.T.E, PREZIOSO',
#   'Lola Young',
#   'Alexy Large',
#   'KAROL G',
#   'Alexy Large, Dana',
#   'Guilherme & Benuto',
#   'Jamie Brown, Marshmello',
#   'HUGEL, Topic, Arash, Daecolm',
#   'Lah Pat, Flo Milli',
#   'Billie Eilish',
#   'Einar, A36',
#   'Kendrick Lamar, Lefty Gunplay',
#   'Gracie Abrams',
#   'Oimara',
#   'SAINt JHN',
#   'Teddy Swims',
#   'Fiorella',
#   'The Weeknd, Playboi Carti',
#   'Lil Uzi Vert',
#   'Joé Dwèt Filé',
#   'Nico K.I.Z, Yassin',
#   'Chappell Roan',
#   'Mackenzy Mackay',
#   'ROSÉ, Bruno Mars',
#   'Aminé, Smino',
#   'Adam Port, Stryv, Keinemusik, Orso, Malachiii',
#   'DUSTY LOCANE, J Hound',
#   'Lady Gaga, Bruno Mars',
#   'Gracie Abrams',
#   'Gracie Abrams',
#   'Robin Schulz, KIDDO',
#   'Billie Eilish',
#   'OneRepublic',
#   'Dream Supplier, Baby Sleeps, Background White Noise',
#   'Gracie Abrams',
#   'Yves Berendse',
#   'SAINt JHN',
#   'PAWSA, The Adventures Of Stevie V',
#   'Still Woozy',
#   'ROSÉ, Bruno Mars',
#   'Tamino',
#   'Yves Berendse, Emma Heesters',
#   'Lah Pat, Flo Milli',
#   'Sven Versteeg, Likke Pêhp',
#   'Karen Zoid, Richard vd Westhuizen',
#   'Lola Young',
#   'FINNEAS',
#   'Martin Morero',
#   'Aminé, Smino',
#   'CYRIL, maryjo',
#   'Johann Sebastian Bach, Carolin Widmann',
#   'Gigi Perez',
#   'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#   'Martin Garrix, Jex',
#   'Billie Eilish',
#   'Kendrick Lamar',
#   'Karen Zoid, Sonja Heroldt',
#   'Teddy Swims',
#   'FINNEAS',
#   'Joshua Robbie, Lange Frans',
#   'Rotimi',
#   'Kevin, Idaly',
#   'D.T.E, PREZIOSO',
#   'Alex Warren',
#   'Karen Zoid, AB De Villiers',
#   'Donnie, Marco Schuitmaker',
#   'Karen Zoid, Craig Hinds (Watershed)',
#   'HUGEL, Topic, Arash, Daecolm',
#   'Jamie Brown, Marshmello',
#   'Lost Frequencies, Tom Odell',
#   'Rsko',
#   'Robert van Hemert',
#   'Calema',
#   'Morgan Wallen',
#   'Lola Young',
#   'Billie Eilish',
#   'William Orbit, Georgia'],
#  'pais': ['AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL'],
#  'genero': []}

# %% [markdown]
# ## De Json a CSV

# %%
import pandas as pd
import requests

# %% [markdown]
# # 2. Sacar de Lastfm el género de las canciones.

# %%
# Coloca tus credenciales de lastfm aquí
CLIENT_ID = '3377e9e50365058dda182c3667e94f69'
API_KEY = '3377e9e50365058dda182c3667e94f69'

last_fm_connect = requests.get(f"http://www.last.fm/api/auth/?api_key={API_KEY}")

# %%
extra_central_last = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist=Sasha&track=here+she+comes+again&api_key={API_KEY}&autocorrect=1&format=json")

# %% [markdown]
# Llamada a API Last.FM y filtro para conseguir el género

# %%
extra_central_last.json()
# Out:
# {'toptags': {'tag': [{'count': 100,
#     'name': 'pop',
#     'url': 'https://www.last.fm/tag/pop'},
#    {'count': 25, 'name': 'Love', 'url': 'https://www.last.fm/tag/Love'},
#    {'count': 13, 'name': 'german', 'url': 'https://www.last.fm/tag/german'},
#    {'count': 13,
#     'name': '5 of 10 stars',
#     'url': 'https://www.last.fm/tag/5+of+10+stars'},
#    {'count': 13,
#     'name': 'beautiful english ones',
#     'url': 'https://www.last.fm/tag/beautiful+english+ones'},
#    {'count': 13, 'name': 'lts', 'url': 'https://www.last.fm/tag/lts'},
#    {'count': 13, 'name': 'edhits', 'url': 'https://www.last.fm/tag/edhits'}],
#   '@attr': {'artist': 'Sasha', 'track': 'Here She Comes Again'}}}

# %%
extra_central_last.json()['toptags']['tag'][0]['name']
# Out:
# 'pop'

# %%
lista_nombres_central = list(dic_central.values())[0]
lista_artistas_central = list(dic_central.values())[2]

# %%
lista_nombres_central
# Out:
# ['Wackelkontakt',
#  'All We Got (feat. KIDDO)',
#  'Die With A Smile',
#  'That’s So True - Live From Radio City Music Hall',
#  'That’s So True',
#  '04:30',
#  'APT.',
#  'Hurt',
#  'BIRDS OF A FEATHER',
#  'Circles',
#  'Not Like Us',
#  'Das riecht gut / Ça Sent Bon',
#  'Sailor Song',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'The Emptiness Machine',
#  'Selfmade Babylon',
#  'The Days - NOTION Remix',
#  'Postcards - Acoustic Version',
#  'Verwandtschaftstreffen',
#  "Don't Play by the Rules",
#  'Good Luck, Babe!',
#  'Passenger Princess',
#  'WILDFLOWER',
#  'Aimer à moitié',
#  'Ma Baby',
#  'Rodeo (Remix)',
#  'Timeless (feat. Playboi Carti)',
#  'Schifoan',
#  'tv off (feat. lefty gunplay)',
#  'EA2 (The Beginning of the Era)',
#  'Messy',
#  'Little Window - Live Studio Session',
#  'The Emptiness Machine',
#  'Anders',
#  'ALL IN (Lieblingslieder)',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'I Adore You (feat. Daecolm)',
#  'Egoist - Live At Elbphilharmonie Hamburg',
#  'eehhhyyy',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Kisses (feat. bbyclose)',
#  "Un'estate normale",
#  "Stumblin' In",
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Fata Morgana',
#  'Bank of Wildflowers (feat. Georgia)',
#  'APT.',
#  'Bruder',
#  'DENIAL IS A RIVER',
#  'Party Jumpin’',
#  'Wackelkontakt',
#  'All We Got (feat. KIDDO)',
#  'Die With A Smile',
#  'Selfmade Babylon',
#  'APT.',
#  '04:30',
#  'That’s So True',
#  'That’s So True - Live From Radio City Music Hall',
#  'Not Like Us',
#  'Das riecht gut / Ça Sent Bon',
#  'Fata Morgana',
#  'Hurt',
#  'BIRDS OF A FEATHER',
#  'Rodeo (Remix)',
#  'Ma Baby',
#  'Circles',
#  'The Days - NOTION Remix',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Sailor Song',
#  'Anders',
#  'The Emptiness Machine',
#  'Bruder',
#  'eehhhyyy',
#  'Schifoan',
#  'I Adore You (feat. Daecolm)',
#  "Don't Play by the Rules",
#  'Rote Flaggen',
#  'Passenger Princess',
#  'Timeless (feat. Playboi Carti)',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Kisses (feat. bbyclose)',
#  'Aimer à moitié',
#  'Butcher',
#  'Postcards - Acoustic Version',
#  'WILDFLOWER',
#  'Little Window - Live Studio Session',
#  'Messy',
#  'Babylon - Live',
#  'tv off (feat. lefty gunplay)',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'The Emptiness Machine',
#  'Family Feud - Live at The Ford',
#  'PLAYBOYBUNNIES',
#  'Elixir',
#  'Thank You (Not So Bad)',
#  'Rid Of Me - Live',
#  'Vois sur ton chemin - Techno Mix',
#  'ARIES "The Charismatic" - Official Piano Tutorial',
#  'Good Luck, Babe!',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Die With A Smile',
#  'All We Got (feat. KIDDO)',
#  'That’s So True',
#  'Hurt',
#  'APT.',
#  'That’s So True - Live From Radio City Music Hall',
#  'BIRDS OF A FEATHER',
#  'Oublier',
#  'Not Like Us',
#  '04:30',
#  'Wackelkontakt',
#  'Aimer à moitié',
#  'Sailor Song',
#  'Circles',
#  'I Adore You (feat. Daecolm)',
#  'Das riecht gut / Ça Sent Bon',
#  'Si Antes Te Hubiera Conocido',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'WILDFLOWER',
#  'Passenger Princess',
#  'Messy',
#  'Rodeo (Remix)',
#  'Timeless (feat. Playboi Carti)',
#  'Little Window - Live Studio Session',
#  'tv off (feat. lefty gunplay)',
#  'Party Jumpin’',
#  'Lose Control',
#  'Selfmade Babylon',
#  'Beautiful Things',
#  'Postcards - Acoustic Version',
#  'Move',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'APT.',
#  'TV - Live From Singapore’s Cloud Forest',
#  "Stumblin' In",
#  "I Ain't Sayin' - Performance",
#  'Good Luck, Babe!',
#  "Don't Play by the Rules",
#  'The Sound of Silence - CYRIL Remix',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Black Friday (pretty like the sun)',
#  'Dingue de toi (Turn me on) [feat. Dana]',
#  'NANANI NANANA',
#  'Babylon - Live',
#  'Gata Only',
#  'EA2 (The Beginning of the Era)',
#  "I Don't Wanna Wait",
#  'Tuck Your Chain',
#  'Bad Dreams',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Die With A Smile',
#  'Postcards - Acoustic Version',
#  'BIRDS OF A FEATHER',
#  'All We Got (feat. KIDDO)',
#  'Not Like Us',
#  'That’s So True - Live From Radio City Music Hall',
#  'That’s So True',
#  'Hurt',
#  'Clean Baby Sleep White Noise (Loopable)',
#  '04:30',
#  'APT.',
#  'Babylon - Live',
#  'tv off (feat. lefty gunplay)',
#  'Lindo Momento',
#  'WILDFLOWER',
#  'Seu Astral / Mistérios',
#  'Sailor Song',
#  'Rodeo (Remix)',
#  'Good Luck, Babe!',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'luther (with sza)',
#  'Circles',
#  'luther (with sza)',
#  'Selfmade Babylon',
#  'DENIAL IS A RIVER',
#  'Standard',
#  'Si Antes Te Hubiera Conocido',
#  'Passenger Princess',
#  'APT.',
#  'Tussi Code Mari',
#  'squabble up',
#  'Pasatiempo',
#  'Timeless (feat. Playboi Carti)',
#  'Das riecht gut / Ça Sent Bon',
#  'One Of The Girls (with JENNIE, Lily Rose Depp)',
#  'Dużo Ciebie Mi',
#  'Like Him (feat. Lola Young)',
#  'Fam*ly (feat. Tiji Jojo, DADA & LEX)',
#  'Messy',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'blue',
#  'Little Window - Live Studio Session',
#  'Qué Pasaría...',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Taste',
#  'Rid Of Me - Live',
#  'Loco',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Who',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Die With A Smile',
#  'That’s So True - Live From Radio City Music Hall',
#  'That’s So True',
#  'All We Got (feat. KIDDO)',
#  'APT.',
#  'Oublier',
#  'BIRDS OF A FEATHER',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Sailor Song',
#  'Hurt',
#  'Beautiful Things',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Messy',
#  'Babylon - Live',
#  'Not Like Us',
#  'Aimer à moitié',
#  'Dirty Cash (Money Talks)',
#  'TV - Live From Singapore’s Cloud Forest',
#  'Born With a Broken Heart',
#  "Ballade Vir 'n Enkeling - Live At Mothership Studios",
#  'CIEL',
#  'Circles',
#  'WILDFLOWER',
#  'crocodile tears',
#  'NANANI NANANA',
#  'Ek Verlang Na Jou - Live at Mothership Studios',
#  'Lose Control',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Kisses (feat. bbyclose)',
#  "J'suis mal",
#  'Black Friday (pretty like the sun)',
#  'Indigo Girl - Live at Mothership Studios',
#  'Mauvais Garçon',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'The Emptiness Machine',
#  'Passenger Princess',
#  'Carry You Home',
#  'Rodeo (Remix)',
#  'Messy',
#  'Dingue de toi (Turn me on) [feat. Dana]',
#  'I Adore You (feat. Daecolm)',
#  'Little Window - Live Studio Session',
#  'Good Luck, Babe!',
#  'Family Feud - Live at The Ford',
#  'Si Antes Te Hubiera Conocido',
#  "Don't Play by the Rules",
#  'CIEL',
#  'Postcards - Acoustic Version',
#  'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#  'Meisie Wat Haar Potlood Kou - Live at Mothership Studios',
#  'Vibrador',
#  'Oublier',
#  'Cupido',
#  'Aimer à moitié',
#  'Kikito',
#  'All We Got (feat. KIDDO)',
#  'Die With A Smile',
#  'Hurt',
#  'APT.',
#  'Kreepin',
#  'BIRDS OF A FEATHER',
#  '04:30',
#  'That’s So True',
#  'Das riecht gut / Ça Sent Bon',
#  'Not Like Us',
#  'That’s So True - Live From Radio City Music Hall',
#  'Beautiful Things',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'The Emptiness Machine',
#  'Lindo Momento',
#  'Sailor Song',
#  'Tarde Demais',
#  'NANANI NANANA',
#  "Don't Play by the Rules",
#  'Messy',
#  "J'suis mal",
#  'Si Antes Te Hubiera Conocido',
#  'Dingue de toi (Turn me on) [feat. Dana]',
#  'Sujeito Homem - Ao Vivo',
#  'Party Jumpin’',
#  'I Adore You (feat. Daecolm)',
#  'Rodeo (Remix)',
#  'WILDFLOWER',
#  'Standard',
#  'tv off (feat. lefty gunplay)',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Wackelkontakt',
#  'Circles',
#  'Lose Control',
#  'Seu Astral / Mistérios',
#  'Timeless (feat. Playboi Carti)',
#  'EA2 (The Beginning of the Era)',
#  '4 Kampé',
#  'Bruder',
#  'Good Luck, Babe!',
#  'Postcards - Acoustic Version',
#  'APT.',
#  'Passenger Princess',
#  'Move',
#  'RESPECT MY MOOD (Official Music Video)',
#  'Die With A Smile',
#  'That’s So True - Live From Radio City Music Hall',
#  'That’s So True',
#  'All We Got (feat. KIDDO)',
#  'BIRDS OF A FEATHER',
#  'Hurt',
#  'Clean Baby Sleep White Noise (Loopable)',
#  'Risk - Live From The Tonight Show With Jimmy Fallon',
#  'Terug In De Tijd',
#  'Circles',
#  'Dirty Cash (Money Talks)',
#  'Rid Of Me - Live',
#  'APT.',
#  'Babylon - Live',
#  'Alleen Met Jou',
#  'Rodeo (Remix)',
#  'Blikkendag',
#  "Ballade Vir 'n Enkeling - Live At Mothership Studios",
#  'Messy',
#  'Little Window - Live Studio Session',
#  'Spijt Is Voor Later',
#  'Passenger Princess',
#  'Still Into You',
#  'J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda',
#  'Sailor Song',
#  'Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile)',
#  'Told You So',
#  'Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles',
#  'Not Like Us',
#  'Ek Verlang Na Jou - Live at Mothership Studios',
#  'Lose Control',
#  'Family Feud - Live at The Ford',
#  'I Surrender - Remix',
#  'ILMSY (MOVES)',
#  'SOS',
#  "Don't Play by the Rules",
#  'Carry You Home',
#  'Meisie Wat Haar Potlood Kou - Live at Mothership Studios',
#  'Hier Mag Alles',
#  'Indigo Girl - Live at Mothership Studios',
#  'I Adore You (feat. Daecolm)',
#  'Party Jumpin’',
#  'Black Friday (pretty like the sun)',
#  'Oublier',
#  'Zoet, Zout, Zuur',
#  'Aimer à moitié',
#  'Love Somebody',
#  'FAKE - BRITs 2022 Rising Star Live Session',
#  'WILDFLOWER',
#  'Bank of Wildflowers (feat. Georgia)']

# %%
lista_artistas_central
# Out:
# ['Oimara',
#  'Robin Schulz, KIDDO',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Gracie Abrams',
#  'Haze, Mucco',
#  'ROSÉ, Bruno Mars',
#  'OneRepublic',
#  'Billie Eilish',
#  'SAINt JHN',
#  'Kendrick Lamar',
#  'Team Karacho, Roger Rekless',
#  'Gigi Perez',
#  'Gracie Abrams',
#  'Linkin Park',
#  'Bausa, Bozza',
#  'Chrystal, NOTION',
#  'Mackenzy Mackay',
#  'RIAN',
#  'D.T.E, PREZIOSO',
#  'Chappell Roan',
#  'Aminé, Smino',
#  'Billie Eilish',
#  'Calema',
#  'Jazeek',
#  'Lah Pat, Flo Milli',
#  'The Weeknd, Playboi Carti',
#  'Felix Harrer, Leopold Franz',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Lil Uzi Vert',
#  'Lola Young',
#  'FINNEAS',
#  'Linkin Park',
#  'Tommy',
#  'Fäaschtbänkler',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'HUGEL, Topic, Arash, Daecolm',
#  'JEREMIAS',
#  'Zartmann, Drumla, Dauner',
#  'Billie Eilish',
#  'BL3SS, CamrinWatsin, bbyclose',
#  'Nek',
#  'CYRIL',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Nina Chuba',
#  'William Orbit, Georgia',
#  'ROSÉ, Bruno Mars',
#  'Nico K.I.Z, Yassin',
#  'Doechii',
#  'Jamie Brown, Marshmello',
#  'Oimara',
#  'Robin Schulz, KIDDO',
#  'Lady Gaga, Bruno Mars',
#  'Bausa, Bozza',
#  'ROSÉ, Bruno Mars',
#  'Haze, Mucco',
#  'Gracie Abrams',
#  'Gracie Abrams',
#  'Kendrick Lamar',
#  'Team Karacho, Roger Rekless',
#  'Nina Chuba',
#  'OneRepublic',
#  'Billie Eilish',
#  'Lah Pat, Flo Milli',
#  'Jazeek',
#  'SAINt JHN',
#  'Chrystal, NOTION',
#  'Gracie Abrams',
#  'Gigi Perez',
#  'Tommy',
#  'Linkin Park',
#  'Nico K.I.Z, Yassin',
#  'Zartmann, Drumla, Dauner',
#  'Felix Harrer, Leopold Franz',
#  'HUGEL, Topic, Arash, Daecolm',
#  'D.T.E, PREZIOSO',
#  'Berq',
#  'Aminé, Smino',
#  'The Weeknd, Playboi Carti',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'BL3SS, CamrinWatsin, bbyclose',
#  'Calema',
#  'Sosa La M, Luciano',
#  'Mackenzy Mackay',
#  'Billie Eilish',
#  'FINNEAS',
#  'Lola Young',
#  'Tamino',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Billie Eilish',
#  'Linkin Park',
#  'FINNEAS',
#  'Jazeek, Luciano, Miksu / Macloud',
#  'Tommy Saint',
#  'Dimitri Vegas & Like Mike, Tiësto, Dido, W&W, Dimitri Vegas, Like Mike',
#  'Still Woozy',
#  'BENNETT',
#  'Tony Ann',
#  'Chappell Roan',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Lady Gaga, Bruno Mars',
#  'Robin Schulz, KIDDO',
#  'Gracie Abrams',
#  'OneRepublic',
#  'ROSÉ, Bruno Mars',
#  'Gracie Abrams',
#  'Billie Eilish',
#  'Rsko',
#  'Kendrick Lamar',
#  'Haze, Mucco',
#  'Oimara',
#  'Calema',
#  'Gigi Perez',
#  'SAINt JHN',
#  'HUGEL, Topic, Arash, Daecolm',
#  'Team Karacho, Roger Rekless',
#  'KAROL G',
#  'Gracie Abrams',
#  'Billie Eilish',
#  'Aminé, Smino',
#  'Lola Young',
#  'Lah Pat, Flo Milli',
#  'The Weeknd, Playboi Carti',
#  'FINNEAS',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Jamie Brown, Marshmello',
#  'Teddy Swims',
#  'Bausa, Bozza',
#  'Benson Boone',
#  'Mackenzy Mackay',
#  'Adam Port, Stryv, Keinemusik, Orso, Malachiii',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'ROSÉ, Bruno Mars',
#  'Billie Eilish',
#  'CYRIL',
#  'Jordan Davis',
#  'Chappell Roan',
#  'D.T.E, PREZIOSO',
#  'Disturbed, CYRIL',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Lost Frequencies, Tom Odell',
#  'Alexy Large, Dana',
#  'Gazo',
#  'Tamino',
#  'FloyyMenor, Cris Mj',
#  'Lil Uzi Vert',
#  'David Guetta, OneRepublic',
#  'Money Man, Danny Towers',
#  'Teddy Swims',
#  'Billie Eilish',
#  'Lady Gaga, Bruno Mars',
#  'Mackenzy Mackay',
#  'Billie Eilish',
#  'Robin Schulz, KIDDO',
#  'Kendrick Lamar',
#  'Gracie Abrams',
#  'Gracie Abrams',
#  'OneRepublic',
#  'Dream Supplier, Baby Sleeps, Background White Noise',
#  'Haze, Mucco',
#  'ROSÉ, Bruno Mars',
#  'Tamino',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Julliany Souza',
#  'Billie Eilish',
#  'Fiorella',
#  'Gigi Perez',
#  'Lah Pat, Flo Milli',
#  'Chappell Roan',
#  'Gracie Abrams',
#  'Kendrick Lamar, SZA',
#  'SAINt JHN',
#  'Kendrick Lamar, SZA',
#  'Bausa, Bozza',
#  'Doechii',
#  'Einar, A36',
#  'KAROL G',
#  'Aminé, Smino',
#  'ROSÉ, Bruno Mars',
#  'Marcianeke, Crismj',
#  'Kendrick Lamar',
#  'La China, ECKO',
#  'The Weeknd, Playboi Carti',
#  'Team Karacho, Roger Rekless',
#  'The Weeknd, JENNIE, Lily-Rose Depp',
#  'Lemon',
#  'Tyler, The Creator, Lola Young',
#  'BAD HOP, Tiji Jojo, Dada, LEX',
#  'Lola Young',
#  'Billie Eilish',
#  'yung kai',
#  'FINNEAS',
#  'Rauw Alejandro, Bad Bunny',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Sabrina Carpenter',
#  'Still Woozy',
#  'Neton Vega',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Jimin',
#  'Billie Eilish',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Gracie Abrams',
#  'Robin Schulz, KIDDO',
#  'ROSÉ, Bruno Mars',
#  'Rsko',
#  'Billie Eilish',
#  'Gracie Abrams',
#  'Gigi Perez',
#  'OneRepublic',
#  'Benson Boone',
#  'Billie Eilish',
#  'Lola Young',
#  'Tamino',
#  'Kendrick Lamar',
#  'Calema',
#  'PAWSA, The Adventures Of Stevie V',
#  'Billie Eilish',
#  'Damiano David',
#  'Karen Zoid, Richard vd Westhuizen',
#  'GIMS',
#  'SAINt JHN',
#  'Billie Eilish',
#  'TAELA',
#  'Gazo',
#  'Karen Zoid, Sonja Heroldt',
#  'Teddy Swims',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'BL3SS, CamrinWatsin, bbyclose',
#  'Alexy Large',
#  'Lost Frequencies, Tom Odell',
#  'Karen Zoid, Craig Hinds (Watershed)',
#  'Helena',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Linkin Park',
#  'Aminé, Smino',
#  'Alex Warren',
#  'Lah Pat, Flo Milli',
#  'Lola Young',
#  'Alexy Large, Dana',
#  'HUGEL, Topic, Arash, Daecolm',
#  'FINNEAS',
#  'Chappell Roan',
#  'FINNEAS',
#  'KAROL G',
#  'D.T.E, PREZIOSO',
#  'GIMS',
#  'Mackenzy Mackay',
#  'Stromae, Pomme, Arcane',
#  'Karen Zoid, AB De Villiers',
#  'Engel Montaz',
#  'Rsko',
#  'Engel Montaz, Kuv507, Latinnites Music',
#  'Calema',
#  'Engel Montaz, Chimbala, Leo RD',
#  'Robin Schulz, KIDDO',
#  'Lady Gaga, Bruno Mars',
#  'OneRepublic',
#  'ROSÉ, Bruno Mars',
#  'Jay Worthy, DJ.Fresh',
#  'Billie Eilish',
#  'Haze, Mucco',
#  'Gracie Abrams',
#  'Team Karacho, Roger Rekless',
#  'Kendrick Lamar',
#  'Gracie Abrams',
#  'Benson Boone',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Linkin Park',
#  'Julliany Souza',
#  'Gigi Perez',
#  'Nuno Ribeiro',
#  'Gazo',
#  'D.T.E, PREZIOSO',
#  'Lola Young',
#  'Alexy Large',
#  'KAROL G',
#  'Alexy Large, Dana',
#  'Guilherme & Benuto',
#  'Jamie Brown, Marshmello',
#  'HUGEL, Topic, Arash, Daecolm',
#  'Lah Pat, Flo Milli',
#  'Billie Eilish',
#  'Einar, A36',
#  'Kendrick Lamar, Lefty Gunplay',
#  'Gracie Abrams',
#  'Oimara',
#  'SAINt JHN',
#  'Teddy Swims',
#  'Fiorella',
#  'The Weeknd, Playboi Carti',
#  'Lil Uzi Vert',
#  'Joé Dwèt Filé',
#  'Nico K.I.Z, Yassin',
#  'Chappell Roan',
#  'Mackenzy Mackay',
#  'ROSÉ, Bruno Mars',
#  'Aminé, Smino',
#  'Adam Port, Stryv, Keinemusik, Orso, Malachiii',
#  'DUSTY LOCANE, J Hound',
#  'Lady Gaga, Bruno Mars',
#  'Gracie Abrams',
#  'Gracie Abrams',
#  'Robin Schulz, KIDDO',
#  'Billie Eilish',
#  'OneRepublic',
#  'Dream Supplier, Baby Sleeps, Background White Noise',
#  'Gracie Abrams',
#  'Yves Berendse',
#  'SAINt JHN',
#  'PAWSA, The Adventures Of Stevie V',
#  'Still Woozy',
#  'ROSÉ, Bruno Mars',
#  'Tamino',
#  'Yves Berendse, Emma Heesters',
#  'Lah Pat, Flo Milli',
#  'Sven Versteeg, Likke Pêhp',
#  'Karen Zoid, Richard vd Westhuizen',
#  'Lola Young',
#  'FINNEAS',
#  'Martin Morero',
#  'Aminé, Smino',
#  'CYRIL, maryjo',
#  'Johann Sebastian Bach, Carolin Widmann',
#  'Gigi Perez',
#  'Sergei Rachmaninoff, Martin James Bartlett, Joshua Weilerstein, London Philharmonic Orchestra',
#  'Martin Garrix, Jex',
#  'Billie Eilish',
#  'Kendrick Lamar',
#  'Karen Zoid, Sonja Heroldt',
#  'Teddy Swims',
#  'FINNEAS',
#  'Joshua Robbie, Lange Frans',
#  'Rotimi',
#  'Kevin, Idaly',
#  'D.T.E, PREZIOSO',
#  'Alex Warren',
#  'Karen Zoid, AB De Villiers',
#  'Donnie, Marco Schuitmaker',
#  'Karen Zoid, Craig Hinds (Watershed)',
#  'HUGEL, Topic, Arash, Daecolm',
#  'Jamie Brown, Marshmello',
#  'Lost Frequencies, Tom Odell',
#  'Rsko',
#  'Robert van Hemert',
#  'Calema',
#  'Morgan Wallen',
#  'Lola Young',
#  'Billie Eilish',
#  'William Orbit, Georgia']

# %%
def llamada_lastfm(lista_nombres, lista_artistas,datos):
    for i in range(len(lista_nombres)):
        try:
            nombre = str(lista_nombres[i]).replace(' ', '+')
            artista = lista_artistas[i].replace(' ', '+').replace(',', '+&')
            llamada_genero = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist={artista}&track={nombre}&api_key={API_KEY}&autocorrect=1&format=json")
            try:
                genero_cancion = llamada_genero.json()['toptags']['tag'][0]['name']
                datos['genero'].append(genero_cancion)
            except KeyError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no está registrada en lastfm")
                
            except IndexError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no tiene tags")
            
        except:
            datos['genero'].append("NULL")
            print(f"Hay problemas con la canción {lista_nombres[i]}")

# %%
llamada_lastfm(lista_nombres_central, lista_artistas_central, dic_central)
# Out:
# La canción Wackelkontakt no tiene tags
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción 04:30 no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Circles no tiene tags
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Selfmade Babylon no está registrada en lastfm
# La canción The Days - NOTION Remix no está registrada en lastfm
# La canción Postcards - Acoustic Version no tiene tags
# La canción Verwandtschaftstreffen no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción Ma Baby no tiene tags
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Schifoan no está registrada en lastfm
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Anders no tiene tags
# La canción ALL IN (Lieblingslieder) no tiene tags
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Egoist - Live At Elbphilharmonie Hamburg no está registrada en lastfm
# La canción eehhhyyy no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Kisses (feat. bbyclose) no está registrada en lastfm
# La canción Un'estate normale no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Fata Morgana no tiene tags
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Bruder no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Wackelkontakt no tiene tags
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción Selfmade Babylon no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción 04:30 no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Fata Morgana no tiene tags
# La canción Hurt no tiene tags
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Ma Baby no tiene tags
# La canción Circles no tiene tags
# La canción The Days - NOTION Remix no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Anders no tiene tags
# La canción Bruder no está registrada en lastfm
# La canción eehhhyyy no está registrada en lastfm
# La canción Schifoan no está registrada en lastfm
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Kisses (feat. bbyclose) no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción Butcher no está registrada en lastfm
# La canción Postcards - Acoustic Version no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Babylon - Live no tiene tags
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción PLAYBOYBUNNIES no está registrada en lastfm
# La canción Elixir no tiene tags
# La canción Thank You (Not So Bad) no está registrada en lastfm
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción ARIES "The Charismatic" - Official Piano Tutorial no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción APT. no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Oublier no tiene tags
# La canción 04:30 no está registrada en lastfm
# La canción Wackelkontakt no tiene tags
# La canción Aimer à moitié no tiene tags
# La canción Circles no tiene tags
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Little Window - Live Studio Session no tiene tags
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Selfmade Babylon no está registrada en lastfm
# La canción Postcards - Acoustic Version no tiene tags
# La canción Move no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción I Ain't Sayin' - Performance no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción The Sound of Silence - CYRIL Remix no está registrada en lastfm
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Black Friday (pretty like the sun) no está registrada en lastfm
# La canción Dingue de toi (Turn me on) [feat. Dana] no está registrada en lastfm
# La canción NANANI NANANA no tiene tags
# La canción Babylon - Live no tiene tags
# La canción Gata Only no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción I Don't Wanna Wait no está registrada en lastfm
# La canción Tuck Your Chain no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción Postcards - Acoustic Version no tiene tags
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción Hurt no tiene tags
# La canción Clean Baby Sleep White Noise (Loopable) no está registrada en lastfm
# La canción 04:30 no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción Lindo Momento no tiene tags
# La canción Seu Astral / Mistérios no tiene tags
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción luther (with sza) no está registrada en lastfm
# La canción Circles no tiene tags
# La canción luther (with sza) no está registrada en lastfm
# La canción Selfmade Babylon no está registrada en lastfm
# La canción Standard no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Tussi Code Mari no está registrada en lastfm
# La canción Pasatiempo no está registrada en lastfm
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción One Of The Girls (with JENNIE, Lily Rose Depp) no está registrada en lastfm
# La canción Like Him (feat. Lola Young) no está registrada en lastfm
# La canción Fam*ly (feat. Tiji Jojo, DADA & LEX) no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Little Window - Live Studio Session no tiene tags
# La canción Qué Pasaría... no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción Loco no tiene tags
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Die With A Smile no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Oublier no tiene tags
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Hurt no tiene tags
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Babylon - Live no tiene tags
# La canción Aimer à moitié no tiene tags
# La canción Dirty Cash (Money Talks) no está registrada en lastfm
# La canción TV - Live From Singapore’s Cloud Forest no tiene tags
# La canción Ballade Vir 'n Enkeling - Live At Mothership Studios no está registrada en lastfm
# La canción CIEL no tiene tags
# La canción Circles no tiene tags
# La canción crocodile tears no tiene tags
# La canción NANANI NANANA no tiene tags
# La canción Ek Verlang Na Jou - Live at Mothership Studios no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Kisses (feat. bbyclose) no está registrada en lastfm
# La canción J'suis mal no tiene tags
# La canción Black Friday (pretty like the sun) no está registrada en lastfm
# La canción Indigo Girl - Live at Mothership Studios no está registrada en lastfm
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Dingue de toi (Turn me on) [feat. Dana] no está registrada en lastfm
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Little Window - Live Studio Session no tiene tags
# La canción Family Feud - Live at The Ford no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción CIEL no tiene tags
# La canción Postcards - Acoustic Version no tiene tags
# La canción Ma Meilleure Ennemie (from the series Arcane League of Legends) no está registrada en lastfm
# La canción Meisie Wat Haar Potlood Kou - Live at Mothership Studios no está registrada en lastfm
# La canción Vibrador no tiene tags
# La canción Oublier no tiene tags
# La canción Cupido no está registrada en lastfm
# La canción Aimer à moitié no tiene tags
# La canción Kikito no está registrada en lastfm
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción APT. no está registrada en lastfm
# La canción Kreepin no está registrada en lastfm
# La canción 04:30 no está registrada en lastfm
# La canción Das riecht gut / Ça Sent Bon no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Lindo Momento no tiene tags
# La canción Tarde Demais no tiene tags
# La canción NANANI NANANA no tiene tags
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción J'suis mal no tiene tags
# La canción Dingue de toi (Turn me on) [feat. Dana] no está registrada en lastfm
# La canción Sujeito Homem - Ao Vivo no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Standard no está registrada en lastfm
# La canción tv off (feat. lefty gunplay) no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Wackelkontakt no tiene tags
# La canción Circles no tiene tags
# La canción Seu Astral / Mistérios no tiene tags
# La canción Timeless (feat. Playboi Carti) no está registrada en lastfm
# La canción EA2 (The Beginning of the Era) no tiene tags
# La canción 4 Kampé no tiene tags
# La canción Bruder no está registrada en lastfm
# La canción Postcards - Acoustic Version no tiene tags
# La canción APT. no está registrada en lastfm
# La canción Passenger Princess no está registrada en lastfm
# La canción Move no está registrada en lastfm
# La canción RESPECT MY MOOD (Official Music Video) no está registrada en lastfm
# La canción Die With A Smile no está registrada en lastfm
# La canción That’s So True - Live From Radio City Music Hall no tiene tags
# La canción All We Got (feat. KIDDO) no está registrada en lastfm
# La canción Hurt no tiene tags
# La canción Clean Baby Sleep White Noise (Loopable) no está registrada en lastfm
# La canción Risk - Live From The Tonight Show With Jimmy Fallon no tiene tags
# La canción Terug In De Tijd no tiene tags
# La canción Circles no tiene tags
# La canción Dirty Cash (Money Talks) no está registrada en lastfm
# La canción Rid Of Me - Live no está registrada en lastfm
# La canción APT. no está registrada en lastfm
# La canción Babylon - Live no tiene tags
# La canción Alleen Met Jou no está registrada en lastfm
# La canción Rodeo (Remix) no está registrada en lastfm
# La canción Blikkendag no está registrada en lastfm
# La canción Ballade Vir 'n Enkeling - Live At Mothership Studios no está registrada en lastfm
# La canción Little Window - Live Studio Session no tiene tags
# La canción Passenger Princess no está registrada en lastfm
# La canción Still Into You no está registrada en lastfm
# La canción J.S. Bach: Violin Partita No. 2 in D Minor, BWV 1004 - I. Allemanda no está registrada en lastfm
# La canción Rachmaninov: Rhapsody on a Theme of Paganini, Op. 43: Variation 18 (Andante cantabile) no está registrada en lastfm
# La canción Told You So no está registrada en lastfm
# La canción Happier Than Ever - Live From Disney’s Happier Than Ever/A Love Letter to Los Angeles no tiene tags
# La canción Ek Verlang Na Jou - Live at Mothership Studios no está registrada en lastfm
# La canción Family Feud - Live at The Ford no tiene tags
# La canción I Surrender - Remix no está registrada en lastfm
# La canción ILMSY (MOVES) no tiene tags
# La canción SOS no está registrada en lastfm
# La canción Don't Play by the Rules no está registrada en lastfm
# La canción Meisie Wat Haar Potlood Kou - Live at Mothership Studios no está registrada en lastfm
# La canción Hier Mag Alles no está registrada en lastfm
# La canción Indigo Girl - Live at Mothership Studios no está registrada en lastfm
# La canción I Adore You (feat. Daecolm) no está registrada en lastfm
# La canción Party Jumpin’ no está registrada en lastfm
# La canción Black Friday (pretty like the sun) no está registrada en lastfm
# La canción Oublier no tiene tags
# La canción Zoet, Zout, Zuur no tiene tags
# La canción Aimer à moitié no tiene tags
# La canción FAKE - BRITs 2022 Rising Star Live Session no está registrada en lastfm
# La canción Bank of Wildflowers (feat. Georgia) no está registrada en lastfm

# %%
df_central = pd.DataFrame(dic_central)

# %%
df_central.index.name="id"

# %%
df_central
# Out:
#                                                nombre  popularity  \
# id
# 0                                       Wackelkontakt          78
# 1                            All We Got (feat. KIDDO)          14
# 2                                    Die With A Smile          96
# 3    That’s So True - Live From Radio City Music Hall          20
# 4                                      That’s So True          91
# ..                                                ...         ...
# 345                                    Aimer à moitié           2
# 346                                     Love Somebody          81
# 347        FAKE - BRITs 2022 Rising Star Live Session           1
# 348                                        WILDFLOWER          90
# 349               Bank of Wildflowers (feat. Georgia)           0
#
#                     artista pais                genero
# id
# 0                    Oimara   AT                  NULL
# 1       Robin Schulz, KIDDO   AT                  NULL
# 2     Lady Gaga, Bruno Mars   AT                  NULL
# 3             Gracie Abrams   AT                  NULL
# 4             Gracie Abrams   AT  love at first listen
# ..                      ...  ...                   ...
# 345                  Calema   NL                  NULL
# 346           Morgan Wallen   NL               country
# 347              Lola Young   NL                  NULL
# 348           Billie Eilish   NL           edu e marco
# 349  William Orbit, Georgia   NL                  NULL
#
# [350 rows x 5 columns]

# %% [markdown]
# 🧠Recordatorio: Como la llamada test_2 nos devuelve varios géneros (tags), decidimos quedarnos con el primero, que es el más utilizado.

# %% [markdown]
# Queremos extraer el género para introducirlo en el diccionario `prueba`, por lo que hacemos dos listas, una con los nombres de las canciones y otra con los artistas. Iremos iterando por las dos a la vez para poder hacer la llamada a la API de lastfm.

# %%
df_central.to_csv("paises_europa_central_2020_2024.csv")

# %% [markdown]
# # 3. Crear la bbdd

# %% [markdown]
# # 4. Alimentar la bbdd

# %% [markdown]
# # 5. Next steps
#
# - Sacar más de 50 canciones por llamadas
