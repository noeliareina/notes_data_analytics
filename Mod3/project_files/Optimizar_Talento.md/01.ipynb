# %%
pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = '13122d95aee54d2e828fdbc53ab27756'
CLIENT_SECRET = '628a3ebb227a4a46a8cdc6cc44327ee6'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# LISTA DE DICCIONARIOS

# %%
datos_2024 = []
for A in hp_data:
    A.append({"artista": artistas["name"], "ouse"h: character["house"], 
                              "yearOfBirth": character["yearOfBirth"], "patronus": character["patronus"],
                              "actor":character["actor"] })
