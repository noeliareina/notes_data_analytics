# %%
# pip install spotipy

# %%
## - Explicar como usar la libreria spotipy 
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = 'tu_cliente'
CLIENT_SECRET = 'tu_secreto'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.search(q = "genre:rock year:2020", limit=100, offset=200, type='track', market=None)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=5&query=genre%3Arock%20year%3A2020&type=track',
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?offset=5&limit=5&query=genre%3Arock%20year%3A2020&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 100,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#        'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#        'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#        'name': 'Arde Bogotá',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
# ...

# %% [markdown]
# ## LAST.FM
# PARA QUE VEA QUE LLAMAMOS EN BUCLE
#
# LISTA 20 ARTISTAS
# artist_get.info ----- API
# DATAFRAME SACAR DATOS ÚNICOS DE UNA COLUMNA
