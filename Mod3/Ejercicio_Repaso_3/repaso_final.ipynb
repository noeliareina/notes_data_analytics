# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_precios = pd.read_csv("files/precios_productos.csv", index_col=0)

df_precios.head()
# Out:
#         price reference_price                        product_id  \
# 6837303   0,7             0,7  9b1d806ddaed2a3b4c842c361e9171a8
# 5137438  3,19           10,63  baf038a3f001812899adb8beaf4e0ec7
# 6005999  3,99           15,96  ca2fc753e5ea44e8c95888983c1dafe1
# 6995217  3,39            5,22  48c959cc94d6d82d1151189b2abe9e83
# 5760664  2,79            0,47  8904722366039ba8f147e2e75a5d1ce1
#
#         reference_unit          insert_date
# 6837303             ud  2022-06-08 00:00:00
# 5137438             kg  2022-02-10 00:00:00
# 6005999              l  2022-04-11 00:00:00
# 6995217              l  2022-06-19 00:00:00
# 5760664             ud  2022-03-25 00:00:00

# %%
df_precios.shape
# Out:
# (1000000, 5)

# %% [markdown]
# no tienes sentido a que los tipos de dato no son los correctos

# %%
df_precios.describe().T
# Out:
#                    count unique                               top    freq
# price             999999   1026                              1,99   33376
# reference_price   999999   2876                              1,99    6587
# product_id       1000000   9469  dec17046c7afb4e5a02252f79738045b     368
# reference_unit    998391      5                                kg  496396
# insert_date      1000000    382               2021-11-07 00:00:00    2828

# %%
# nos quedamos con una muestra de los datos porque e4l df es muy grande
# df_precios = df_precios.sample(200000)

# %%
df_precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 6837303 to 5813238
# Data columns (total 5 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   price            999999 non-null   object
#  1   reference_price  999999 non-null   object
#  2   product_id       1000000 non-null  object
#  3   reference_unit   998391 non-null   object
#  4   insert_date      1000000 non-null  object
# dtypes: object(5)
# memory usage: 45.8+ MB

# %%
df_precios.isna().sum()/df_precios.shape[0]*100
# Out:
# price              0.0001
# reference_price    0.0001
# product_id         0.0000
# reference_unit     0.1609
# insert_date        0.0000
# dtype: float64

# %%
df_precios.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_prod = pd.read_csv("files/productos_dia.csv", index_col=0)

df_prod.head(2)
# Out:
#                                                        url supermarket  \
# 2362486  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362487  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
#
#                                                       name  description  \
# 2362486   MISTOL lavavajillas mano original botella 900 ml          NaN
# 2362487  DIA lavavajillas máquina premium todo en uno e...          NaN
#
#                                product_id
# 2362486  9e2fda45e63337294f2a604178823026
# 2362487  244994c762813d38881cb118742152a2

# %%
df_prod.shape
# Out:
# (11494, 5)

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11494 entries, 2362486 to 7838355
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          11494 non-null  object
#  1   supermarket  11494 non-null  object
#  2   name         11494 non-null  object
#  3   description  0 non-null      float64
#  4   product_id   11494 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 538.8+ KB

# %%
df_prod.describe().T
# Out:
#              count  mean  std  min  25%  50%  75%  max
# description    0.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
df_prod.describe(include="O").T
# Out:
#              count unique                                                top  \
# url          11494  10245  https://www.dia.es/compra-online/frescos/fruta...
# supermarket  11494      1                                             dia-es
# name         11494  10767                          Ciruela roja cesta 500 gr
# product_id   11494   9496                   cd3f6bc51b2d934c1e46b0136ed62779
#
#               freq
# url              7
# supermarket  11494
# name             3
# product_id       8

# %%
df_prod.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_prod[df_prod["product_id"].duplicated()].sort_values("product_id").head(3)
# Out:
#                                                        url supermarket  \
# 4525857  https://www.dia.es/compra-online/congelados/pe...      dia-es
# 4917259  https://www.dia.es/compra-online/platos-prepar...      dia-es
# 4019287  https://www.dia.es/compra-online/despensa/arro...      dia-es
#
#                                                       name  description  \
# 4525857  DIA MARI MARINERA medallones de merluza del ca...          NaN
# 4917259          DIA AL PUNTO cocido madrileño lata 440 gr          NaN
# 4019287          DIA AL PUNTO cocido madrileño lata 440 gr          NaN
#
#                                product_id
# 4525857  0008afbaae96e6003d71de151a2ec67b
# 4917259  000d481c0e60b87db07bd8e395e505de
# 4019287  000d481c0e60b87db07bd8e395e505de

# %%
df_prod["product_id"].value_counts()
# Out:
# product_id
# cd3f6bc51b2d934c1e46b0136ed62779    8
# 5d2d1ed4575049c5cf5bea27ea6bad2c    7
# 2f268ae7ec6b26d49f1f463c4dd49244    6
# b9c8b94b603a4b69e4454717730eab8c    5
# 8cbd3b92d31f10e7bcaafce818654e62    5
#                                    ..
# 6f4d88f0a4086815d84d8ded55b4952b    1
# 7de400a481c91edf1c8f7dc9936e0f5e    1
# 5c110b54fc971385c8ff63c61335ccb2    1
# c1b6a4c537bd007c158207d09bac8ce6    1
# 244994c762813d38881cb118742152a2    1
# Name: count, Length: 9496, dtype: int64

# %%
df_revisar = df_prod[df_prod.duplicated(subset="product_id", keep=False)].sort_values("product_id")

df_revisar.to_csv("files/revisar.csv")

# %%
df_prod[df_prod.duplicated(subset="product_id", keep=False)].sort_values("product_id").iloc[2,2]
# Out:
# 'DIA cocido madrileño lata 440 gr'

# %%
df_prod[df_prod.duplicated(subset="product_id", keep=False)].sort_values("product_id").iloc[3,2]
# Out:
# 'DIA AL PUNTO cocido madrileño lata 440 gr'

# %% [markdown]
# df[df.duplicated(subset="columna", keep=False)].sort_values("columna"): valores duplicados en una columna ordenados de forma descendente. Keep: False muestra todos los duplicados, first el primer resultado de los duplicados, last el último

# %%
df_prod_no_dup = df_prod.drop_duplicates(subset="product_id", keep="last")
df_prod_no_dup.head()
# Out:
#                                                        url supermarket  \
# 2362486  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362487  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362489  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362501  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362502  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
#
#                                                       name  description  \
# 2362486   MISTOL lavavajillas mano original botella 900 ml          NaN
# 2362487  DIA lavavajillas máquina premium todo en uno e...          NaN
# 2362489  FAIRY lavavajillas máquina platinum plus limón...          NaN
# 2362501  FAIRY lavavajillas mano concentrado aloe vera ...          NaN
# 2362502  DIA lavavajillas mano super concentrado botell...          NaN
#
#                                product_id
# 2362486  9e2fda45e63337294f2a604178823026
# ...

# %%
df_prod_no_dup.duplicated(subset="product_id").sum()
# Out:
# np.int64(0)

# %%
df_prod_no_dup.isna().sum()/df_prod_no_dup.shape[0]*100
# Out:
# url              0.0
# supermarket      0.0
# name             0.0
# description    100.0
# product_id       0.0
# dtype: float64

# %%
df_prod_no_dup.drop(columns=["description"], inplace=True)

df_prod_no_dup.head()
# Out:
# C:\Users\cesar\AppData\Local\Temp\ipykernel_20704\1329032205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prod_no_dup.drop(columns=["description"], inplace=True)
#                                                        url supermarket  \
# 2362486  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362487  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362489  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362501  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2362502  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
#
#                                                       name  \
# 2362486   MISTOL lavavajillas mano original botella 900 ml
# 2362487  DIA lavavajillas máquina premium todo en uno e...
# ...

# %%
df_unido = df_prod_no_dup.merge(df_precios, on=["product_id"], how="left")
df_unido.head()
# Out:
#                                                  url supermarket  \
# 0  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 1  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 2  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 3  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
# 4  https://www.dia.es/compra-online/cuidado-del-h...      dia-es
#
#                                                name  \
# 0  MISTOL lavavajillas mano original botella 900 ml
# 1  MISTOL lavavajillas mano original botella 900 ml
# 2  MISTOL lavavajillas mano original botella 900 ml
# 3  MISTOL lavavajillas mano original botella 900 ml
# 4  MISTOL lavavajillas mano original botella 900 ml
#
#                          product_id price reference_price reference_unit  \
# 0  9e2fda45e63337294f2a604178823026  1,59            1,59             ud
# 1  9e2fda45e63337294f2a604178823026  1,59            1,59             ud
# ...

# %%
# df_unido = df_precios.merge(df_prod_no_dup, on=["product_id"], how="right")

# df_unido.head()
# Out:
#   price reference_price                        product_id reference_unit  \
# 0  1,59            1,59  9e2fda45e63337294f2a604178823026             ud
# 1  1,59            1,59  9e2fda45e63337294f2a604178823026             ud
# 2  1,59            1,59  9e2fda45e63337294f2a604178823026             ud
# 3  1,59            1,59  9e2fda45e63337294f2a604178823026             ud
# 4  1,59            1,59  9e2fda45e63337294f2a604178823026             ud
#
#            insert_date                                                url  \
# 0  2021-08-14 00:00:00  https://www.dia.es/compra-online/cuidado-del-h...
# 1  2021-08-17 00:00:00  https://www.dia.es/compra-online/cuidado-del-h...
# 2  2021-08-02 00:00:00  https://www.dia.es/compra-online/cuidado-del-h...
# 3  2021-08-08 00:00:00  https://www.dia.es/compra-online/cuidado-del-h...
# 4  2021-08-18 00:00:00  https://www.dia.es/compra-online/cuidado-del-h...
#
#   supermarket                                              name
# ...

# %%
df_unido.drop(columns=["supermarket"], inplace=True)

# %%
df_unido.head()
# Out:
#                                                  url  \
# 0  https://www.dia.es/compra-online/cuidado-del-h...
# 1  https://www.dia.es/compra-online/cuidado-del-h...
# 2  https://www.dia.es/compra-online/cuidado-del-h...
# 3  https://www.dia.es/compra-online/cuidado-del-h...
# 4  https://www.dia.es/compra-online/cuidado-del-h...
#
#                                                name  \
# 0  MISTOL lavavajillas mano original botella 900 ml
# 1  MISTOL lavavajillas mano original botella 900 ml
# 2  MISTOL lavavajillas mano original botella 900 ml
# 3  MISTOL lavavajillas mano original botella 900 ml
# 4  MISTOL lavavajillas mano original botella 900 ml
#
#                          product_id price reference_price reference_unit  \
# 0  9e2fda45e63337294f2a604178823026  1,59            1,59             ud
# 1  9e2fda45e63337294f2a604178823026  1,59            1,59             ud
# 2  9e2fda45e63337294f2a604178823026  1,59            1,59             ud
# ...

# %%
df_unido.shape
# Out:
# (1000027, 7)

# %%
def cambiar_float(dato):
    try:
        return float(dato.replace(",", "."))
    
    except:
        return np.nan

# %%
x = "2,3"

cambiar_float(x)
# Out:
# 2.3

# %%
df_precios["price"].unique()
# Out:
# array([nan])

# %%
columnas = ["price","reference_price"]

for col in columnas:
    df_unido[col] = df_unido[col].apply(cambiar_float)

# %%
df_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000027 entries, 0 to 1000026
# Data columns (total 7 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   url              1000027 non-null  object
#  1   name             1000027 non-null  object
#  2   product_id       1000027 non-null  object
#  3   price            999999 non-null   float64
#  4   reference_price  999999 non-null   float64
#  5   reference_unit   998391 non-null   object
#  6   insert_date      1000000 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 53.4+ MB

# %%
df_unido.head(2)
# Out:
#                                                  url  \
# 0  https://www.dia.es/compra-online/cuidado-del-h...
# 1  https://www.dia.es/compra-online/cuidado-del-h...
#
#                                                name  \
# 0  MISTOL lavavajillas mano original botella 900 ml
# 1  MISTOL lavavajillas mano original botella 900 ml
#
#                          product_id  price  reference_price reference_unit  \
# 0  9e2fda45e63337294f2a604178823026   1.59             1.59             ud
# 1  9e2fda45e63337294f2a604178823026   1.59             1.59             ud
#
#            insert_date
# 0  2021-08-14 00:00:00
# 1  2021-08-17 00:00:00

# %%
df_unido["insert_date"].str.split(" ").str[0]
# Out:
# 0          2021-08-14
# 1          2021-08-17
# 2          2021-08-02
# 3          2021-08-08
# 4          2021-08-18
#               ...
# 1000022    2022-01-03
# 1000023    2022-06-04
# 1000024    2022-07-01
# 1000025    2022-01-19
# 1000026    2022-02-13
# Name: insert_date, Length: 1000027, dtype: object

# %%
df_unido["insert_date"].str.split(" ", expand=True).get(0)
# Out:
# 0          2021-08-14
# 1          2021-08-17
# 2          2021-08-02
# 3          2021-08-08
# 4          2021-08-18
#               ...
# 1000022    2022-01-03
# 1000023    2022-06-04
# 1000024    2022-07-01
# 1000025    2022-01-19
# 1000026    2022-02-13
# Name: 0, Length: 1000027, dtype: object

# %%
df_unido["date"] = df_unido["insert_date"].str.split(" ").str[0]

df_unido.head()
# Out:
#                                                  url  \
# 0  https://www.dia.es/compra-online/cuidado-del-h...
# 1  https://www.dia.es/compra-online/cuidado-del-h...
# 2  https://www.dia.es/compra-online/cuidado-del-h...
# 3  https://www.dia.es/compra-online/cuidado-del-h...
# 4  https://www.dia.es/compra-online/cuidado-del-h...
#
#                                                name  \
# 0  MISTOL lavavajillas mano original botella 900 ml
# 1  MISTOL lavavajillas mano original botella 900 ml
# 2  MISTOL lavavajillas mano original botella 900 ml
# 3  MISTOL lavavajillas mano original botella 900 ml
# 4  MISTOL lavavajillas mano original botella 900 ml
#
#                          product_id  price  reference_price reference_unit  \
# 0  9e2fda45e63337294f2a604178823026   1.59             1.59             ud
# 1  9e2fda45e63337294f2a604178823026   1.59             1.59             ud
# 2  9e2fda45e63337294f2a604178823026   1.59             1.59             ud
# ...

# %%
df_unido["date"] = pd.to_datetime(df_unido["date"])

df_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000027 entries, 0 to 1000026
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   url              1000027 non-null  object
#  1   name             1000027 non-null  object
#  2   product_id       1000027 non-null  object
#  3   price            999999 non-null   float64
#  4   reference_price  999999 non-null   float64
#  5   reference_unit   998391 non-null   object
#  6   insert_date      1000000 non-null  object
#  7   date             1000000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 61.0+ MB

# %%
df_unido["date"].dt.year
# Out:
# 0          2021.0
# 1          2021.0
# 2          2021.0
# 3          2021.0
# 4          2021.0
#             ...
# 1000022    2022.0
# 1000023    2022.0
# 1000024    2022.0
# 1000025    2022.0
# 1000026    2022.0
# Name: date, Length: 1000027, dtype: float64

# %%
df_unido["url"][0].split("/")
# Out:
# ['https:',
#  '',
#  'www.dia.es',
#  'compra-online',
#  'cuidado-del-hogar',
#  'lavavajillas',
#  'p',
#  '181184']

# %%
df_unido.head()

# %%
## otra función para obtener categorias y subcategorias
def sacar_info(x):
    if "al-dia" in x:
        return "frescos", x.split("/")[5]

    elif "bulto-mixto" in x or "peso" in x or "caducidad" in x or "clasificacion-de-categorias" in x:
        return x.split("/")[5], x.split("/")[6]
        
    else:
        return x.split("/")[4], x.split("/")[5]

# %%
sacar_info("https://www.dia.es/compra-online/cuidado-personal/bano-e-higiene-personal/cuidado-del-cabello/p/283797")
# Out:
# ('cuidado-personal', 'bano-e-higiene-personal')

# %%
df_unido[["categoria", "subcategoria"]] = df_unido.apply(lambda x: sacar_info(x["url"]), axis=1, result_type="expand")
