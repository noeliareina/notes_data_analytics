# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("files/Spotify_Youtube.csv", index_col=0)
df.head(5)
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
display(df.tail())
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri  Danceability  Energy  \
# ...

# %%
df.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri  Danceability  Energy  \
# ...

# %%
df.shape[0]
# Out:
# 20718

# %%
df.shape[1]
# Out:
# 27

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Artist              0.000000
# Url_spotify         0.000000
# Track               0.000000
# Album               0.000000
# Album_type          0.000000
# Uri                 0.000000
# Danceability        0.009653
# Energy              0.009653
# Key                 0.009653
# Loudness            0.009653
# Speechiness         0.009653
# Acousticness        0.009653
# Instrumentalness    0.009653
# Liveness            0.009653
# Valence             0.009653
# Tempo               0.009653
# Duration_ms         0.009653
# Url_youtube         2.268559
# Title               2.268559
# Channel             2.268559
# Views               2.268559
# Likes               2.611256
# Comments            2.746404
# Description         4.228207
# Licensed            2.268559
# official_video      2.268559
# Stream              2.780191
# dtype: float64

# %%
len(df)
# Out:
# 20718

# %%
df.shape[0]
# Out:
# 20718

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# Danceability      20716.0  6.197775e-01  1.652724e-01      0.000000
# Energy            20716.0  6.352503e-01  2.141468e-01      0.000020
# Key               20716.0  5.300348e+00  3.576449e+00      0.000000
# Loudness          20716.0 -7.671680e+00  4.632749e+00    -46.251000
# Speechiness       20716.0  9.645601e-02  1.119600e-01      0.000000
# Acousticness      20716.0  2.915353e-01  2.862988e-01      0.000001
# Instrumentalness  20716.0  5.596156e-02  1.932620e-01      0.000000
# Liveness          20716.0  1.935210e-01  1.685309e-01      0.014500
# Valence           20716.0  5.298533e-01  2.454408e-01      0.000000
# Tempo             20716.0  1.206383e+02  2.957902e+01      0.000000
# Duration_ms       20716.0  2.247176e+05  1.247905e+05  30985.000000
# Views             20248.0  9.393782e+07  2.746443e+08      0.000000
# Likes             20177.0  6.633411e+05  1.789324e+06      0.000000
# ...

# %%
df.describe(include="O").T
# Out:
#                 count unique  \
# Artist          20718   2079
# Url_spotify     20718   2079
# Track           20718  17841
# Album           20718  11937
# Album_type      20718      3
# Uri             20718  18862
# Url_youtube     20248  18154
# Title           20248  18146
# Channel         20248   6714
# Description     19842  17395
# Licensed        20248      2
# official_video  20248      2
#
#                                                               top   freq
# Artist                                                SICK LEGEND     10
# Url_spotify     https://open.spotify.com/artist/3EYY5FwDkHEYLw...     10
# Track                   El Ultimo Adiós - Varios Artistas Version     24
# Album                                               Greatest Hits     30
# Album_type                                                  album  14926
# Uri                          spotify:track:0tzixmHNQfE6S6SirSToxW     24
# ...

# %%
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %%
columnas = {}

for c in df.columns:
    columnas[c] = c.upper()

columnas
# Out:
# {'artist': 'ARTIST',
#  'url_spotify': 'URL_SPOTIFY',
#  'track': 'TRACK',
#  'album': 'ALBUM',
#  'album_type': 'ALBUM_TYPE',
#  'uri': 'URI',
#  'danceability': 'DANCEABILITY',
#  'energy': 'ENERGY',
#  'key': 'KEY',
#  'loudness': 'LOUDNESS',
#  'speechiness': 'SPEECHINESS',
#  'acousticness': 'ACOUSTICNESS',
#  'instrumentalness': 'INSTRUMENTALNESS',
#  'liveness': 'LIVENESS',
#  'valence': 'VALENCE',
#  'tempo': 'TEMPO',
#  'duration_ms': 'DURATION_MS',
#  'url_youtube': 'URL_YOUTUBE',
#  'title': 'TITLE',
#  'channel': 'CHANNEL',
#  'views': 'VIEWS',
#  'likes': 'LIKES',
#  'comments': 'COMMENTS',
#  'description': 'DESCRIPTION',
#  'licensed': 'LICENSED',
#  'official_video': 'OFFICIAL_VIDEO',
#  'stream': 'STREAM'}

# %%
nuevas_col = {columna: columna.upper() for columna in df.columns}

# %%
nuevas_col
# Out:
# {'artist': 'ARTIST',
#  'url_spotify': 'URL_SPOTIFY',
#  'track': 'TRACK',
#  'album': 'ALBUM',
#  'album_type': 'ALBUM_TYPE',
#  'uri': 'URI',
#  'danceability': 'DANCEABILITY',
#  'energy': 'ENERGY',
#  'key': 'KEY',
#  'loudness': 'LOUDNESS',
#  'speechiness': 'SPEECHINESS',
#  'acousticness': 'ACOUSTICNESS',
#  'instrumentalness': 'INSTRUMENTALNESS',
#  'liveness': 'LIVENESS',
#  'valence': 'VALENCE',
#  'tempo': 'TEMPO',
#  'duration_ms': 'DURATION_MS',
#  'url_youtube': 'URL_YOUTUBE',
#  'title': 'TITLE',
#  'channel': 'CHANNEL',
#  'views': 'VIEWS',
#  'likes': 'LIKES',
#  'comments': 'COMMENTS',
#  'description': 'DESCRIPTION',
#  'licensed': 'LICENSED',
#  'official_video': 'OFFICIAL_VIDEO',
#  'stream': 'STREAM'}

# %%
df.rename(columns={columna: columna.upper() for columna in df.columns})
# Out:
#             ARTIST                                        URL_SPOTIFY  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                TRACK  \
# 0                                     Feel Good Inc.
# ...

# %%
df["album"].str.replace("Demon", "patata")
# Out:
# 0                                          patata Days
# 1                                        Plastic Beach
# 2        New Gold (feat. Tame Impala and Bootie Brown)
# 3                                        Plastic Beach
# 4                                             Gorillaz
#                              ...
# 20713                             JUST DANCE HARDSTYLE
# 20714                   SET FIRE TO THE RAIN HARDSTYLE
# 20715                        OUTSIDE HARDSTYLE SPED UP
# 20716                              ONLY GIRL HARDSTYLE
# 20717                               MISS YOU HARDSTYLE
# Name: album, Length: 20718, dtype: object

# %%
lista_errores = []
test = "0,6"

def cambiar_comas(dato):
    try:
        return float(dato.replace(",", "."))
    except:
        lista_errores.append(dato)
        return np.nan

# %%
cambiar_comas(test)
# Out:
# 0.6

# %%
cambiar_comas("tres")
# Out:
# nan

# %%
def corregir_columna(df, columnas):
    for col in columnas:
        df[col] = df[col].str.replace(',', '.').astype(float)
    return df

# %%
# df["danceability"].apply(cambiar_comas)
# df["energy"].apply(cambiar_comas)

# %%
# lista_columnas = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness']

# for col in lista_columnas:
#     df[col] = df[col].apply(cambiar_comas)

# %%
df.head()
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            album album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
test = "Feel Good Inc."

# %%
def minus(dato):
    try:
        return dato.lower()
    except:
        return dato

# %%
minus(test)
# Out:
# 'feel good inc.'

# %%
df["title"].str.lower()
# Out:
# 0               gorillaz - feel good inc. (official video)
# 1        gorillaz - rhinestone eyes [storyboard film] (...
# 2        gorillaz - new gold ft. tame impala & bootie b...
# 3           gorillaz - on melancholy hill (official video)
# 4               gorillaz - clint eastwood (official video)
#                                ...
# 20713                                 just dance hardstyle
# 20714                       set fire to the rain hardstyle
# 20715                            outside hardstyle sped up
# 20716                                  only girl hardstyle
# 20717                                   miss you hardstyle
# Name: title, Length: 20718, dtype: object

# %%
def minus_2(dato):
    if type(dato) == str:
        return dato.lower()
    else:
        return dato

# %%
minus_2("Hola")
# Out:
# 'hola'

# %%
df.isna().sum()
# Out:
# artist                0
# url_spotify           0
# track                 0
# album                 0
# album_type            0
# uri                   0
# danceability          2
# energy                2
# key                   2
# loudness              2
# speechiness           2
# acousticness          2
# instrumentalness      2
# liveness              2
# valence               2
# tempo                 2
# duration_ms           2
# url_youtube         470
# title               470
# channel             470
# views               470
# likes               541
# comments            569
# description         876
# licensed            470
# official_video      470
# stream              576
# dtype: int64

# %%
df["title"].apply(lambda texto: texto.lower() if type(texto) == str else texto)
# Out:
# 0               gorillaz - feel good inc. (official video)
# 1        gorillaz - rhinestone eyes [storyboard film] (...
# 2        gorillaz - new gold ft. tame impala & bootie b...
# 3           gorillaz - on melancholy hill (official video)
# 4               gorillaz - clint eastwood (official video)
#                                ...
# 20713                                 just dance hardstyle
# 20714                       set fire to the rain hardstyle
# 20715                            outside hardstyle sped up
# 20716                                  only girl hardstyle
# 20717                                   miss you hardstyle
# Name: title, Length: 20718, dtype: object

# %%
lista_col_lower = ['track', 'title', 'album']

for col in lista_col_lower:
    df[col] = df[col].apply(lambda texto: texto.lower() if type(texto) == str else texto)

# %%
# sy_dt[["track", "title", "album"]] = sy_dt[["track", "title", "album"]].apply(lambda col: col.str.lower())

# %%
df["artist"].unique()
# Out:
# array(['Gorillaz', 'Red Hot Chili Peppers', '50 Cent', ..., 'LE SSERAFIM',
#        'ThxSoMch', 'SICK LEGEND'], shape=(2079,), dtype=object)

# %%
df[df['artist'].str.contains('$', regex=False)].head()
# Out:
#          artist                                        url_spotify  \
# 5332  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5333  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5334  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5335  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
# 5336  Too $hort  https://open.spotify.com/artist/4sb7rZNN93BSS6...
#
#                                                   track  \
# 5332                                   blow the whistle
# 5333           gettin' it (feat. parliament funkadelic)
# 5334  big subwoofer (feat. snoop dogg, ice cube, e-4...
# 5335                      i'm a player - street version
# 5336                                         the ghetto
#
#                               album album_type  \
# 5332               blow the whistle      album
# 5333  gettin' it (album number ten)      album
# 5334                  big subwoofer     single
# ...

# %%
df["artist"]
# Out:
# 0           Gorillaz
# 1           Gorillaz
# 2           Gorillaz
# 3           Gorillaz
# 4           Gorillaz
#             ...
# 20713    SICK LEGEND
# 20714    SICK LEGEND
# 20715    SICK LEGEND
# 20716    SICK LEGEND
# 20717    SICK LEGEND
# Name: artist, Length: 20718, dtype: object

# %%
mascara = df["artist"].str.contains("$", regex=False)

# %%
df["artist"][mascara]
# Out:
# 5332     Too $hort
# 5333     Too $hort
# 5334     Too $hort
# 5335     Too $hort
# 5336     Too $hort
#            ...
# 19521         $NOT
# 19522         $NOT
# 19523         $NOT
# 19524         $NOT
# 19525         $NOT
# Name: artist, Length: 90, dtype: object

# %% [markdown]
# Solución con métodos de filtrado de pandas

# %%
df["artist"][mascara].unique()
# Out:
# array(['Too $hort', 'Curren$y', 'Ty Dolla $ign', 'A$AP Rocky',
#        'A$AP Ferg', 'Joey Bada$$', '$uicideboy$', 'bbno$', '$NOT'],
#       dtype=object)

# %% [markdown]
# Solución con python a tope!!

# %%
for artista in df["artist"].unique():  # para ver si realmente hay artistas con $
    if "$" in str(artista):
        print(artista)
# Out:
# Too $hort
# Curren$y
# Ty Dolla $ign
# A$AP Rocky
# A$AP Ferg
# Joey Bada$$
# $uicideboy$
# bbno$
# $NOT

# %%
def cambiar_simbolo(dato):
    return dato.replace("$", "s")

# %%
df["artist"].apply(cambiar_simbolo)

# %%
df["artist"] = df["artist"].apply(lambda dato: dato.replace("$", "s"))

# %%
df["artist"][df["artist"].str.contains("$", regex=False)].unique()
# Out:
# array([], dtype=object)

# %%
df["album_type"].value_counts()
# Out:
# album_type
# album          14926
# single          5004
# compilation      788
# Name: count, dtype: int64

# %%
df_album = df[df["album_type"] == "album"]
df_album.shape
# Out:
# (14926, 27)

# %%
tipos = df["album_type"].unique()
tipos
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
for tipo in tipos:
    print(tipo)
    print("------------------")
# Out:
# album
# ------------------
# single
# ------------------
# compilation
# ------------------

# %%
for tipo in tipos:
    
    display(df[df["album_type"] == tipo].head())
    print(tipo, "->", df[df["album_type"] == tipo].shape[0])

    print("--------------------------------------------------------")
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                 track          album album_type  \
# 0      feel good inc.     demon days      album
# 1     rhinestone eyes  plastic beach      album
# 3  on melancholy hill  plastic beach      album
# 4      clint eastwood       gorillaz      album
# 5                dare     demon days      album
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# ...

# %%
diccionario_dfs = {}

for tipo in tipos:

    diccionario_dfs[tipo] = df[df["album_type"] == tipo]

# %%
diccionario_dfs["compilation"]
# Out:
#               artist                                        url_spotify  \
# 154          Shakira  https://open.spotify.com/artist/0EmeFodog0BfCg...
# 206        Sean Paul  https://open.spotify.com/artist/3Isy6kedDrgPYo...
# 220             2Pac  https://open.spotify.com/artist/1ZwdS5xdxEREPy...
# 222             2Pac  https://open.spotify.com/artist/1ZwdS5xdxEREPy...
# 225             2Pac  https://open.spotify.com/artist/1ZwdS5xdxEREPy...
# ...              ...                                                ...
# 19367    Luísa Sonza  https://open.spotify.com/artist/4PzYKhC14sTJNE...
# 19508          Aitch  https://open.spotify.com/artist/2PJEagPIxaBuge...
# 20462  Tz da Coronel  https://open.spotify.com/artist/3lIU3RoZiHen1Q...
# 20521      Rosa Linn  https://open.spotify.com/artist/46xBNx0j6cwY6s...
# 20600          Oruam  https://open.spotify.com/artist/4yGgbQJMq9orWy...
#
#                                                    track  \
# ...

# %%
diccionario_dfs["album"].shape
# Out:
# (14926, 27)

# %%
diccionario_dfs["single"].shape
# Out:
# (5004, 27)

# %%
diccionario_dfs["single"]["artist"].unique()
# Out:
# array(['Gorillaz', '50 Cent', 'Metallica', ..., 'LE SSERAFIM', 'ThxSoMch',
#        'SICK LEGEND'], shape=(1355,), dtype=object)

# %%
diccionario_dfs["album"].to_csv("files/df_album.csv")

# %%
df_album
