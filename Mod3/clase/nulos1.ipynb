# %% [markdown]
# # Nulos: -> Resumen con necesidad de contexto, no es una norma estricta
#
# ## Primer paso:
#     **Exploración y entendimiento de los valores nulos**
#     Tenemos que buscar patrones y analizar tanto el núm cómo la naturaleza de los valores nulos.
#
# ## Segundo paso:
#
#     ### Tipos de valores nulos:
#
#         - Columnas categoricas:
#             - Si el % de nulos es pequeño y tenemos una moda representativa, cambiamos por la moda
#             - EN caso contrario, categorizamos cómo "Unk"
#
#         - Columnas numericas:
#             - La mediana es más robusta que la media a la hora de imputar los valores nulos

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv("files/merchant_ejercicios_apply.csv", index_col=0)

df.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
# 2               18.0                23.0               8.0               7.0
# 3                7.0                 8.0               5.0               5.0
# 4                1.0                 2.0               2.0               1.0
#
#   badge_local_product badge_product_quality badge_fast_shipping  \
# 0                  No                 Buena                  No
# 1                  No                 Buena                  No
# 2                  No                 Buena                  No
# 3                  No                 Buena                  No
# 4                  No                 Buena                  No
#
#                                                 tags product_color  \
# 0  Summer,Fashion,womenunderwearsuit,printedpajam...         white
# 1  Mini,womens dresses,Summer,Patchwork,fashion d...         green
# 2  Summer,Fashion,Necks,Beach,Dress,Loose,beach d...         white
# 3  Summer,Shorts,Lace,pants,Waist,Short pants,Yel...           red
# 4  Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...         black
#
#   product_variation_size_id shipping_option_name  shipping_option_price  \
# 0                         M   Livraison standard                      4
# 1                        XS   Livraison standard                      2
# 2                       XXS   Livraison standard                      1
# 3                         S    Standard Shipping                      1
# 4                       XXS   Livraison standard                      1
#
#   shipping_is_express  countries_shipped_to  inventory_total origin_country  \
# 0                  No                    34               50             CN
# 1                  No                    41               50             CN
# 2                  No                    41               50             CN
# 3                  No                    41               50             CN
# 4                  No                    41               50             CN
#
#   merchant_name  merchant_info_subtitle  merchant_rating_count  \
# 0      zgrdejia                     NaN                    568
# 1     sarahouse     83 % avis positifs                   17752
# 2     sarahouse     83 % avis positifs                   17752
# 3     sarahouse  83% Positive Feedback                   17752
# 4     sarahouse     83 % avis positifs                   17752
#
#                 merchant_id                                      product_url  \
# 0  595097d6a26f6e070cb878d1  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
# 1  56458aa03a698c35c9050988  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 2  56458aa03a698c35c9050988  https://www.wish.com/c/5df2576d68963c1660471f9a
# 3  56458aa03a698c35c9050988  https://www.wish.com/c/5d58daef3159a812b05933d2
# 4  56458aa03a698c35c9050988  https://www.wish.com/c/5e9fa7de39682a0043ab7898
#
#                  product_id  listed_products  total_units_sold  \
# 0  5e9ae51d43d6a96e303acdb0                1               100
# 1  58940d436a0d3d5da4e95a38                6             21400
# 2  5df2576d68963c1660471f9a                6             21400
# 3  5d58daef3159a812b05933d2                6             21400
# 4  5e9fa7de39682a0043ab7898                6             21400
#
#    mean_units_sold_per_product  rating_employee  merchant_ratings_count  \
# 0                        100.0            4.129                   568.0
# 1                       3567.0            3.900                 17752.0
# 2                       3567.0            3.900                 17752.0
# 3                       3567.0            3.900                 17752.0
# 4                       3567.0            3.900                 17752.0
#
#    mean_product_prices  mean_retail_prices  mean_product_ratings_count  \
# 0                16.00               14.00                        54.0
# 1                 5.68               10.33                      1057.0
# 2                 5.68               10.33                      1057.0
# 3                 5.68               10.33                      1057.0
# 4                 5.68               10.33                      1057.0
#
#    discount_percentage seller_reputation
# 0                14.29             Buena
# 1               -63.64           Regular
# 2               -38.75           Regular
# 3               -17.83           Regular
# 4               -43.50           Regular

# %%
data = {
    'Experiencia': [1, 3, 5, 2, 8, 10, 4, 6, 7, 9],  
    'Salario': [30000, 45000, np.nan, 35000, 80000, 95000, np.nan, 65000, 75000, np.nan]  
}

df_ejemplo = pd.DataFrame(data)

# %%
df.describe().T
# Out:
#                               count          mean           std     min  \
# price                        1573.0      8.325372      3.932030   1.000
# retail_price                 1573.0     23.288620     30.357863   1.000
# units_sold                   1573.0   4339.005086   9356.539302   1.000
# rating_sold                  1573.0      3.820896      0.515374   1.000
# rating_count                 1573.0    889.659250   1983.928834   0.000
# rating_five_count            1528.0    442.263743    980.203270   0.000
# rating_four_count            1528.0    179.599476    400.516231   0.000
# rating_three_count           1528.0    134.549738    311.690656   0.000
# rating_two_count             1528.0     63.711387    151.343933   0.000
# rating_one_count             1528.0     95.735602    214.075544   0.000
# shipping_option_price        1573.0      2.345200      1.024371   1.000
# countries_shipped_to         1573.0     40.456453     20.301203   6.000
# inventory_total              1573.0     49.821360      2.562799   1.000
# merchant_rating_count        1573.0  26495.832804  78474.455607   0.000
# listed_products              1573.0      2.586777      2.218848   1.000
# total_units_sold             1573.0  11299.397966  18973.200472   1.000
# mean_units_sold_per_product  1573.0   4339.010172   8047.707932   1.000
# rating_employee              1573.0      4.032364      0.204752   2.333
# merchant_ratings_count       1573.0  26495.832804  78474.455607   0.000
# mean_product_prices          1573.0      8.325601      3.588461   1.000
# mean_retail_prices           1573.0     23.288589     28.750732   1.000
# mean_product_ratings_count   1573.0    889.686586   1716.377853   0.000
# discount_percentage          1573.0    -26.060668     40.883828 -96.930
#
#                                   25%       50%        75%        max
# price                           5.810     8.000     11.000       49.0
# retail_price                    7.000    10.000     26.000      252.0
# units_sold                    100.000  1000.000   5000.000   100000.0
# rating_sold                     3.550     3.850      4.110        5.0
# rating_count                   24.000   150.000    855.000    20744.0
# rating_five_count              12.000    79.000    413.500    11548.0
# rating_four_count               5.000    31.500    168.250     4152.0
# rating_three_count              4.000    24.000    129.250     3658.0
# rating_two_count                2.000    11.000     62.000     2003.0
# rating_one_count                4.000    20.000     94.000     2789.0
# shipping_option_price           2.000     2.000      3.000       12.0
# countries_shipped_to           31.000    40.000     43.000      140.0
# inventory_total                50.000    50.000     50.000       50.0
# merchant_rating_count        1987.000  7936.000  24564.000  2174765.0
# listed_products                 1.000     2.000      3.000       15.0
# total_units_sold              200.000  2000.000  15000.000   120000.0
# mean_units_sold_per_product   100.000  1000.000   5017.000   100000.0
# rating_employee                 3.917     4.041      4.162        5.0
# merchant_ratings_count       1987.000  7936.000  24564.000  2174765.0
# mean_product_prices             6.000     8.000     10.250       49.0
# mean_retail_prices              7.000    11.000     26.000      252.0
# mean_product_ratings_count     38.000   279.000    957.000    20744.0
# discount_percentage           -72.350    -5.830     12.500       18.2

# %%
df_ejemplo
# Out:
#    Experiencia  Salario
# 0            1  30000.0
# 1            3  45000.0
# 2            5      NaN
# 3            2  35000.0
# 4            8  80000.0
# 5           10  95000.0
# 6            4      NaN
# 7            6  65000.0
# 8            7  75000.0
# 9            9      NaN

# %%
df_ejemplo.style.highlight_null(color='yellow')
# Out:
# <style type="text/css">
# #T_a6808_row2_col1, #T_a6808_row6_col1, #T_a6808_row9_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a6808">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6808_level0_col0" class="col_heading level0 col0" >Experiencia</th>
#       <th id="T_a6808_level0_col1" class="col_heading level0 col1" >Salario</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6808_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6808_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a6808_row0_col1" class="data row0 col1" >30000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6808_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_a6808_row1_col1" class="data row1 col1" >45000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6808_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_a6808_row2_col1" class="data row2 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6808_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_a6808_row3_col1" class="data row3 col1" >35000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6808_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_a6808_row4_col1" class="data row4 col1" >80000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6808_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_a6808_row5_col1" class="data row5 col1" >95000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6808_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_a6808_row6_col1" class="data row6 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6808_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_a6808_row7_col1" class="data row7 col1" >65000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6808_row8_col0" class="data row8 col0" >7</td>
#       <td id="T_a6808_row8_col1" class="data row8 col1" >75000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6808_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6808_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_a6808_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
imputer_knn = KNNImputer(n_neighbors=3)

# %%
imputado = imputer_knn.fit_transform(df_ejemplo[["Experiencia",	"Salario"]])

# %%
imputado
# Out:
# array([[1.00000000e+00, 3.00000000e+04],
#        [3.00000000e+00, 4.50000000e+04],
#        [5.00000000e+00, 6.16666667e+04],
#        [2.00000000e+00, 3.50000000e+04],
#        [8.00000000e+00, 8.00000000e+04],
#        [1.00000000e+01, 9.50000000e+04],
#        [4.00000000e+00, 4.83333333e+04],
#        [6.00000000e+00, 6.50000000e+04],
#        [7.00000000e+00, 7.50000000e+04],
#        [9.00000000e+00, 8.33333333e+04]])

# %%
pd.DataFrame(imputado)
# Out:
#       0             1
# 0   1.0  30000.000000
# 1   3.0  45000.000000
# 2   5.0  61666.666667
# 3   2.0  35000.000000
# 4   8.0  80000.000000
# 5  10.0  95000.000000
# 6   4.0  48333.333333
# 7   6.0  65000.000000
# 8   7.0  75000.000000
# 9   9.0  83333.333333

# %%
df_ejemplo.head()
# Out:
#    Experiencia  Salario
# 0            1  30000.0
# 1            3  45000.0
# 2            5      NaN
# 3            2  35000.0
# 4            8  80000.0

# %%
df_ejemplo[["exp_knn", "sal_knn"]] = imputado

# %%
df_ejemplo
# Out:
#    Experiencia  Salario  exp_knn       sal_knn
# 0            1  30000.0      1.0  30000.000000
# 1            3  45000.0      3.0  45000.000000
# 2            5      NaN      5.0  61666.666667
# 3            2  35000.0      2.0  35000.000000
# 4            8  80000.0      8.0  80000.000000
# 5           10  95000.0     10.0  95000.000000
# 6            4      NaN      4.0  48333.333333
# 7            6  65000.0      6.0  65000.000000
# 8            7  75000.0      7.0  75000.000000
# 9            9      NaN      9.0  83333.333333

# %%
df_ejemplo.describe().T
# Out:
#              count          mean           std      min           25%  \
# Experiencia   10.0      5.500000      3.027650      1.0      3.250000
# Salario        7.0  60714.285714  24567.690746  30000.0  40000.000000
# exp_knn       10.0      5.500000      3.027650      1.0      3.250000
# sal_knn       10.0  61833.333333  21793.786633  30000.0  45833.333333
#
#                       50%       75%      max
# Experiencia      5.500000      7.75     10.0
# Salario      65000.000000  77500.00  95000.0
# exp_knn          5.500000      7.75     10.0
# sal_knn      63333.333333  78750.00  95000.0

# %%
df_ejemplo = df_ejemplo.drop(columns=["Salario", "exp_knn"])

# %%
df_ejemplo
# Out:
#    Experiencia       sal_knn
# 0            1  30000.000000
# 1            3  45000.000000
# 2            5  61666.666667
# 3            2  35000.000000
# 4            8  80000.000000
# 5           10  95000.000000
# 6            4  48333.333333
# 7            6  65000.000000
# 8            7  75000.000000
# 9            9  83333.333333
