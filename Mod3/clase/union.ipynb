# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({"cliente" :[1,2,3], "telf":[4,5,6]})
df2 = pd.DataFrame({"cliente" :[7,8,9], "telf":[10,11,12]})

# %%
df1
# Out:
#    cliente  telf
# 0        1     4
# 1        2     5
# 2        3     6

# %%
df2
# Out:
#    cliente  telf
# 0        7    10
# 1        8    11
# 2        9    12

# %% [markdown]
# - concat -> el uso práctico es poner un df encima del otro
# - join
# - merge

# %%
pd.concat([df1, df2], axis = 0, ignore_index=True)
# Out:
#    cliente  telf
# 0        1     4
# 1        2     5
# 2        3     6
# 3        7    10
# 4        8    11
# 5        9    12

# %%
df1 = pd.DataFrame({"cliente" :[1,2,3], "telf":[4,5,6]})
df2 = pd.DataFrame({"cliente" :[7,8,9], "telfefono":[10,11,12]})

# %%
df1
# Out:
#    cliente  telf
# 0        1     4
# 1        2     5
# 2        3     6

# %%
df2
# Out:
#    cliente  telfefono
# 0        7         10
# 1        8         11
# 2        9         12

# %%
pd.concat([df1, df2], axis = 0, ignore_index=True)
# Out:
#    cliente  telf  telfefono
# 0        1   4.0        NaN
# 1        2   5.0        NaN
# 2        3   6.0        NaN
# 3        7   NaN       10.0
# 4        8   NaN       11.0
# 5        9   NaN       12.0

# %%
df1 = pd.DataFrame({"cliente" :[1,2,3], "telf":[4,5,6]})
df2 = pd.DataFrame({"cliente" :[7,8,9], "telf":[10,11,12], "dirección":["a", "b", "c"]})

# %%
df1
# Out:
#    cliente  telf
# 0        1     4
# 1        2     5
# 2        3     6

# %%
df2
# Out:
#    cliente  telf dirección
# 0        7    10         a
# 1        8    11         b
# 2        9    12         c

# %%
pd.concat([df1, df2], axis = 0, ignore_index=True)
# Out:
#    cliente  telf dirección
# 0        1     4       NaN
# 1        2     5       NaN
# 2        3     6       NaN
# 3        7    10         a
# 4        8    11         b
# 5        9    12         c

# %%
df3 = pd.DataFrame({"A" :[1,2,3], "B":[4,5,6]})
df4 = pd.DataFrame({"C" :[7,8,9], "D":[10,11,12]})

# %%
df3
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df4
# Out:
#    C   D
# 0  7  10
# 1  8  11
# 2  9  12

# %%
pd.concat([df3,df4], axis = 1)
# Out:
#    A  B  C   D
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %%
df_rating = pd.read_csv("files/rating-and-performance.csv", index_col=0)

df_rating.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
df_cat = df_rating.select_dtypes(include="O")
df_cat.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig currency_buyer  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...            EUR
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress            EUR
# 2      2020 New Arrival Women Spring and Summer Beach...            EUR
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...            EUR
# 4      Women Summer Shorts Lace Up Elastic Waistband ...            EUR
#
#                                                     tags product_color  \
# index
# 0      Summer,Fashion,womenunderwearsuit,printedpajam...         white
# ...

# %%
df_num = df_rating.select_dtypes(exclude="O")
df_num.head()
# Out:
#        price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0      16.00            14         100               0    3.76            54
# 1       8.00            22       20000               1    3.45          6135
# 2       8.00            43         100               0    3.57            14
# 3       8.00             8        5000               1    4.03           579
# 4       2.72             3         100               1    3.10            20
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# 0                   26.0                8.0                10.0
# 1                 2269.0             1027.0              1118.0
# 2                    5.0                4.0                 2.0
# 3                  295.0              119.0                87.0
# 4                    6.0                4.0                 2.0
#
#        rating_two_count  ...  badge_fast_shipping  \
# index                    ...
# ...

# %%
df_num.drop([0,1], axis=0, inplace=	True)

# %%
df_num.head()
# Out:
#        price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 2       8.00            43         100               0    3.57            14
# 3       8.00             8        5000               1    4.03           579
# 4       2.72             3         100               1    3.10            20
# 5       3.92             9          10               0    5.00             1
# 6       7.00             6       50000               0    3.84          6742
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# 2                    5.0                4.0                 2.0
# 3                  295.0              119.0                87.0
# 4                    6.0                4.0                 2.0
# 5                    1.0                0.0                 0.0
# 6                 3172.0             1352.0               971.0
#
#        rating_two_count  ...  badge_fast_shipping  \
# index                    ...
# ...

# %%
pd.concat([df_num, df_cat], axis=1).head(3)
# Out:
#        price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 2       8.00          43.0       100.0             0.0    3.57          14.0
# 3       8.00           8.0      5000.0             1.0    4.03         579.0
# 4       2.72           3.0       100.0             1.0    3.10          20.0
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# 2                    5.0                4.0                 2.0
# 3                  295.0              119.0                87.0
# 4                    6.0                4.0                 2.0
#
#        rating_two_count  ...   merchant_title  merchant_name  \
# index                    ...
# 2                   0.0  ...           hxt520         hxt520
# 3                  42.0  ...         allenfan       allenfan
# 4                   2.0  ...  youngpeopleshop    happyhorses
#
#                   merchant_info_subtitle               merchant_id  \
# index
# ...

# %%
df_num.head()
# Out:
#        price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 2       8.00            43         100               0    3.57            14
# 3       8.00             8        5000               1    4.03           579
# 4       2.72             3         100               1    3.10            20
# 5       3.92             9          10               0    5.00             1
# 6       7.00             6       50000               0    3.84          6742
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# 2                    5.0                4.0                 2.0
# 3                  295.0              119.0                87.0
# 4                    6.0                4.0                 2.0
# 5                    1.0                0.0                 0.0
# 6                 3172.0             1352.0               971.0
#
#        rating_two_count  ...  badge_fast_shipping  \
# index                    ...
# ...

# %%
df_num.reset_index()
# Out:
#       index  price  retail_price  units_sold  uses_ad_boosts  rating  \
# 0         2   8.00            43         100               0    3.57
# 1         3   8.00             8        5000               1    4.03
# 2         4   2.72             3         100               1    3.10
# 3         5   3.92             9          10               0    5.00
# 4         6   7.00             6       50000               0    3.84
# ...     ...    ...           ...         ...             ...     ...
# 1566   1568   6.00             9       10000               1    4.08
# 1567   1569   2.00            56         100               1    3.07
# 1568   1570   5.00            19         100               0    3.71
# 1569   1571  13.00            11         100               0    2.50
# 1570   1572   7.00             6         100               1    4.07
#
#       rating_count  rating_five_count  rating_four_count  rating_three_count  \
# ...

# %%
df1 = pd.DataFrame({"cliente" :[1,2,3], "telf":[4,5,6]})
df2 = pd.DataFrame({"cliente" :[7,8,9], "telf":[10,11,12]})

# %%
df1
# Out:
#    cliente  telf
# 0        1     4
# 1        2     5
# 2        3     6

# %%
df2
# Out:
#    cliente  telf
# 0        7    10
# 1        8    11
# 2        9    12

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#    cliente  telf  cliente  telf
# 0        1     4        7    10
# 1        2     5        8    11
# 2        3     6        9    12

# %%
df1.join(df2, lsuffix="_l", rsuffix="_r")
# Out:
#    cliente_l  telf_l  cliente_r  telf_r
# 0          1       4          7      10
# 1          2       5          8      11
# 2          3       6          9      12

# %%
df1 = pd.DataFrame({"A" :[1,2,3], "B":[4,5,6]})
df2 = pd.DataFrame({"C" :[7,8,9], "D":[10,11,12]})

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    C   D
# 0  7  10
# 1  8  11
# 2  9  12

# %%
df1.join(df2)
# Out:
#    A  B  C   D
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %%
df_rating.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
df_ins = pd.read_csv("files/insight.csv", index_col=0)
df_ins.head()
# Out:
#                     merchant.id  listed.products  total.units.sold  \
# index
# 0      5357bcf2bb72c5504882e889                2            120000
# 1      5708773c3c02161b3f8c7900                5            107100
# 2      5417aada4ad3ab27e954b76c                2            100007
# 3      570f3a713a698c14278bb51e                1            100000
# 4      53082ea15aefb07dfe1f2a4f                1            100000
#
#        mean.units.sold.per.product  rating  merchant.ratings.count  \
# index
# 0                          60000.0   4.219                320031.0
# 1                          21420.0   3.934                139223.0
# 2                          50004.0   4.053                108048.0
# 3                         100000.0   3.889                 19248.0
# 4                         100000.0   4.036                366898.0
#
#        mean.product.prices  mean.retail.prices  average.discount  \
# index
# 0                     9.00                20.0              54.0
# ...

# %%
df_ins[df_ins["merchant.id"]=="558c2cdc89d53c4005ea2920"]
# Out:
#                     merchant.id  listed.products  total.units.sold  \
# index
# 17     558c2cdc89d53c4005ea2920               15             58500
#
#        mean.units.sold.per.product  rating  merchant.ratings.count  \
# index
# 17                          3900.0   3.885                 32168.0
#
#        mean.product.prices  mean.retail.prices  average.discount  \
# index
# 17                    4.18                4.13               1.0
#
#        mean.discount  mean.product.ratings.count  total.urgency.count  \
# index
# 17               1.2                       749.0                  6.0
#
#        urgency.text.rate
# index
# 17                  40.0

# %%
df_ins["listed.products"].value_counts()
# Out:
# listed.products
# 1     635
# 2     178
# 3      70
# 4      43
# 5      17
# 6       8
# 8       3
# 7       1
# 15      1
# 12      1
# 9       1
# Name: count, dtype: int64

# %%
df_rating["merchant_id"].value_counts()
# Out:
# merchant_id
# 558c2cdc89d53c4005ea2920    15
# 5acaf29d5ebcfd72403106a8    12
# 583138b06339b410ab9663ec     9
# 564d8a9ac0f55a1276cd96f8     8
# 5533c83986ff95173dc017d0     8
#                             ..
# 58b26eaa01c02f5114ac2ae9     1
# 54b8872d40b37856baa55e38     1
# 59146c0c71a2f21160479ee5     1
# 58c4f51a77361650efb028df     1
# 5add589edb5f1f32114d07df     1
# Name: count, Length: 958, dtype: int64

# %% [markdown]
# sé que tengo dos columnas con la misma data, entonces tengo que usar un merge porque une por columnas y no por índices
# OJO, las columnas no se llaman igual

# %%
df_final = df_rating.merge(df_ins, left_on="merchant_id", right_on="merchant.id", how="left", suffixes=["_l", "_r"])

# %%
len(df_rating["merchant_id"].unique())
# Out:
# 958

# %%
df_ins["merchant.id"].nunique()
# Out:
# 958

# %%
df_final.head(3)
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
# 2  2020 New Arrival Women Spring and Summer Beach...    8.0            43
#
#   currency_buyer  units_sold  uses_ad_boosts  rating_l  rating_count  \
# 0            EUR         100               0      3.76            54
# 1            EUR       20000               1      3.45          6135
# 2            EUR         100               0      3.57            14
#
#    rating_five_count  ...  mean.units.sold.per.product  rating_r  \
# 0               26.0  ...                        100.0     4.129
# ...

# %%
df_final.shape
# Out:
# (1573, 56)

# %% [markdown]
# badges_count, product_variation_inventory, urgency_text, merchant_title, merchant_has_profile_picture, merchant_profile_picture, product_picture, total_urgency_count, has_urgency_banner, urgency_text_rate

# %%
df_final.drop(columns=["badges_count", "product_variation_inventory", "urgency_text", "merchant_title", "merchant_has_profile_picture", "merchant_profile_picture", "product_picture", "total_urgency_count", "has_urgency_banner", "urgency_text_rate"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df_final.drop(columns=["badges_count", "product_variation_inventory", "urgency_text", "merchant_title", "merchant_has_profile_picture", "merchant_profile_picture", "product_picture", "total_urgency_count", "has_urgency_banner", "urgency_text_rate"])
#
# File c:\Users\cesar\anaconda3\envs\promo_m\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
# ...

# %%
df_final.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating_l', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month', 'merchant.id', 'listed.products',
# ...

# %% [markdown]
# En la columna de merchant_info_subtitle, si nos fijamos hay algunas celdas donde tenemos entre paréntesis el número total de calificaciones para el comerciante (que es la misma información que la que tenemos en la columna "merchant_rating_count"). Eliminad de la columna "merchant_info_subtitle" la parte del string de los paréntesis. Guardar el resultado de vuestra limpieza en una columna que se llame igual, es decir, "merchant_info_subtitle".

# %%
df_final["merchant_info_subtitle"]
# Out:
# 0                             (568 notes)
# 1       83 % avis positifs (17,752 notes)
# 2          86 % avis positifs (295 notes)
# 3                          (23,832 notes)
# 4       85 % avis positifs (14,482 notes)
#                       ...
# 1568     90 % avis positifs (5,316 notes)
# 1569                        (4,435 notes)
# 1570       86 % avis positifs (210 notes)
# 1571        77 % avis positifs (31 notes)
# 1572     90 % avis positifs (7,023 notes)
# Name: merchant_info_subtitle, Length: 1573, dtype: object

# %%
x = "83 % avis positifs (17,752 notes)"

print(x)
# Out:
# 83 % avis positifs (17,752 notes)

# %%
x.split("(")
# Out:
# ['83 % avis positifs ', '17,752 notes)']

# %%
x.split("(")[0]
# Out:
# '83 % avis positifs '

# %%
x.split("(")[0].strip()
# Out:
# '83 % avis positifs'

# %%
df_final["merchant_info_subtitle"].str.split("(")
# Out:
# 0                             [, 568 notes)]
# 1       [83 % avis positifs , 17,752 notes)]
# 2          [86 % avis positifs , 295 notes)]
# 3                          [, 23,832 notes)]
# 4       [85 % avis positifs , 14,482 notes)]
#                         ...
# 1568     [90 % avis positifs , 5,316 notes)]
# 1569                        [, 4,435 notes)]
# 1570       [86 % avis positifs , 210 notes)]
# 1571        [77 % avis positifs , 31 notes)]
# 1572     [90 % avis positifs , 7,023 notes)]
# Name: merchant_info_subtitle, Length: 1573, dtype: object

# %%
df_final["merchant_info_subtitle"].str.split("(", expand=True)
# Out:
#                         0              1
# 0                             568 notes)
# 1     83 % avis positifs   17,752 notes)
# 2     86 % avis positifs      295 notes)
# 3                          23,832 notes)
# 4     85 % avis positifs   14,482 notes)
# ...                   ...            ...
# 1568  90 % avis positifs    5,316 notes)
# 1569                        4,435 notes)
# 1570  86 % avis positifs      210 notes)
# 1571  77 % avis positifs       31 notes)
# 1572  90 % avis positifs    7,023 notes)
#
# [1573 rows x 2 columns]

# %%
df_final["merchant_info_subtitle"].str.split("(", expand=True).get(0).str.strip()
# Out:
# 0
# 1       83 % avis positifs
# 2       86 % avis positifs
# 3
# 4       85 % avis positifs
#                ...
# 1568    90 % avis positifs
# 1569
# 1570    86 % avis positifs
# 1571    77 % avis positifs
# 1572    90 % avis positifs
# Name: 0, Length: 1573, dtype: object

# %%
df_final["merchant_info_subtitle_2"] = df_final["merchant_info_subtitle"].str.split("(", expand=True).get(0).str.strip()

# %%
df_final[["merchant_info_subtitle", "merchant_info_subtitle_2"]].sample(5)
# Out:
#                   merchant_info_subtitle merchant_info_subtitle_2
# 1540                       (6,187 notes)
# 792    90 % avis positifs (15,551 notes)       90 % avis positifs
# 441   89 % avis positifs (246,312 notes)       89 % avis positifs
# 63                         (6,187 notes)
# 826     89 % avis positifs (4,632 notes)       89 % avis positifs

# %%
df_final.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating_l', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month', 'merchant.id', 'listed.products',
# ...

# %%
df_final["merchant_info_subtitle"]  = df_final["merchant_info_subtitle"].str.replace("\(.*\)", "", regex = True)
