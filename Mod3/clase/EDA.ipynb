# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("files/rating-and-performance.csv", index_col=0)
df.head(3)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
# 2      2020 New Arrival Women Spring and Summer Beach...    8.0            43
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# ...

# %%
df.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
df.shape
# Out:
# (1573, 43)

# %%
print(f"El núm de filas de mi df es {df.shape[0]} y tiene {df.shape[1]} columnas")
# Out:
# El núm de filas de mi df es 1573 y tiene 43 columnas

# %%
df.describe().T
# Out:
#                                count          mean           std       min  \
# price                         1573.0      8.325372      3.932030  1.000000
# retail_price                  1573.0     23.288620     30.357863  1.000000
# units_sold                    1573.0   4339.005086   9356.539302  1.000000
# uses_ad_boosts                1573.0      0.432931      0.495639  0.000000
# rating                        1573.0      3.820896      0.515374  1.000000
# rating_count                  1573.0    889.659250   1983.928834  0.000000
# rating_five_count             1528.0    442.263743    980.203270  0.000000
# rating_four_count             1528.0    179.599476    400.516231  0.000000
# rating_three_count            1528.0    134.549738    311.690656  0.000000
# rating_two_count              1528.0     63.711387    151.343933  0.000000
# rating_one_count              1528.0     95.735602    214.075544  0.000000
# ...

# %%
df.describe(include="O").T
# Out:
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# title                      Nouvelle mode d'été femmes robe décontractée c...
# ...

# %%
df.head(3)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
# 2      2020 New Arrival Women Spring and Summer Beach...    8.0            43
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# ...

# %%
df["currency_buyer"].nunique()
# Out:
# 1

# %%
df["currency_buyer"].unique()
# Out:
# array(['EUR'], dtype=object)

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(68)

# %%
df.head(5)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
df.duplicated(subset="title").sum()
# Out:
# np.int64(372)

# %%
df[df.duplicated(subset="title", keep=False)].sort_values("title")
# Out:
#                                                    title  \
# index
# 1562    Summer Women s Fashion Lace Up Tie Pants Plus...
# 1160    Summer Women s Fashion Lace Up Tie Pants Plus...
# 146    10 couleurs femmes shorts d'été lacent ceintur...
# 1569   10 couleurs femmes shorts d'été lacent ceintur...
# 811    2018 Femme Femme Mode Note Musicale Débardeur ...
# ...                                                  ...
# 1219   Été nouvelle mode femmes deux pièces vêtements...
# 804    Été nouvelle mode femmes deux pièces vêtements...
# 306    Évider robe licou femmes été col en V robe san...
# 639    Évider robe licou femmes été col en V robe san...
# 1489   Évider robe licou femmes été col en V robe san...
#
#                                               title_orig  price  retail_price  \
# index
# 1562    Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 1160    Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# ...

# %%
df.isna().sum()
# Out:
# title                              0
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 45
# rating_four_count                 45
# rating_three_count                45
# rating_two_count                  45
# rating_one_count                  45
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# ...

# %%
df.isna().sum()/1573*100
# Out:
# title                            0.000000
# title_orig                       0.000000
# price                            0.000000
# retail_price                     0.000000
# currency_buyer                   0.000000
# units_sold                       0.000000
# uses_ad_boosts                   0.000000
# rating                           0.000000
# rating_count                     0.000000
# rating_five_count                2.860776
# rating_four_count                2.860776
# rating_three_count               2.860776
# rating_two_count                 2.860776
# rating_one_count                 2.860776
# badges_count                     0.000000
# badge_local_product              0.000000
# badge_product_quality            0.000000
# badge_fast_shipping              0.000000
# tags                             0.000000
# product_color                    2.606484
# product_variation_size_id        0.890019
# product_variation_inventory      0.000000
# ...

# %%
df.shape
# Out:
# (1573, 43)

# %%
round(df.isna().sum()/df.shape[0]*100, 2)
# Out:
# title                            0.00
# title_orig                       0.00
# price                            0.00
# retail_price                     0.00
# currency_buyer                   0.00
# units_sold                       0.00
# uses_ad_boosts                   0.00
# rating                           0.00
# rating_count                     0.00
# rating_five_count                2.86
# rating_four_count                2.86
# rating_three_count               2.86
# rating_two_count                 2.86
# rating_one_count                 2.86
# badges_count                     0.00
# badge_local_product              0.00
# badge_product_quality            0.00
# badge_fast_shipping              0.00
# tags                             0.00
# product_color                    2.61
# product_variation_size_id        0.89
# product_variation_inventory      0.00
# shipping_option_name             0.00
# shipping_option_price            0.00
# shipping_is_express              0.00
# ...

# %%
df.duplicated()
# Out:
# index
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# Length: 1573, dtype: bool

# %%
x = df.isna().sum()

# %%
x
# Out:
# title                              0
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 45
# rating_four_count                 45
# rating_three_count                45
# rating_two_count                  45
# rating_one_count                  45
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# ...

# %%
y = df.info()

y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
type(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %% [markdown]
# # OJO con esto, matamos el DF

# %%
df_limpio = df.drop(columns=["currency_buyer"], inplace=True)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
df_2 = pd.read_csv("files/rating-and-performance.csv", index_col=0)
df_2.head(3)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
# 2      2020 New Arrival Women Spring and Summer Beach...    8.0            43
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# ...

# %%
df_2.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
df_limpio = df_2.drop(columns=["currency_buyer"], inplace=False)

# %%
df_limpio.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#        units_sold  uses_ad_boosts  rating  rating_count  rating_five_count  \
# index
# ...

# %%
df_2.drop(columns=["title"])
# Out:
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
# ...                                                  ...    ...           ...
# 1568   New Fashion Women Bohemia Dandelion Print Tee ...   6.00             9
# 1569   10 Color Women Summer Shorts Lace Up Elastic W...   2.00            56
# 1570   New Men Siwmwear Beach-Shorts Men Summer Quick...   5.00            19
# 1571   Fashion Women Summer Sleeveless Dresses V Neck...  13.00            11
# 1572   Fashion Women Yoga Pants Slim Fit Fitness Runn...   7.00             6
#
# ...

# %% [markdown]
# Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.

# %%
df_2.head(2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress    8.0            22
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
#
#        rating_five_count  rating_four_count  rating_three_count  \
# index
# 0                   26.0                8.0                10.0
# 1                 2269.0             1027.0              1118.0
#
#        rating_two_count  rating_one_count  badges_count  badge_local_product  \
# index
# ...

# %%
df_cat = df_2.select_dtypes(include="O") # -> o mayúscula ("O") es lo mismo que poner object

df_cat.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig currency_buyer  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...            EUR
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress            EUR
# 2      2020 New Arrival Women Spring and Summer Beach...            EUR
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...            EUR
# 4      Women Summer Shorts Lace Up Elastic Waistband ...            EUR
#
#                                                     tags product_color  \
# index
# 0      Summer,Fashion,womenunderwearsuit,printedpajam...         white
# ...

# %%
df_cat.columns
# Out:
# Index(['title', 'title_orig', 'currency_buyer', 'tags', 'product_color',
#        'product_variation_size_id', 'shipping_option_name', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_id', 'merchant_profile_picture',
#        'product_url', 'product_picture', 'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
df_cat["title"].value_counts()
# Out:
# title
# Nouvelle mode d'été femmes robe décontractée col rond lâche Big Swing jupe sans manches Soild couleur robe de plage                                           24
# Mini robe de soirée décontractée sans manches pour femmes                                                                                                     12
# Femmes d'été Sling Dress V-cou Floral Strap plissé Casual Pocket Large Dress                                                                                   9
# Pantalon à lacets à la mode pour femmes d'été, plus la taille Pantalon court à taille haute décontracté                                                        9
# Tissu taille formateur gilet chaud shaper été shaperwear minceur réglable sueur ceinture corps shaper                                                          9
#                                                                                                                                                               ..
# ...

# %%
df_cat["tags"].value_counts()
# Out:
# tags
# Summer,Fashion,Necks,Skirts,Dress,Loose,Women's Fashion,Round neck,beach dress,sleeveless,Beach,Casual,Women                                                                                                                                            17
# Summer,Sling,Dresses,Dress,V-neck,Casual,Pocket,Women's Fashion,Sleeveless dress,women dress,Floral,sleeveless,Women,loose dress,Pleated,casual dress                                                                                                    9
# slimming,wasitcincher,Fashion,waistgirdle,slimmingcorset,Corset,Summer,Waist,waist trainer,Fashion Accessory,Vest,shaperwear,belt                                                                                                                        8
# ...

# %%
for col in df_cat.columns:
    print(df_cat[col].value_counts())
    print("--------------------------------------")
# Out:
# title
# Nouvelle mode d'été femmes robe décontractée col rond lâche Big Swing jupe sans manches Soild couleur robe de plage                                           24
# Mini robe de soirée décontractée sans manches pour femmes                                                                                                     12
# Femmes d'été Sling Dress V-cou Floral Strap plissé Casual Pocket Large Dress                                                                                   9
# Pantalon à lacets à la mode pour femmes d'été, plus la taille Pantalon court à taille haute décontracté                                                        9
# Tissu taille formateur gilet chaud shaper été shaperwear minceur réglable sueur ceinture corps shaper                                                          9
#                                                                                                                                                               ..
# ...

# %%
df_2["price"].value_counts()
# Out:
# price
# 8.00     282
# 11.00    202
# 7.00     129
# 9.00     126
# 6.00     120
#         ...
# 1.67       1
# 1.84       1
# 3.72       1
# 27.00      1
# 5.91       1
# Name: count, Length: 127, dtype: int64

# %%
df_2.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
def mostrar_cabeza(dataframe):
    display(dataframe.head())

# %%
mostrar_cabeza(df_2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
from src import soporte_2 as sp2

# %%
from src import soporte as sp

# %%
sp.exploracion(df_2)
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %%
sp.nombre
# Out:
# 'Cesar'
