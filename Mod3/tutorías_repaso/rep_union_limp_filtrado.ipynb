# %% [markdown]
# 💡 Unión y Limpieza de Datos en Pandas
#
# Aquí vamos a aprender a combinar datos de diferentes fuentes y a limpiar datos para analizarlos mejor. Vamos a dividirlo en partes sencillas.

# %% [markdown]
# 🔹 1. Métodos para Unir Datos en Pandas
# Imagina que tienes dos tablas de empleados:
#
# Una con datos personales (df_empleados)
#
# Otra con salarios (df_salarios)
#
# 🔹 Ejemplo de las tablas

# %%
import pandas as pd
# Out:
# Index(['id', 'nombre', 'departamento'], dtype='object')

# %%
df_empleados = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "nombre": ["Ana", "Luis", "Carlos", "Marta"],
    "departamento": ["Ventas", "IT", "RRHH", "IT"]
})
df_empleados = pd.DataFrame(df_empleados)
df_empleados.columns
# Out:
# Index(['id', 'nombre', 'departamento'], dtype='object')

# %%
df_salarios = pd.DataFrame({
    "id": [1, 2, 4, 5],
    "salario": [3000, 4000, 3500, 2800]
})
df_salarios = pd.DataFrame(df_salarios)
df_salarios.columns
# Out:
# Index(['id', 'salario'], dtype='object')

# %% [markdown]
# 🔹 2. Métodos de Unión
# 💥 Aquí vienen los tres métodos clave para unir tablas:
#
# 📌 1. merge() → La forma más flexible para unir dos DataFrames
# Permite unir basándose en una columna clave (id en este caso).
#
# Tipos de unión con merge()

# %%
df_completo = df_empleados.merge(df_salarios, on="id", how="outer")
pd.DataFrame(df_completo)
# Out:
#    id  nombre departamento  salario
# 0   1     Ana       Ventas   3000.0
# 1   2    Luis           IT   4000.0
# 2   3  Carlos         RRHH      NaN
# 3   4   Marta           IT   3500.0
# 4   5     NaN          NaN   2800.0

# %% [markdown]
# ## Tipos de how
# - Inner : Solo devuelve las coincidencias (intersección). // >>>>>>>>>>>>>
# - left : Mantiene todo el DataFrame izquierdo (df_empleados) y añade lo que coincida del derecho. // >>>>>>>>>>>>>>>>><>
# - right : Mantiene todo el DataFrame derecho (df_salarios) y añade lo que coincida del izquierdo. // >>>>>>>>>>>>>>>>>>>>>>>>><<<>>>
# - outer : Devuelve todo, incluso si no hay coincidencias.

# %% [markdown]
# 📌 2. concat() → Apilar tablas
#
# Este método no une por columnas clave, sino que las pega una encima de otra (vertical) o una al lado de otra (horizontal).

# %%
df_union_filas = pd.concat([df_empleados, df_salarios], axis=0)  # Une en filas (vertical)
df_union_columnas = pd.concat([df_empleados, df_salarios], axis=1)  # Une en columnas (horizontal)

# %%
df_union_filas
# Out:
#    id  nombre departamento  salario
# 0   1     Ana       Ventas      NaN
# 1   2    Luis           IT      NaN
# 2   3  Carlos         RRHH      NaN
# 3   4   Marta           IT      NaN
# 0   1     NaN          NaN   3000.0
# 1   2     NaN          NaN   4000.0
# 2   4     NaN          NaN   3500.0
# 3   5     NaN          NaN   2800.0

# %%
df_union_columnas
# Out:
#    id  nombre departamento  id  salario
# 0   1     Ana       Ventas   1     3000
# 1   2    Luis           IT   2     4000
# 2   3  Carlos         RRHH   4     3500
# 3   4   Marta           IT   5     2800

# %% [markdown]
# 📌 3. join() → Unir por índice
# Si los DataFrames tienen el mismo índice, puedes unirlos de forma más rápida.

# %%
df_empleados.set_index("id", inplace=True)
df_salarios.set_index("id", inplace=True)
# inplace=True:
# Pandas no modifica el DataFrame original, 
# solo te devuelve una copia con el nuevo índice.

# %% [markdown]
# Si "id" ya es el índice, no necesitas set_index().
#
# 🔹 Solución: Si necesitas que vuelva a ser una columna, usa:

# %%
# df_empleados.reset_index(inplace=True)

# %%
# Ver las columnas
#print(df_empleados.columns)

# Si "id" no está, revisa y corrige el nombre
#df_empleados.rename(columns=lambda x: x.strip(), inplace=True)  # Elimina espacios

# Volver a intentar establecer el índice
#df_empleados.set_index("id", inplace=True)

# %%
df_join = df_empleados.join(df_salarios, how="left")

# %%
df_join
# Out:
#     nombre departamento  salario
# id
# 1      Ana       Ventas   3000.0
# 2     Luis           IT   4000.0
# 3   Carlos         RRHH      NaN
# 4    Marta           IT   3500.0

# %%
df_join_right = df_empleados.join(df_salarios, how="right")

# %%
df_join_right
# Out:
#    nombre departamento  salario
# id
# 1     Ana       Ventas     3000
# 2    Luis           IT     4000
# 4   Marta           IT     3500
# 5     NaN          NaN     2800

# %% [markdown]
# ### Mantiene lo que hay en el derecho (right) y añade lo que coincida en el izquierdo

# %% [markdown]
# 🏋️‍♀️ Ejercicio Práctico

# %%
df_productos = pd.DataFrame({
    "id_producto": [1, 2, 3, 4],
    "nombre": ["Zapatos", "Camisa", "Pantalón", "Gorra"]
})

df_precios = pd.DataFrame({
    "id_producto": [2, 3, 5],
    "precio": [25, 30, 15]
})

# %%
df_productos = pd.DataFrame(df_productos)
df_productos
# Out:
#                nombre
# id_producto
# 1             Zapatos
# 2              Camisa
# 3            Pantalón
# 4               Gorra

# %%
df_precios = pd.DataFrame (df_precios)
df_precios
# Out:
#              precio
# id_producto
# 2                25
# 3                30
# 5                15

# %%
df_productos.set_index("id_producto", inplace=True)
df_precios.set_index("id_producto", inplace=True)

# %% [markdown]
# ➡️ Ejercicio:
#
# 1. Usa merge() para unir ambas tablas usando un left join.

# %%
df_merge = df_productos.merge(df_precios, on="id_producto", how="left")
pd.DataFrame(df_merge)
# Out:
#                nombre  precio
# id_producto
# 1             Zapatos     NaN
# 2              Camisa    25.0
# 3            Pantalón    30.0
# 4               Gorra     NaN

# %% [markdown]
# 2. Usa concat() para unirlas en filas.

# %%
df_concat = pd.concat([df_productos, df_precios], axis=1) 
df_concat
# Out:
#                nombre  precio
# id_producto
# 1             Zapatos     NaN
# 2              Camisa    25.0
# 3            Pantalón    30.0
# 4               Gorra     NaN
# 5                 NaN    15.0

# %% [markdown]
# 3. Usa join() tras convertir id_producto en índice.

# %%
df_join = df_productos.join(df_precios, how="left")  
df_join
# Out:
#                nombre  precio
# id_producto
# 1             Zapatos     NaN
# 2              Camisa    25.0
# 3            Pantalón    30.0
# 4               Gorra     NaN
